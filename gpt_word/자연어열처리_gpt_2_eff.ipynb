# %%
"""
의학 텍스트 분류기와 프롬프트를 통합한 파일 (GPT API 형식)
"""
import nest_asyncio
nest_asyncio.apply()  # 중첩 이벤트 루프 허용
import os
import json
import logging
import asyncio
import pandas as pd
import openai
from datetime import datetime
import sys
from typing import List, Dict, Optional
from tenacity import retry, stop_after_attempt, wait_exponential
import re
from prompts.medical_prompts import CCPrompts
from prompts.medical_prompts import TreatmentPrompts
from prompts.medical_prompts import TherapyPrompts
# from prompts.medical_prompts import PresentIllnessPrompts

from prompts.PI_prompts import PresentIllnessPrompts_ver2
from prompts.medical_prompts import NumericPrompts

from rate_limiter.rate_limiter import RateLimiter

from tqdm.asyncio import tqdm as tqdm_asyncio

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel('../../data/centum_data/21.11-24.6환자 CC_PI_치료계획.xlsx')
df['날짜'] = pd.to_datetime(df['날짜'])
df = df.iloc[:,1:]

api = pd.read_csv('../../data/info.csv')
api_key = api.loc[1][1]

# %%
df.columns = df.columns.str.strip()
df = df[['환자번호', '날짜', 'CC', '약', '장치', '습관', '찜질', '마사지, 스트레칭', 'PI']]

# %%
df

# %%
class Config:
    # 실제 OpenAI API 키로 교체하거나 환경변수로부터 로드하세요.
    API_KEY = api_key
    # MODEL_NAME = "gpt-4o"
    MODEL_NAME = "o3-mini"
    MAX_TOKENS = 4096
    TEMPERATURE = 0
    BATCH_SIZE = 100
    SEMAPHORE_LIMIT = 5
    MAX_RETRIES = 4
    CHECKPOINT_DIR = "checkpoints"
    LOG_FILE = "medical_classifier.log"
    # RPM_LIMIT = 4000  # 실제 한도보다 약간 낮게 설정
    # TPM_LIMIT = 3800000  # 실제 한도보다 약간 낮게 설정
    
    # o1 모델 API 제한 반영 (약간의 여유를 둠)
    RPM_LIMIT = 4800  # 5,000 RPM
    TPM_LIMIT = 3800000  # 4,000,000 TPM
    TPD_LIMIT = 38000000  # 40,000,000 TPD
    INDEX_COLUMNS = ['환자번호', '날짜']

#############################################
# 로깅 설정 함수
#############################################

def setup_logging(log_file=Config.LOG_FILE):
    """로깅 설정을 초기화하는 함수"""
    logging.basicConfig(
        level=logging.INFO,
        format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
        handlers=[
            logging.FileHandler(log_file),
            logging.StreamHandler()
        ]
    )
    return logging.getLogger(__name__)

# 초기 로거 생성 (설정은 아직 적용되지 않음)
logger = logging.getLogger(__name__)


#############################################
# 체크포인트 관리 클래스
#############################################

class CheckpointManager:
    """Checkpoint management class"""
    def __init__(self, checkpoint_dir: str = Config.CHECKPOINT_DIR):
        self.checkpoint_dir = checkpoint_dir
        os.makedirs(self.checkpoint_dir, exist_ok=True)
    
    def get_checkpoint_path(self, column: str) -> str:
        safe_column = column.replace("/", "_").replace("\\", "_")
        return os.path.join(self.checkpoint_dir, f"{safe_column}_checkpoint.parquet")

    def save_checkpoint(self, df: pd.DataFrame, column: str) -> None:
        try:
            # 인덱스가 튜플이거나 복합 인덱스인 경우 문자열로 변환
            if isinstance(df.index, pd.MultiIndex) or df.index.dtype == 'object':
                # 인덱스를 문자열로 변환하여 저장
                df_to_save = df.copy()
                df_to_save.index = df_to_save.index.map(str)
                df_to_save.to_parquet(self.get_checkpoint_path(column))
            else:
                df.to_parquet(self.get_checkpoint_path(column))
            logger.info(f"Checkpoint saved for column {column}")
        except Exception as e:
            logger.error(f"Failed to save checkpoint for {column}: {str(e)}")

    def load_checkpoint(self, column: str) -> Optional[pd.DataFrame]:
        path = self.get_checkpoint_path(column)
        if os.path.exists(path):
            try:
                return pd.read_parquet(path)
            except Exception as e:
                logger.error(f"Failed to load checkpoint for {column}: {str(e)}")
        return None


#############################################
# 메디컬 텍스트 분류기 클래스 (GPT API 사용)
#############################################

class MedicalTextClassifier:
    """의학 텍스트 분류기 클래스"""
    
    def __init__(self, api_key: str, config=None):
        """초기화"""
        self.config = config if config is not None else Config
        
        # API 키 설정 방식 수정
        # 방법 1: 클라이언트 초기화 시 직접 API 키 설정
        self.client = openai.OpenAI(api_key=api_key)  
        
        # 방법 2: 환경 변수로 API 키 설정 (추가적인 방법)
        import os
        os.environ["OPENAI_API_KEY"] = api_key
        self.config = config if config is not None else Config
        self.client = openai.OpenAI(api_key=api_key)  # 클라이언트 객체 생성 방식 변경
        self.semaphore = asyncio.Semaphore(self.config.SEMAPHORE_LIMIT)
        self.checkpoint = CheckpointManager(self.config.CHECKPOINT_DIR)
        # Rate Limiter 객체 추가
        self.rate_limiter = RateLimiter(
            rpm_limit=self.config.RPM_LIMIT,
            tpm_limit=self.config.TPM_LIMIT
        )
        # 분류기 메소드 맵핑
        self.classifiers = {
            'CC': self._classify_cc,
            '약': self._classify_medication,
            '장치': self._classify_device,
            '습관': self._classify_habit,
            '찜질': self._classify_hot_pack,
            '마사지, 스트레칭': self._classify_massage,
            'PI': self._classify_present_illness,
        }
    
    async def process_all_columns(self, df: pd.DataFrame) -> pd.DataFrame:
        """모든 컬럼 처리"""
        original_shape = df.shape
        processed_cols = 0
        
        # 원본 인덱스 저장 및 리셋
        original_index = df.index.copy()
        result_df = df.reset_index().copy()  # 인덱스를 컬럼으로 변환하여 복사
        
        for column in self.classifiers.keys():
            if column in df.columns:
                logger.info(f"Processing column: {column}")
                # 인덱스가 리셋된 데이터프레임 전달
                column_results = await self._process_column_with_checkpoint(result_df, column)
                
                if column_results is not None and not column_results.empty:
                    # 결과 데이터프레임에 매핑 (이미 인덱스가 컬럼으로 변환되어 있음)
                    for derived_col in column_results.columns:
                        if derived_col.startswith(f"{column}_"):
                            result_df[derived_col] = column_results[derived_col]
                    
                    # 로깅
                    derived_cols = [col for col in column_results.columns 
                                    if col.startswith(f"{column}_")]
                    logger.info(f"Column {column} generated {len(derived_cols)} derived columns: {derived_cols}")
                    
                    for derived_col in derived_cols:
                        non_empty_count = result_df[derived_col].notna().sum()
                        logger.info(f"Column {derived_col} has {non_empty_count} non-empty values")
                
                processed_cols += 1
        
        # 처리 완료 후 원래 인덱스로 복원 (필요한 경우)
        # result_df.set_index(self.config.INDEX_COLUMNS, inplace=True)
        
        logger.info(f"Original DataFrame shape: {original_shape}, Processed columns: {processed_cols}")
        return result_df

    async def _process_column_with_checkpoint(self, df: pd.DataFrame, column: str) -> pd.DataFrame:
        """체크포인트를 사용한 컬럼 처리"""
        try:
            # 체크포인트 확인
            checkpoint_df = self.checkpoint.load_checkpoint(column)
            if checkpoint_df is not None:
                logger.info(f"Resumed from checkpoint for {column}")
                return checkpoint_df

            # 공백이거나 길이가 0인 레코드 제외
            mask = df[column].notna() & (df[column].astype(str).str.strip().str.len() > 0)
            
            if not mask.any():
                logger.info(f"No valid text entries found in column {column}")
                return pd.DataFrame()

            # 필터링된 텍스트와 인덱스 쌍 생성 (인덱스가 컬럼으로 변환됨)
            filtered_df = df.loc[mask].copy()
            # 유니크한 식별자로 행 인덱스 사용
            texts_with_idx = [(idx, text) for idx, text in zip(filtered_df.index, filtered_df[column])]
            
            logger.info(f"Processing {len(texts_with_idx)} valid records for column {column}")
            
            # API 호출 및 결과 처리
            results = await self._safe_process_batches(
                texts=[text for _, text in texts_with_idx],
                original_indices=[idx for idx, _ in texts_with_idx],
                classifier=self.classifiers[column],
                column=column
            )

            # 결과 처리
            if results:
                # 결과를 데이터프레임으로 변환
                results_df = pd.DataFrame(results)
                
                # 'index' 열을 인덱스로 설정
                if 'index' in results_df.columns:
                    results_df.set_index('index', inplace=True)
                
                # 컬럼명 변경: 결과의 각 키에 column_ 접두사 추가
                results_df.columns = [f"{column}_{col}" for col in results_df.columns]
                
                # 데이터프레임 저장 및 반환
                self.checkpoint.save_checkpoint(results_df, column)
                return pd.DataFrame(results_df)

            return pd.DataFrame()

        except Exception as e:
            logger.error(f"Critical error processing {column}: {str(e)}")
            raise

    async def _safe_process_batches(self, texts: List[str], original_indices: List[int],
                                classifier, column: str) -> List[Dict]:
        """더 높은 신뢰성을 위해 한 번에 하나의 레코드 처리"""
        results = []

        for i, (text, idx) in enumerate(zip(texts, original_indices)):
            try:
                # 유효하지 않은 텍스트 건너뛰기
                if text is None or len(str(text).strip()) == 0:
                    logger.info(f"Skipping invalid text at index {idx} (None or empty)")
                    results.append({"index": idx})
                    continue
                    
                logger.info(f"단일 텍스트 처리 중 {i+1}/{len(texts)} (인덱스 {idx})")
                
                # API 호출
                batch_result = await self._process_with_retry(classifier, [text], [idx])
                
                if batch_result:
                    results.extend(batch_result)
                    
                    # 중간 체크포인트 저장
                    if (i + 1) % 10 == 0 or i == len(texts) - 1:
                        partial_df = pd.DataFrame(results)
                        if 'index' in partial_df.columns:
                            partial_df.set_index('index', inplace=True)
                        
                        # 컬럼명 변경
                        partial_df.columns = [f"{column}_{col}" for col in partial_df.columns]
                        self.checkpoint.save_checkpoint(partial_df, column)
                    
            except Exception as e:
                logger.error(f"인덱스 {idx}의 텍스트 처리 실패: {str(e)}")
                results.append({"index": idx})

        return results

    @retry(stop=stop_after_attempt(3),
           wait=wait_exponential(multiplier=1, min=2, max=10))
# _process_with_retry 메서드에 추가
    async def _process_with_retry(self, classifier, batch_texts: List[str], batch_indices: List[int]) -> List[Dict]:
        """각 텍스트를 개별적으로 처리하여 정확한 매핑 보장"""
        results = []

        for i, text in enumerate(batch_texts):
            async with self.semaphore:
                # 한 번에 하나의 텍스트 처리
                single_result = await classifier([text], self.semaphore)
                if single_result and len(single_result) > 0:
                    # 결과에 인덱스 추가
                    results.append({"index": batch_indices[i], **single_result[0]})
                else:
                    # API가 빈 또는 유효하지 않은 결과를 반환한 경우 처리
                    results.append({"index": batch_indices[i]})
                
                # 각 개별 결과 로깅
                logger.info(f"텍스트 {i} (인덱스 {batch_indices[i]}) 처리 완료: {single_result[0] if single_result and len(single_result) > 0 else '결과 없음'}")
        
        return results

    def _cleanup_checkpoint(self, column: str) -> None:
        """성공적인 처리 후 체크포인트 정리"""
        try:
            checkpoint_path = self.checkpoint.get_checkpoint_path(column)
            if os.path.exists(checkpoint_path):
                os.remove(checkpoint_path)
                logger.info(f"Checkpoint cleaned up for {column}")
        except Exception as e:
            logger.error(f"Failed to cleanup checkpoint for {column}: {str(e)}")

    # _make_api_call 메서드 수정 (rate limiter 사용)
    # @retry(stop=stop_after_attempt(3),
    #     wait=wait_exponential(multiplier=1, min=2, max=10))
    # # gpt-4o 모델 사용
    # async def _make_api_call(self, prompt: str, semaphore: asyncio.Semaphore) -> List[Dict]:
    #     """API 호출 메소드 (OpenAI API v1.0.0+ with Rate Limiting)"""
    #     try:
    #         async with semaphore:
    #             # API 호출 수행
    #             client = openai.OpenAI(api_key=self.config.API_KEY)
                
    #             # 헤더에 명시적으로 인증 정보 추가
    #             headers = {
    #                 "Authorization": f"Bearer {self.config.API_KEY}",
    #                 "Content-Type": "application/json"
    #             }
                
    #             # API 호출 시 헤더 추가
    #             response = await asyncio.to_thread(
    #                 client.chat.completions.create,
    #                 model=self.config.MODEL_NAME,
    #                 messages=[
    #                     {"role": "system", "content": "JSON 형식으로 응답하세요."},
    #                     {"role": "user", "content": prompt}
    #                 ],
    #                 max_tokens=self.config.MAX_TOKENS,
    #                 temperature=self.config.TEMPERATURE,
    #                 # headers=headers  # 헤더 추가
    #             )
                
    #             # 실제 토큰 사용량 기록 (응답 토큰 + 입력 토큰)
    #             total_tokens = response.usage.total_tokens
    #             self.rate_limiter.record_request(total_tokens)
                
    #             # 레이트 리밋 헤더가 있다면 정보 업데이트
    #             if hasattr(response, 'headers'):
    #                 self.rate_limiter.update_from_headers(response.headers)
                
    #             # 현재 사용량 로깅
    #             usage = self.rate_limiter.get_current_usage()
    #             logger.info(f"Current API usage: {usage['rpm']} RPM, {usage['tpm']} TPM")
                
    #             content = response.choices[0].message.content
    #             logger.debug(f"API Response: {content[:200]}...")
    #             result = self._validate_and_parse_json(content)
    #             if not result:
    #                 raise ValueError("Invalid JSON structure")
    #             return result

    #     except Exception as e:
    #         logger.error(f"API call failed: {str(e)}")
    #         raise
    
    #o1-mini 모델 사용
    @retry(stop=stop_after_attempt(3),
    wait=wait_exponential(multiplier=1, min=2, max=10))
    async def _make_api_call(self, prompt: str, semaphore: asyncio.Semaphore) -> List[Dict]:
        """API 호출 메소드 (직접 API 호출)"""
        try:
            async with semaphore:
                import httpx
                
                # API 요청 준비
                url = "https://api.openai.com/v1/chat/completions"
                headers = {
                    "Authorization": f"Bearer {self.config.API_KEY}",
                    "Content-Type": "application/json"
                }
                data = {
                    "model": "gpt-3.5-turbo",
                    "messages": [
                        {"role": "system", "content": "JSON 형식으로 응답하세요."},
                        {"role": "user", "content": prompt}
                    ],
                    "max_tokens": self.config.MAX_TOKENS,
                    "temperature": self.config.TEMPERATURE
                }
                
                # API 호출
                async with httpx.AsyncClient() as client:
                    response = await client.post(url, headers=headers, json=data, timeout=60.0)
                    response.raise_for_status()  # 오류 발생 시 예외 발생
                    response_data = response.json()
                
                # 응답 처리
                content = response_data["choices"][0]["message"]["content"]
                logger.debug(f"API Response: {content[:200]}...")
                
                # 토큰 사용량 기록
                total_tokens = response_data["usage"]["total_tokens"]
                self.rate_limiter.record_request(total_tokens)
                
                # JSON 파싱
                result = self._validate_and_parse_json(content)
                if not result:
                    raise ValueError("Invalid JSON structure")
                return result

        except httpx.HTTPStatusError as e:
            logger.error(f"HTTP error: {e.response.status_code} - {e.response.text}")
            raise
        except Exception as e:
            logger.error(f"API call failed: {str(e)}")
            raise

    def _validate_and_parse_json(self, content: str) -> List[Dict]:
        """향상된 JSON 응답 검증 및 파싱"""
        try:
            # 원시 내용 로깅
            logger.info(f"원시 API 응답: {content[:500]}...")
            
            # 먼저 직접 JSON 파싱 시도
            try:
                parsed = json.loads(content)
                if isinstance(parsed, list):
                    return parsed
            except json.JSONDecodeError:
                pass  # 직접 파싱이 실패하면 정규식 추출로 계속 진행
            
            # 정규식으로 JSON 추출
            json_pattern = r'```json\s*([\s\S]*?)\s*```|(\[[\s\S]*\])'
            matches = re.findall(json_pattern, content)
            
            for match in matches:
                # 각 일치 항목 시도
                for m in match:
                    if not m.strip():
                        continue
                        
                    try:
                        parsed = json.loads(m.strip())
                        if isinstance(parsed, list):
                            logger.info(f"JSON 파싱 성공: {parsed}")
                            return parsed
                    except:
                        continue
            
            # 마지막 수단: JSON 객체나 배열처럼 보이는 것 찾기
            fallback_pattern = r'(\{[\s\S]*?\}|\[[\s\S]*?\])'
            fallback_matches = re.findall(fallback_pattern, content)
            
            for m in fallback_matches:
                try:
                    parsed = json.loads(m.strip())
                    if isinstance(parsed, dict):
                        # 단일 객체를 목록으로 변환
                        return [parsed]
                    elif isinstance(parsed, list):
                        return parsed
                except:
                    continue
                    
            logger.error(f"응답에서 JSON을 파싱하지 못함")
            return []
            
        except Exception as e:
            logger.error(f"JSON 파싱 오류: {str(e)}")
            return []
        
    async def _classify_cc(self, texts: List[str], semaphore: asyncio.Semaphore) -> List[Dict]:
        """Chief Complaints 분류"""
        # CC를 3개의 작은 프롬프트로 분할
        cc_results = await self._make_api_call(CCPrompts.cc_analysis_prompt(texts), semaphore)
        history_results = await self._make_api_call(CCPrompts.cc_history_prompt(texts), semaphore)
        severity_results = await self._make_api_call(CCPrompts.cc_severity_prompt(texts), semaphore)
        
        # 결과 병합
        combined_results = []
        for i in range(len(texts)):
            combined_dict = {}
            if i < len(cc_results):
                combined_dict.update(cc_results[i])
            if i < len(history_results):
                combined_dict.update(history_results[i])
            if i < len(severity_results):
                combined_dict.update(severity_results[i])
            
            combined_results.append(combined_dict)
        
        return combined_results
    
    async def _classify_medication(self, texts: List[str], semaphore: asyncio.Semaphore) -> List[Dict]:
        """약물 복용 분류"""
        results = await self._make_api_call(TreatmentPrompts.medication_prompt(texts), semaphore)
        logger.debug(f"약물 분류 결과: {results}")
        return results

    async def _classify_device(self, texts: List[str], semaphore: asyncio.Semaphore) -> List[Dict]:
        """장치 사용 분류"""
        results = await self._make_api_call(TreatmentPrompts.device_prompt(texts), semaphore)
        logger.debug(f"장치 분류 결과: {results}")
        return results

    async def _classify_habit(self, texts: List[str], semaphore: asyncio.Semaphore) -> List[Dict]:
        """습관 분류"""
        results = await self._make_api_call(TreatmentPrompts.habit_prompt(texts), semaphore)
        logger.debug(f"습관 분류 결과: {results}")
        return results

    async def _classify_hot_pack(self, texts: List[str], semaphore: asyncio.Semaphore) -> List[Dict]:
        """찜질 분류"""
        results = await self._make_api_call(TherapyPrompts.hot_pack_prompt(texts), semaphore)
        logger.debug(f"찜질 분류 결과: {results}")
        return results
    
    async def _classify_massage(self, texts: List[str], semaphore: asyncio.Semaphore) -> List[Dict]:
        """마사지 및 스트레칭 분류"""
        results = await self._make_api_call(TherapyPrompts.massage_prompt(texts), semaphore)
        logger.debug(f"마사지 분류 결과: {results}")
        return results 
        
    async def _classify_present_illness(self, texts: List[str], semaphore: asyncio.Semaphore) -> List[Dict]:
        """PI 분류 개선"""
        # 유효하지 않은 텍스트 필터링 (None, 비어있거나 길이가 0)
        valid_texts = []
        valid_indices = []
        result_mapping = {}
        
        for i, text in enumerate(texts):
            if text is None or len(str(text).strip()) == 0:
                # 유효하지 않은 텍스트는 빈 결과로 매핑
                result_mapping[i] = {}
            else:
                # 텍스트 길이 제한 (10,000자)
                valid_text = text[:10000] if len(text) > 10000 else text
                valid_texts.append(valid_text)
                valid_indices.append(i)
        
        # 유효한 텍스트가 없으면 빈 결과 반환
        if not valid_texts:
            logger.info("No valid texts for PI classification")
            return [{} for _ in range(len(texts))]
        
        # 로깅 추가: 유효한 텍스트 확인
        for i, text in enumerate(valid_texts):
            logger.info(f"Valid text {i}, length {len(text)}, first 100 chars: {text[:100]}")
        
        smaller_batch_size = 10  # PI에 대해 더 작은 배치 크기 사용
        all_valid_results = []
        
        for i in range(0, len(valid_texts), smaller_batch_size):
            batch = valid_texts[i:i+smaller_batch_size]
            batch_results = []  # 각 배치의 결과를 저장할 리스트
            
            # 로깅 추가: 배치 크기 및 첫 번째 텍스트 확인
            logger.info(f"Processing batch {i//smaller_batch_size + 1}, size: {len(batch)}")
            if batch:
                logger.info(f"First item in batch, length {len(batch[0])}, first 100 chars: {batch[0][:100]}")
        
            try:
                logger.info(f"Processing PI basic info batch {i//smaller_batch_size + 1}")
                pi_aggravating_factors_results = await self._make_api_call(PresentIllnessPrompts_ver2.pi_aggravating_factors(batch), semaphore)
                
                logger.info(f"Processing PI examination batch {i//smaller_batch_size + 1}")
                pi_TMJ_PI_desc_results = await self._make_api_call(PresentIllnessPrompts_ver2.pi_TMJ_PI_desc(batch), semaphore)
                
                logger.info(f"Processing PI treatment batch {i//smaller_batch_size + 1}")
                pi_TMJ_PI_treatment_results = await self._make_api_call(PresentIllnessPrompts_ver2.pi_TMJ_PI_treatment(batch), semaphore)
                
                logger.info(f"Processing PI treatment batch {i//smaller_batch_size + 1}")
                pi_drug_treatment_results = await self._make_api_call(PresentIllnessPrompts_ver2.pi_drug_treatment(batch), semaphore)
                
                logger.info(f"Processing PI treatment batch {i//smaller_batch_size + 1}")
                pi_closing_dentalgear_desc_results = await self._make_api_call(PresentIllnessPrompts_ver2.pi_closing_dentalgear_desc(batch), semaphore)
                
                logger.info(f"Processing PI treatment batch {i//smaller_batch_size + 1}")
                pi_PI_check_results = await self._make_api_call(PresentIllnessPrompts_ver2.pi_PI_check(batch), semaphore)
                
                logger.info(f"Processing PI treatment batch {i//smaller_batch_size + 1}")
                pi_PI_diagnosis_jojint_results = await self._make_api_call(PresentIllnessPrompts_ver2.pi_PI_diagnosis_jojint(batch), semaphore)
                
                logger.info(f"Processing PI treatment batch {i//smaller_batch_size + 1}")
                pi_occlusal_treatment_results = await self._make_api_call(PresentIllnessPrompts_ver2.pi_occlusal_treatment(batch), semaphore)
                
                logger.info(f"Processing PI treatment batch {i//smaller_batch_size + 1}")
                pi_medication_prescription_results = await self._make_api_call(PresentIllnessPrompts_ver2.pi_medication_prescription(batch), semaphore)
                
                logger.info(f"Processing PI treatment batch {i//smaller_batch_size + 1}")
                pi_other_treatment_results = await self._make_api_call(PresentIllnessPrompts_ver2.pi_other_treatment(batch), semaphore)
                
                logger.info(f"Processing PI treatment batch {i//smaller_batch_size + 1}")
                pi_onset_results = await self._make_api_call(PresentIllnessPrompts_ver2.pi_onset(batch), semaphore)
                
                logger.info(f"Processing PI treatment batch {i//smaller_batch_size + 1}")
                pi_pattern_results = await self._make_api_call(PresentIllnessPrompts_ver2.pi_pattern(batch), semaphore)
                
                logger.info(f"Processing PI treatment batch {i//smaller_batch_size + 1}")
                pi_status_results = await self._make_api_call(PresentIllnessPrompts_ver2.pi_status(batch), semaphore)
                
                for j in range(len(batch)):
                    combined_dict = {}
                    if j < len(pi_aggravating_factors_results):
                        combined_dict.update(pi_aggravating_factors_results[j])
                    if j < len(pi_TMJ_PI_desc_results):
                        combined_dict.update(pi_TMJ_PI_desc_results[j])
                    if j < len(pi_TMJ_PI_treatment_results):
                        combined_dict.update(pi_TMJ_PI_treatment_results[j])
                    if j < len(pi_drug_treatment_results):
                        combined_dict.update(pi_drug_treatment_results[j])
                    if j < len(pi_closing_dentalgear_desc_results):
                        combined_dict.update(pi_closing_dentalgear_desc_results[j])
                    if j < len(pi_PI_check_results):
                        combined_dict.update(pi_PI_check_results[j])
                    if j < len(pi_PI_diagnosis_jojint_results):
                        combined_dict.update(pi_PI_diagnosis_jojint_results[j])
                    if j < len(pi_occlusal_treatment_results):
                        combined_dict.update(pi_occlusal_treatment_results[j])
                    if j < len(pi_medication_prescription_results):
                        combined_dict.update(pi_medication_prescription_results[j])
                    if j < len(pi_other_treatment_results):
                        combined_dict.update(pi_other_treatment_results[j])
                    if j < len(pi_onset_results):
                        combined_dict.update(pi_onset_results[j])
                    if j < len(pi_pattern_results):
                        combined_dict.update(pi_pattern_results[j])
                    if j < len(pi_status_results):
                        combined_dict.update(pi_status_results[j])
                    
                    batch_results.append(combined_dict)
                
                all_valid_results.extend(batch_results)
            
            except Exception as e:
                logger.error(f"Error processing PI batch {i//smaller_batch_size + 1}: {str(e)}")
                all_valid_results.extend([{} for _ in range(len(batch))])
        
        # 최종 결과 배열 생성 (원래 순서대로)
        # 먼저 빈 결과 딕셔너리로 채움
        final_results = [{} for _ in range(len(texts))]
        
        # 유효한 텍스트에 대한 결과를 올바른 위치에 넣음
        for valid_idx, result in zip(valid_indices, all_valid_results):
            final_results[valid_idx] = result
        
        return final_results

        
#############################################
# 의학 데이터 처리 함수
#############################################

async def process_medical_data(df: pd.DataFrame, api_key: str) -> pd.DataFrame:
    """Process medical data with comprehensive error handling and logging"""
    classifier = MedicalTextClassifier(api_key)
    start_time = datetime.now()
    logger.info(f"Starting medical data processing at {start_time}")

    try:
        processed_df = await classifier.process_all_columns(df)

        end_time = datetime.now()
        processing_time = end_time - start_time
        total_rows = len(df)
        processed_columns = [col for col in df.columns if col in classifier.classifiers]

        logger.info("=== Processing Summary ===")
        logger.info(f"Total time: {processing_time}")
        logger.info(f"Total rows processed: {total_rows}")
        logger.info(f"Columns processed: {processed_columns}")

        for col in processed_columns:
            total_entries = df[col].notna().sum()
            processed_entries = sum(1 for col_name in processed_df.columns
                                 if col_name.startswith(f"{col}_")
                                 and processed_df[col_name].notna().any())
            success_rate = (processed_entries / total_entries * 100) if total_entries > 0 else 0
            logger.info(f"{col} - Success rate: {success_rate:.2f}%")

        return processed_df

    except Exception as e:
        logger.critical(f"Critical error during medical data processing: {str(e)}")
        raise


#############################################
# 메인 함수
#############################################

#############################################
# 메인 함수
#############################################

def main():
    """메인 함수"""
    global logger
    logger = setup_logging()
    total_start_time = datetime.now()

    try:
        # 실제 환자 데이터를 로드하는 경우 아래 주석을 해제하세요.
        # df = pd.read_excel('환자데이터.xlsx')
        
        # 원본 데이터 불러오기
        original_df = df
        chunk_size = 200
        total_rows = len(original_df)
        
        # df_checkpoint 폴더 생성
        checkpoint_dir = 'df_checkpoint'
        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)
            logger.info(f"체크포인트 디렉토리 '{checkpoint_dir}'를 생성했습니다.")
        
        # 체크포인트 파일 확인
        checkpoint_file = os.path.join(checkpoint_dir, 'checkpoint.json')
        last_processed_chunk = -1
        all_processed_df = pd.DataFrame()
        
        if os.path.exists(checkpoint_file):
            try:
                with open(checkpoint_file, 'r', encoding='utf-8') as f:
                    checkpoint_data = json.load(f)
                last_processed_chunk = checkpoint_data.get('last_processed_chunk', -1)
                
                # 이미 처리된 데이터 불러오기
                processed_file = checkpoint_data.get('processed_file', '')
                if os.path.exists(processed_file):
                    logger.info(f"체크포인트 파일 {checkpoint_file}을 찾았습니다. 이전 진행 상황을 불러옵니다.")
                    logger.info(f"이미 {last_processed_chunk + 1}개 청크가 처리되었습니다.")
                    
                    # 파일 형식에 따라 적절한 로드 방법 사용
                    if processed_file.endswith('.parquet'):
                        try:
                            all_processed_df = pd.read_parquet(processed_file)
                        except Exception as e:
                            logger.warning(f"Parquet 파일 로드 실패: {str(e)}. CSV 로드를 시도합니다.")
                            csv_file = processed_file.replace('.parquet', '.csv')
                            if os.path.exists(csv_file):
                                all_processed_df = pd.read_csv(csv_file, index_col=0, encoding='utf-8-sig')
                            else:
                                raise Exception(f"대체 CSV 파일을 찾을 수 없습니다: {csv_file}")
                    elif processed_file.endswith('.csv'):
                        all_processed_df = pd.read_csv(processed_file, index_col=0, encoding='utf-8-sig')
                    else:
                        raise Exception(f"지원되지 않는 파일 형식: {processed_file}")
                    
                    # 데이터 로드 확인
                    logger.info(f"체크포인트에서 {len(all_processed_df)}개 행, {len(all_processed_df.columns)}개 열 로드 완료")
            except Exception as e:
                logger.warning(f"체크포인트 파일 로드 실패: {str(e)}. 처음부터 다시 시작합니다.")
                last_processed_chunk = -1
                all_processed_df = pd.DataFrame()
        
        # 청크 생성
        chunks = [original_df[i:i+chunk_size] for i in range(0, total_rows, chunk_size)]
        remaining_chunks = chunks[last_processed_chunk + 1:]
        
        logger.info(f"원본 데이터 총 {total_rows}개를 {len(chunks)}개 청크로 분할하여 처리합니다. (청크 크기: {chunk_size})")
        if last_processed_chunk >= 0:
            logger.info(f"체크포인트에서 재시작: {len(remaining_chunks)}개 청크 남음")
        
        api_key = Config.API_KEY
        
        # MedicalTextClassifier 인스턴스 생성
        classifier = MedicalTextClassifier(api_key)
        
        # 실패한 레코드를 저장할 데이터프레임
        failed_records = pd.DataFrame(columns=['index', 'column', 'text', 'error'])
        
        loop = asyncio.get_event_loop()
        
        # tqdm 진행바 추가
        from tqdm import tqdm
        
        for chunk_num, chunk_df in tqdm(enumerate(remaining_chunks, start=last_processed_chunk + 1), 
                                        total=len(remaining_chunks),
                                        desc="청크 처리 진행률"):
            logger.info(f"청크 {chunk_num+1}/{len(chunks)} 처리 시작 (레코드 {chunk_num*chunk_size+1}-{min((chunk_num+1)*chunk_size, total_rows)})")
            
            try:
                # 청크 처리
                processed_chunk = loop.run_until_complete(process_medical_data(chunk_df, api_key))
                
                # 전체 결과에 추가
                if all_processed_df.empty:
                    all_processed_df = processed_chunk
                else:
                    all_processed_df = pd.concat([all_processed_df, processed_chunk], ignore_index=False)
                
                # 실패한 레코드 확인 (처리된 결과가 없는 행)
                for column in processed_chunk.columns:
                    if column in classifier.classifiers.keys():
                        related_columns = [col for col in processed_chunk.columns if col.startswith(f"{column}_")]
                        
                        if related_columns:  # 파생 컬럼이 존재하는 경우
                            # NaN 값이 있는 행 = 처리 실패한 행
                            mask = processed_chunk[column].notna() & processed_chunk[column].str.strip().astype(bool)
                            has_data_mask = mask.copy()
                            
                            for related_col in related_columns:
                                has_data_mask = has_data_mask & processed_chunk[related_col].isna()
                            
                            failed_indices = processed_chunk[has_data_mask].index.tolist()
                            
                            for idx in failed_indices:
                                failed_records = pd.concat([failed_records, pd.DataFrame([{
                                    'index': idx,
                                    'column': column,
                                    'text': processed_chunk.loc[idx, column],
                                    'error': '처리 결과 없음'
                                }])], ignore_index=True)
                                logger.warning(f"레코드 처리 실패: 인덱스 {idx}, 컬럼 {column}, 텍스트: {processed_chunk.loc[idx, column][:100]}...")
                
                # 각 청크 처리 후 체크포인트 저장
                timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
                
                # 타입 충돌 해결을 위한 데이터프레임 사본 생성
                df_to_save = all_processed_df.copy()
                
                # 데이터 타입 문제 해결 - 모든 컬럼에 대해 안전한 변환 적용
                for col in df_to_save.columns:
                    if col.endswith('_pi_next_schedule'):
                        # 정수형 컬럼은 모두 문자열로 변환
                        df_to_save[col] = df_to_save[col].astype(str)
                    elif df_to_save[col].dtype == 'object':
                        # 객체 타입의 컬럼에서 None이나 nan 값 처리
                        df_to_save[col] = df_to_save[col].fillna('').astype(str)
                
                # 파일 저장
                temp_file = os.path.join(checkpoint_dir, f'temp_processed_data_{timestamp}.parquet')
                try:
                    df_to_save.to_parquet(temp_file)
                except Exception as e:
                    logger.warning(f"Parquet 저장 실패: {str(e)}. CSV 형식으로 저장합니다.")
                    csv_file = os.path.join(checkpoint_dir, f'temp_processed_data_{timestamp}.csv')
                    df_to_save.to_csv(csv_file, index=True, encoding='utf-8-sig')
                    temp_file = csv_file  # 체크포인트 파일 경로 업데이트
                
                checkpoint_data = {
                    'last_processed_chunk': chunk_num,
                    'processed_file': temp_file,
                    'timestamp': timestamp
                }
                
                with open(checkpoint_file, 'w') as f:
                    json.dump(checkpoint_data, f)
                
                logger.info(f"체크포인트 저장 완료: 청크 {chunk_num+1}/{len(chunks)}")
            
            except Exception as e:
                logger.error(f"청크 {chunk_num+1} 처리 중 오류 발생: {str(e)}")
                # 오류가 발생한 청크의 모든 행을 실패로 기록
                for idx, row in chunk_df.iterrows():
                    for column in row.index:
                        if column in classifier.classifiers.keys() and pd.notna(row[column]) and str(row[column]).strip():
                            failed_records = pd.concat([failed_records, pd.DataFrame([{
                                'index': idx,
                                'column': column,
                                'text': row[column],
                                'error': str(e)
                            }])], ignore_index=True)
                
                # 오류 발생 시 지금까지 처리된 데이터 저장
                if not all_processed_df.empty:
                    error_timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
                    
                    # 데이터 타입 문제 해결을 위한 복사본 생성
                    df_error_save = all_processed_df.copy()
                    
                    # 모든 컬럼을 문자열로 변환하여 타입 문제 해결
                    for col in df_error_save.columns:
                        df_error_save[col] = df_error_save[col].fillna('').astype(str)
                    
                    # 저장 시도 - Parquet 실패하면 CSV로 대체
                    try:
                        error_file = os.path.join(checkpoint_dir, f'processed_data_until_error_{error_timestamp}.parquet')
                        df_error_save.to_parquet(error_file)
                    except Exception as e:
                        logger.warning(f"오류 파일 Parquet 저장 실패: {str(e)}. CSV 형식으로 저장합니다.")
                        error_file = os.path.join(checkpoint_dir, f'processed_data_until_error_{error_timestamp}.csv')
                        df_error_save.to_csv(error_file, index=True, encoding='utf-8-sig')
                    
                    logger.info(f"오류 발생 시점까지 처리된 데이터 {len(all_processed_df)}개 행을 {error_file}에 저장했습니다.")
                
                # 오류 발생 시 실패 기록 저장
                if not failed_records.empty:
                    error_failed_file = os.path.join(checkpoint_dir, f'failed_records_until_error_{error_timestamp}.csv')
                    failed_records.to_csv(error_failed_file, index=False, encoding='utf-8-sig')
                    logger.info(f"오류 발생 시점까지 실패한 레코드 {len(failed_records)}개를 {error_failed_file}에 저장했습니다.")
                
                # 예외 재발생
                raise
        
        # 실패한 레코드 저장
        if not failed_records.empty:
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            failed_file = os.path.join(checkpoint_dir, f'failed_records_{timestamp}.csv')
            failed_records.to_csv(failed_file, index=False, encoding='utf-8-sig')
            logger.info(f"실패한 레코드 {len(failed_records)}개를 {failed_file}에 저장했습니다.")
        
        # 처리 결과에 대한 통계 로깅
        processed_columns = [col for col in all_processed_df.columns if col.split('_')[0] in classifier.classifiers.keys()]
        
        logger.info("=== 전체 처리 결과 ===")
        logger.info(f"총 레코드 수: {total_rows}")
        logger.info(f"처리된 컬럼: {processed_columns}")
        logger.info(f"실패한 레코드 수: {len(failed_records)}")
        
        # 데이터프레임 사본 생성
        final_df = all_processed_df.copy()
        
        # 타입 충돌 해결을 위한 열 타입 변환
        for col in final_df.columns:
            if col.endswith('_pi_next_schedule'):
                # 모든 _pi_next_schedule 컬럼은 문자열로 통일
                final_df[col] = final_df[col].fillna('').astype(str)
            elif final_df[col].dtype == 'object':
                # 다른 객체 타입의 열도 모두 문자열로 통일
                final_df[col] = final_df[col].fillna('').astype(str)
        
        # 최종 파일 저장 - Parquet 및 CSV 둘 다 저장
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        
        # Parquet 저장 시도
        try:
            output_file = f'processed_medical_data_{timestamp}.parquet'
            final_df.to_parquet(output_file)
            logger.info(f"처리된 데이터를 {output_file}에 저장했습니다.")
        except Exception as e:
            logger.error(f"Parquet 저장 실패: {str(e)}")
            
        # 백업용 CSV 저장 (필요 시)
        try:
            csv_output_file = f'processed_medical_data_{timestamp}.csv'
            final_df.to_csv(csv_output_file, index=True, encoding='utf-8-sig')
            logger.info(f"처리된 데이터를 CSV 백업 {csv_output_file}에 저장했습니다.")
        except Exception as e:
            logger.error(f"CSV 저장 실패: {str(e)}")
        
        # 처리가 모두 완료되면 체크포인트 파일 삭제
        if os.path.exists(checkpoint_file):
            os.remove(checkpoint_file)
            logger.info("체크포인트 파일 삭제 완료")
        
        # 임시 파일 삭제 (선택 사항 - 체크포인트 폴더의 이력을 유지하고 싶다면 이 부분은 주석 처리할 수 있습니다)
        for file in os.listdir(checkpoint_dir):
            if file.startswith('temp_processed_data_') and file.endswith('.parquet'):
                try:
                    os.remove(os.path.join(checkpoint_dir, file))
                except Exception as e:
                    logger.warning(f"임시 파일 {file} 삭제 실패: {str(e)}")
        
        logger.info("\n=== 세부 처리 결과 ===")
        for column in all_processed_df.columns:
            if '_' in column:  # 파생 컬럼만 표시
                valid_count = all_processed_df[column].notna().sum()
                logger.info(f"{column}: {valid_count} valid entries")
                if all_processed_df[column].dtype in ['object', 'category']:
                    value_counts = all_processed_df[column].value_counts()
                    logger.info(f"Value distribution:\n{value_counts}\n")
                    
    except Exception as e:
        logger.error(f"Main execution failed: {str(e)}")
        import traceback
        logger.error(traceback.format_exc())  # 상세 오류 정보 출력
        sys.exit(1)
    finally:
        # 전체 실행 시간 측정 종료 및 로깅
        total_end_time = datetime.now()
        total_duration = (total_end_time - total_start_time).total_seconds()
        hours, remainder = divmod(total_duration, 3600)
        minutes, seconds = divmod(remainder, 60)
        
        logger.info(f"전체 실행 시간: {int(hours)}시간 {int(minutes)}분 {seconds:.2f}초")
        if 'total_rows' in locals() and total_duration > 0:
            records_per_second = total_rows / total_duration
            logger.info(f"평균 처리 속도: {records_per_second:.2f}건/초")
        
        logger.info("Program execution completed")
       

if __name__ == "__main__":
    main()
# Out:
# 2025-03-09 16:54:01,519 - __main__ - INFO - 원본 데이터 총 20개를 1개 청크로 분할하여 처리합니다. (청크 크기: 2000)
# 청크 처리 진행률:   0%|          | 0/1 [00:00<?, ?it/s]2025-03-09 16:54:01,548 - __main__ - INFO - 청크 1/1 처리 시작 (레코드 1-20)
# 2025-03-09 16:54:01,562 - __main__ - INFO - Starting medical data processing at 2025-03-09 16:54:01.562771
# 2025-03-09 16:54:01,565 - __main__ - INFO - Processing column: CC
# 2025-03-09 16:54:01,572 - __main__ - INFO - Processing 20 valid records for column CC
# 2025-03-09 16:54:01,573 - __main__ - INFO - 단일 텍스트 처리 중 1/20 (인덱스 0)
# 2025-03-09 16:54:03,317 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:03,323 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "오른쪽 턱",
#         "pain_type": "통증",
#         "painUncomp_desc_jaw": "오른쪽 턱의 통증",
#         "disable_desc_jaw": "오른쪽 턱의 제한된 개구",
#         "muscle_joint_desc_stress": "스트레스로 인한 턱 근육의 긴장"
#     }
# ]...
# 2025-03-09 16:54:10,215 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:10,226 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "교정 치료, 보톡스, 물리치료 등",
#         "clinic_history_desc": "왼쪽통증과 입벌림이 힘들어서 서울대병원 30년 전 장치도 했었어요. 장치는 두고 왔어요 - 착용은 1년정도 하고 계속 괜찮다가 이번에 오른쪽 증상 생겼어요. 저번주 토요일 아침에 하품하다가 오른쪽 턱이 쥐난거처럼 경직되더니 현재 치아맞물림도 오른쪽이 어금니가 뜨고 오른쪽 턱이 잘 안벌어져요. 그 날 바로 일반치과 갔고 손으로 턱 넣고 했는데 맞춰지지않는다고 구강내과 가보라고해서 왔어요. 통증은 없어요. 소리는 왼쪽에 있었는데 장치치료 받고 사라져서 현재까지 없어요.",
#         "factor_habbit": "이악무는습관없어요. 이갈이 어렸을 때 만 잠은 잘자요. 스트레스 딱히 없어요(현재 위 남아있는 유치 살짝 흔들리고 있는데 잇몸치료받았고 다니는 치과 있어요.). 초음파ok",
#         "treat_plan...
# 2025-03-09 16:54:11,035 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:11,037 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": null,
#         "duration": "30년"
#     }
# ]...
# 2025-03-09 16:54:11,038 - __main__ - INFO - 텍스트 0 (인덱스 0) 처리 완료: {'location': '오른쪽 턱', 'pain_type': '통증', 'painUncomp_desc_jaw': '오른쪽 턱의 통증', 'disable_desc_jaw': '오른쪽 턱의 제한된 개구', 'muscle_joint_desc_stress': '스트레스로 인한 턱 근육의 긴장', 'dentalHistory_desc': '교정 치료, 보톡스, 물리치료 등', 'clinic_history_desc': '왼쪽통증과 입벌림이 힘들어서 서울대병원 30년 전 장치도 했었어요. 장치는 두고 왔어요 - 착용은 1년정도 하고 계속 괜찮다가 이번에 오른쪽 증상 생겼어요. 저번주 토요일 아침에 하품하다가 오른쪽 턱이 쥐난거처럼 경직되더니 현재 치아맞물림도 오른쪽이 어금니가 뜨고 오른쪽 턱이 잘 안벌어져요. 그 날 바로 일반치과 갔고 손으로 턱 넣고 했는데 맞춰지지않는다고 구강내과 가보라고해서 왔어요. 통증은 없어요. 소리는 왼쪽에 있었는데 장치치료 받고 사라져서 현재까지 없어요.', 'factor_habbit': '이악무는습관없어요. 이갈이 어렸을 때 만 잠은 잘자요. 스트레스 딱히 없어요(현재 위 남아있는 유치 살짝 흔들리고 있는데 잇몸치료받았고 다니는 치과 있어요.). 초음파ok', 'treat_plan': '물리치료, 약물요법, 장치치료, 보톡스 주사 등', 'severity': None, 'vas': None, 'duration': '30년'}
# 2025-03-09 16:54:11,039 - __main__ - INFO - 단일 텍스트 처리 중 2/20 (인덱스 1)
# 2025-03-09 16:54:12,466 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:12,470 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "오른쪽 턱",
#         "pain_type": "불편감",
#         "painUncomp_desc_jaw": "턱이 불편했음",
#         "disable_desc_jaw": "턱벌어지는 것이 비슷함",
#         "muscle_joint_desc_stress": "스트레스로 인한 턱 근육 긴장"
#     }
# ]...
# 2025-03-09 16:54:14,046 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:14,049 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "교정 치료, 보톡스, 물리치료",
#         "clinic_history_desc": "턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기",
#         "factor_habbit": "음식 섭취 습관, 수면 자세, 이 악물기 등",
#         "treat_plan": "물리치료, APS del증상"
#     }
# ]...
# 2025-03-09 16:54:14,791 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:14,794 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": 2,
#         "duration": null
#     }
# ]...
# 2025-03-09 16:54:14,794 - __main__ - INFO - 텍스트 0 (인덱스 1) 처리 완료: {'location': '오른쪽 턱', 'pain_type': '불편감', 'painUncomp_desc_jaw': '턱이 불편했음', 'disable_desc_jaw': '턱벌어지는 것이 비슷함', 'muscle_joint_desc_stress': '스트레스로 인한 턱 근육 긴장', 'dentalHistory_desc': '교정 치료, 보톡스, 물리치료', 'clinic_history_desc': '턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기', 'factor_habbit': '음식 섭취 습관, 수면 자세, 이 악물기 등', 'treat_plan': '물리치료, APS del증상', 'severity': None, 'vas': 2, 'duration': None}
# 2025-03-09 16:54:14,795 - __main__ - INFO - 단일 텍스트 처리 중 3/20 (인덱스 2)
# 2025-03-09 16:54:17,015 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:17,024 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "유치 안쪽 잇몸",
#         "pain_type": "통증",
#         "painUncomp_desc_jaw": "턱 통증",
#         "disable_desc_jaw": "턱 관절의 비정상적인 움직임",
#         "muscle_joint_desc_stress": "스트레스로 인한 턱 근육의 긴장"
#     }
# ]...
# 2025-03-09 16:54:18,506 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:18,510 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "물리치료",
#         "clinic_history_desc": "턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기",
#         "factor_habbit": "음식 섭취 습관, 수면 자세, 이 악물기 등",
#         "treat_plan": "물리치료, 장치치료"
#     }
# ]...
# 2025-03-09 16:54:19,329 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:19,333 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": 3,
#         "duration": "3일"
#     }
# ]...
# 2025-03-09 16:54:19,334 - __main__ - INFO - 텍스트 0 (인덱스 2) 처리 완료: {'location': '유치 안쪽 잇몸', 'pain_type': '통증', 'painUncomp_desc_jaw': '턱 통증', 'disable_desc_jaw': '턱 관절의 비정상적인 움직임', 'muscle_joint_desc_stress': '스트레스로 인한 턱 근육의 긴장', 'dentalHistory_desc': '물리치료', 'clinic_history_desc': '턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기', 'factor_habbit': '음식 섭취 습관, 수면 자세, 이 악물기 등', 'treat_plan': '물리치료, 장치치료', 'severity': None, 'vas': 3, 'duration': '3일'}
# 2025-03-09 16:54:19,335 - __main__ - INFO - 단일 텍스트 처리 중 4/20 (인덱스 3)
# 2025-03-09 16:54:22,340 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:22,344 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "오른쪽 아랫턱",
#         "pain_type": "통증",
#         "painUncomp_desc_jaw": "조금 아플때도 있고 불편할때도 있는",
#         "disable_desc_jaw": "뻐쩍찌근한 느낌",
#         "muscle_joint_desc_stress": "스트레스로 인한 긴장"
#     },
#     {
#         "location": "오른쪽 위 잇몸, 왼쪽 아래",
#         "pain_type": "불편감",
#         "painUncomp_desc_jaw": "울퉁불퉁한 느낌",
#         "disable_desc_jaw": "치실할때 걸려서 안빠진적도 있음",
#         "muscle_joint_desc_stress": "스트레스로 인한 긴장"
#     }
# ]...
# 2025-03-09 16:54:24,050 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:24,055 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "교정 치료, 보톡스, 물리치료",
#         "clinic_history_desc": "턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기",
#         "factor_habbit": "음식 섭취 습관, 수면 자세, 이 악물기",
#         "treat_plan": "물리치료, 약물요법, 장치치료, 보톡스 주사"
#     }
# ]...
# 2025-03-09 16:54:24,785 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:24,789 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": 4,
#         "vas": 3,
#         "duration": null
#     }
# ]...
# 2025-03-09 16:54:24,790 - __main__ - INFO - 텍스트 0 (인덱스 3) 처리 완료: {'location': '오른쪽 아랫턱', 'pain_type': '통증', 'painUncomp_desc_jaw': '조금 아플때도 있고 불편할때도 있는', 'disable_desc_jaw': '뻐쩍찌근한 느낌', 'muscle_joint_desc_stress': '스트레스로 인한 긴장', 'dentalHistory_desc': '교정 치료, 보톡스, 물리치료', 'clinic_history_desc': '턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기', 'factor_habbit': '음식 섭취 습관, 수면 자세, 이 악물기', 'treat_plan': '물리치료, 약물요법, 장치치료, 보톡스 주사', 'severity': 4, 'vas': 3, 'duration': None}
# 2025-03-09 16:54:24,791 - __main__ - INFO - 단일 텍스트 처리 중 5/20 (인덱스 4)
# 2025-03-09 16:54:26,020 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:26,087 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "오른쪽 턱",
#         "pain_type": "통증",
#         "painUncomp_desc_jaw": "턱의 통증",
#         "disable_desc_jaw": "턱 관절의 제한된 개구",
#         "muscle_joint_desc_stress": "스트레스로 인한 턱 근육의 긴장"
#     }
# ]...
# 2025-03-09 16:54:28,443 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:28,447 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "레진치료",
#         "clinic_history_desc": "통증있었어요, 지금은 괜찮아요, 오른쪽으로 씹으면 오른쪽 아파요, 통증크기 비슷해요, 30년된 장치 가지고 오라고 하셔서 가져왔어요, 치아끼리 안닿게 노력헀어요",
#         "factor_habbit": "",
#         "treat_plan": "물리치료, 장치치료"
#     }
# ]...
# 2025-03-09 16:54:29,258 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:29,262 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": 5,
#         "vas": null,
#         "duration": null
#     }
# ]...
# 2025-03-09 16:54:29,264 - __main__ - INFO - 텍스트 0 (인덱스 4) 처리 완료: {'location': '오른쪽 턱', 'pain_type': '통증', 'painUncomp_desc_jaw': '턱의 통증', 'disable_desc_jaw': '턱 관절의 제한된 개구', 'muscle_joint_desc_stress': '스트레스로 인한 턱 근육의 긴장', 'dentalHistory_desc': '레진치료', 'clinic_history_desc': '통증있었어요, 지금은 괜찮아요, 오른쪽으로 씹으면 오른쪽 아파요, 통증크기 비슷해요, 30년된 장치 가지고 오라고 하셔서 가져왔어요, 치아끼리 안닿게 노력헀어요', 'factor_habbit': '', 'treat_plan': '물리치료, 장치치료', 'severity': 5, 'vas': None, 'duration': None}
# 2025-03-09 16:54:29,265 - __main__ - INFO - 단일 텍스트 처리 중 6/20 (인덱스 5)
# 2025-03-09 16:54:31,161 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:31,171 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "오른쪽 턱",
#         "pain_type": "통증",
#         "painUncomp_desc_jaw": "턱 통증",
#         "disable_desc_jaw": "턱 관절의 비정상적인 움직임",
#         "muscle_joint_desc_stress": "스트레스로 인한 턱 근육의 긴장"
#     }
# ]...
# 2025-03-09 16:54:32,618 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:32,623 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "물리치료",
#         "clinic_history_desc": "통증 증상",
#         "factor_habbit": "씹을때 오른쪽 통증",
#         "treat_plan": "임플란트"
#     }
# ]...
# 2025-03-09 16:54:33,562 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:33,566 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": 6,
#         "duration": null
#     }
# ]...
# 2025-03-09 16:54:33,567 - __main__ - INFO - 텍스트 0 (인덱스 5) 처리 완료: {'location': '오른쪽 턱', 'pain_type': '통증', 'painUncomp_desc_jaw': '턱 통증', 'disable_desc_jaw': '턱 관절의 비정상적인 움직임', 'muscle_joint_desc_stress': '스트레스로 인한 턱 근육의 긴장', 'dentalHistory_desc': '물리치료', 'clinic_history_desc': '통증 증상', 'factor_habbit': '씹을때 오른쪽 통증', 'treat_plan': '임플란트', 'severity': None, 'vas': 6, 'duration': None}
# 2025-03-09 16:54:33,568 - __main__ - INFO - 단일 텍스트 처리 중 7/20 (인덱스 6)
# 2025-03-09 16:54:35,713 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:35,718 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "왼쪽 아래 끝에서 2번째쯤",
#         "pain_type": "아픔",
#         "painUncomp_desc_jaw": "턱 통증",
#         "disable_desc_jaw": "잘 안맞물리는 것만 있음",
#         "muscle_joint_desc_stress": "왼쪽 턱이 좀 아픔"
#     }
# ]...
# 2025-03-09 16:54:37,069 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:37,073 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "물리치료",
#         "clinic_history_desc": "턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기",
#         "factor_habbit": "턱 통증, 치아 통증",
#         "treat_plan": "물리치료, 장치치료"
#     }
# ]...
# 2025-03-09 16:54:37,964 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:37,971 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": null,
#         "duration": null
#     }
# ]...
# 2025-03-09 16:54:37,972 - __main__ - INFO - 텍스트 0 (인덱스 6) 처리 완료: {'location': '왼쪽 아래 끝에서 2번째쯤', 'pain_type': '아픔', 'painUncomp_desc_jaw': '턱 통증', 'disable_desc_jaw': '잘 안맞물리는 것만 있음', 'muscle_joint_desc_stress': '왼쪽 턱이 좀 아픔', 'dentalHistory_desc': '물리치료', 'clinic_history_desc': '턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기', 'factor_habbit': '턱 통증, 치아 통증', 'treat_plan': '물리치료, 장치치료', 'severity': None, 'vas': None, 'duration': None}
# 2025-03-09 16:54:37,973 - __main__ - INFO - 단일 텍스트 처리 중 8/20 (인덱스 7)
# 2025-03-09 16:54:39,606 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:39,617 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "턱",
#         "pain_type": "끼익거리는 소리",
#         "painUncomp_desc_jaw": "턱통증이나 불편감은 없어요",
#         "disable_desc_jaw": null,
#         "muscle_joint_desc_stress": "스트레스로 인한 턱 근육의 긴장"
#     }
# ]...
# 2025-03-09 16:54:40,937 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:40,941 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "물리치료",
#         "clinic_history_desc": "턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기",
#         "factor_habbit": "음식 섭취 습관, 수면 자세, 이 악물기",
#         "treat_plan": "물리치료, 장치치료"
#     }
# ]...
# 2025-03-09 16:54:41,757 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:41,760 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": null,
#         "duration": "10일"
#     }
# ]...
# 2025-03-09 16:54:41,761 - __main__ - INFO - 텍스트 0 (인덱스 7) 처리 완료: {'location': '턱', 'pain_type': '끼익거리는 소리', 'painUncomp_desc_jaw': '턱통증이나 불편감은 없어요', 'disable_desc_jaw': None, 'muscle_joint_desc_stress': '스트레스로 인한 턱 근육의 긴장', 'dentalHistory_desc': '물리치료', 'clinic_history_desc': '턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기', 'factor_habbit': '음식 섭취 습관, 수면 자세, 이 악물기', 'treat_plan': '물리치료, 장치치료', 'severity': None, 'vas': None, 'duration': '10일'}
# 2025-03-09 16:54:41,763 - __main__ - INFO - 단일 텍스트 처리 중 9/20 (인덱스 8)
# 2025-03-09 16:54:43,594 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:43,598 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "오른쪽 어금니",
#         "pain_type": "안닿는 느낌",
#         "painUncomp_desc_jaw": "턱 통증/불편감",
#         "disable_desc_jaw": "턱 관절의 비정상적인 움직임",
#         "muscle_joint_desc_stress": "스트레스로 인한 턱 근육의 긴장"
#     }
# ]...
# 2025-03-09 16:54:45,130 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:45,138 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "물리치료",
#         "clinic_history_desc": "턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기",
#         "factor_habbit": "음식 섭취 습관, 수면 자세, 이 악물기 등",
#         "treat_plan": "물리치료, 마사지, 스트레칭"
#     }
# ]...
# 2025-03-09 16:54:45,954 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:45,958 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": 10,
#         "duration": null
#     }
# ]...
# 2025-03-09 16:54:45,959 - __main__ - INFO - 텍스트 0 (인덱스 8) 처리 완료: {'location': '오른쪽 어금니', 'pain_type': '안닿는 느낌', 'painUncomp_desc_jaw': '턱 통증/불편감', 'disable_desc_jaw': '턱 관절의 비정상적인 움직임', 'muscle_joint_desc_stress': '스트레스로 인한 턱 근육의 긴장', 'dentalHistory_desc': '물리치료', 'clinic_history_desc': '턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기', 'factor_habbit': '음식 섭취 습관, 수면 자세, 이 악물기 등', 'treat_plan': '물리치료, 마사지, 스트레칭', 'severity': None, 'vas': 10, 'duration': None}
# 2025-03-09 16:54:45,960 - __main__ - INFO - 단일 텍스트 처리 중 10/20 (인덱스 9)
# 2025-03-09 16:54:47,598 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:47,602 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "오른쪽으로 씹으면 왼쪽에서 치아끼리 미끄러지면서 부딪히는 소리",
#         "pain_type": "소리",
#         "painUncomp_desc_jaw": "턱 통증",
#         "disable_desc_jaw": "치아끼리 안닿게 턱에 힘풀려고 멍때림",
#         "muscle_joint_desc_stress": "스트레스로 인한 턱 근육의 긴장"
#     }
# ]...
# 2025-03-09 16:54:51,180 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:51,185 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "물리치료",
#         "clinic_history_desc": "장치 ck구강내과#11 수빈증상: 8월 부터 오른쪽으로 씹으면 왼쪽에서 치아끼리 미끄러지면서 부딪히는 소리가 나요 그래서 왼쪽으로 씹게 되는거 같아요 오른쪽도 꼭꼭 씹어지는 거 같지 않아요 8월전에는 증상이 좋아지는게 느껴졌는데 이후에는 안느껴져요 이 외에는 불편감 없어요 불편감 없어요 장치 낀날 안낀날 아침에 똑같아요 치아끼리 안닿게 턱에 힘풀려고 멍때렸어요",
#         "factor_habbit": "환자의 음식 섭취 습관, 수면 자세, 이 악물기 등",
#         "treat_plan": "장치치료"
#     }
# ]...
# 2025-03-09 16:54:51,888 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:51,892 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": 8,
#         "duration": null
#     }
# ]...
# 2025-03-09 16:54:51,893 - __main__ - INFO - 텍스트 0 (인덱스 9) 처리 완료: {'location': '오른쪽으로 씹으면 왼쪽에서 치아끼리 미끄러지면서 부딪히는 소리', 'pain_type': '소리', 'painUncomp_desc_jaw': '턱 통증', 'disable_desc_jaw': '치아끼리 안닿게 턱에 힘풀려고 멍때림', 'muscle_joint_desc_stress': '스트레스로 인한 턱 근육의 긴장', 'dentalHistory_desc': '물리치료', 'clinic_history_desc': '장치 ck구강내과#11 수빈증상: 8월 부터 오른쪽으로 씹으면 왼쪽에서 치아끼리 미끄러지면서 부딪히는 소리가 나요 그래서 왼쪽으로 씹게 되는거 같아요 오른쪽도 꼭꼭 씹어지는 거 같지 않아요 8월전에는 증상이 좋아지는게 느껴졌는데 이후에는 안느껴져요 이 외에는 불편감 없어요 불편감 없어요 장치 낀날 안낀날 아침에 똑같아요 치아끼리 안닿게 턱에 힘풀려고 멍때렸어요', 'factor_habbit': '환자의 음식 섭취 습관, 수면 자세, 이 악물기 등', 'treat_plan': '장치치료', 'severity': None, 'vas': 8, 'duration': None}
# 2025-03-09 16:54:51,952 - __main__ - INFO - Checkpoint saved for column CC
# 2025-03-09 16:54:51,952 - __main__ - INFO - 단일 텍스트 처리 중 11/20 (인덱스 10)
# 2025-03-09 16:54:53,222 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:53,227 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "아래 어금니",
#         "pain_type": "시림",
#         "painUncomp_desc_jaw": "",
#         "disable_desc_jaw": "",
#         "muscle_joint_desc_stress": ""
#     }
# ]...
# 2025-03-09 16:54:54,316 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:54,320 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "임플란트 정기체크",
#         "clinic_history_desc": "어금니 통증, 시려움",
#         "factor_habbit": "음식 섭취 시 시려움",
#         "treat_plan": "약물요법"
#     }
# ]...
# 2025-03-09 16:54:55,065 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:55,069 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": null,
#         "duration": null
#     }
# ]...
# 2025-03-09 16:54:55,070 - __main__ - INFO - 텍스트 0 (인덱스 10) 처리 완료: {'location': '아래 어금니', 'pain_type': '시림', 'painUncomp_desc_jaw': '', 'disable_desc_jaw': '', 'muscle_joint_desc_stress': '', 'dentalHistory_desc': '임플란트 정기체크', 'clinic_history_desc': '어금니 통증, 시려움', 'factor_habbit': '음식 섭취 시 시려움', 'treat_plan': '약물요법', 'severity': None, 'vas': None, 'duration': None}
# 2025-03-09 16:54:55,071 - __main__ - INFO - 단일 텍스트 처리 중 12/20 (인덱스 11)
# 2025-03-09 16:54:56,550 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:56,558 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "아래 장치 낀 이후로 왼쪽 치아끼리",
#         "pain_type": "통증",
#         "painUncomp_desc_jaw": "왼쪽 아래 어금니(#36) 통증",
#         "disable_desc_jaw": "오른쪽 턱이 가끔 딱딱해지는 느낌",
#         "muscle_joint_desc_stress": "스트레스로 인한 턱 근육의 긴장"
#     }
# ]...
# 2025-03-09 16:54:58,542 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:58,548 - __main__ - INFO - 원시 API 응답: ```json
# [{
#     "dentalHistory_desc": "환자의 교정 치료, 보톡스, 물리치료 등",
#     "clinic_history_desc": "환자의 턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기 등",
#     "factor_habbit": "환자의 음식 섭취 습관, 수면 자세, 이 악물기 등",
#     "treat_plan": "물리치료, 약물요법, 장치치료, 보톡스 주사 등"
# }]
# ```...
# 2025-03-09 16:54:58,550 - __main__ - INFO - JSON 파싱 성공: [{'dentalHistory_desc': '환자의 교정 치료, 보톡스, 물리치료 등', 'clinic_history_desc': '환자의 턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기 등', 'factor_habbit': '환자의 음식 섭취 습관, 수면 자세, 이 악물기 등', 'treat_plan': '물리치료, 약물요법, 장치치료, 보톡스 주사 등'}]
# 2025-03-09 16:54:59,670 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:54:59,673 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": null,
#         "duration": "2주"
#     }
# ]...
# 2025-03-09 16:54:59,674 - __main__ - INFO - 텍스트 0 (인덱스 11) 처리 완료: {'location': '아래 장치 낀 이후로 왼쪽 치아끼리', 'pain_type': '통증', 'painUncomp_desc_jaw': '왼쪽 아래 어금니(#36) 통증', 'disable_desc_jaw': '오른쪽 턱이 가끔 딱딱해지는 느낌', 'muscle_joint_desc_stress': '스트레스로 인한 턱 근육의 긴장', 'dentalHistory_desc': '환자의 교정 치료, 보톡스, 물리치료 등', 'clinic_history_desc': '환자의 턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기 등', 'factor_habbit': '환자의 음식 섭취 습관, 수면 자세, 이 악물기 등', 'treat_plan': '물리치료, 약물요법, 장치치료, 보톡스 주사 등', 'severity': None, 'vas': None, 'duration': '2주'}
# 2025-03-09 16:54:59,675 - __main__ - INFO - 단일 텍스트 처리 중 13/20 (인덱스 12)
# 2025-03-09 16:55:01,288 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:01,302 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "턱 관절",
#         "pain_type": "통증",
#         "painUncomp_desc_jaw": "통증, 뻐근함 없음",
#         "disable_desc_jaw": "소리 없음, 제한된 개구 없음",
#         "muscle_joint_desc_stress": "스트레스로 인한 턱 근육 긴장"
#     }
# ]...
# 2025-03-09 16:55:03,771 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:03,779 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "이갈이는 가끔 있다고 들었어요",
#         "clinic_history_desc": "턱관절 관련해서 통증, 뻐근함 없고 소리도 과거현재없어요",
#         "factor_habbit": "이악무는습관은 없어요",
#         "treat_plan": ""
#     },
#     {
#         "dentalHistory_desc": "환자의 충치치료",
#         "clinic_history_desc": "왼쪽 아래 어금니 치아깨짐",
#         "factor_habbit": "잠은 잘자는 편인데 숨이 안쉬어지는게 느껴질 때 중간에 깨긴해요",
#         "treat_plan": "내과 진료 후 진행 설명드림 초음파 OK"
#     }
# ]...
# 2025-03-09 16:55:04,670 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:04,675 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": null,
#         "duration": null
#     },
#     {
#         "severity": null,
#         "vas": null,
#         "duration": null
#     }
# ]...
# 2025-03-09 16:55:04,676 - __main__ - INFO - 텍스트 0 (인덱스 12) 처리 완료: {'location': '턱 관절', 'pain_type': '통증', 'painUncomp_desc_jaw': '통증, 뻐근함 없음', 'disable_desc_jaw': '소리 없음, 제한된 개구 없음', 'muscle_joint_desc_stress': '스트레스로 인한 턱 근육 긴장', 'dentalHistory_desc': '이갈이는 가끔 있다고 들었어요', 'clinic_history_desc': '턱관절 관련해서 통증, 뻐근함 없고 소리도 과거현재없어요', 'factor_habbit': '이악무는습관은 없어요', 'treat_plan': '', 'severity': None, 'vas': None, 'duration': None}
# 2025-03-09 16:55:04,676 - __main__ - INFO - 단일 텍스트 처리 중 14/20 (인덱스 13)
# 2025-03-09 16:55:05,867 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:05,879 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "턱",
#         "pain_type": "시리는 통증",
#         "painUncomp_desc_jaw": "양치할때 시리긴 통증",
#         "disable_desc_jaw": "",
#         "muscle_joint_desc_stress": ""
#     }
# ]...
# 2025-03-09 16:55:07,255 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:07,258 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "양치할때 시리긴했어요",
#         "clinic_history_desc": "불편한건없고 검진 보러왔어요",
#         "factor_habbit": "정기ck",
#         "treat_plan": ""
#     }
# ]...
# 2025-03-09 16:55:08,026 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:08,030 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": null,
#         "duration": null
#     }
# ]...
# 2025-03-09 16:55:08,032 - __main__ - INFO - 텍스트 0 (인덱스 13) 처리 완료: {'location': '턱', 'pain_type': '시리는 통증', 'painUncomp_desc_jaw': '양치할때 시리긴 통증', 'disable_desc_jaw': '', 'muscle_joint_desc_stress': '', 'dentalHistory_desc': '양치할때 시리긴했어요', 'clinic_history_desc': '불편한건없고 검진 보러왔어요', 'factor_habbit': '정기ck', 'treat_plan': '', 'severity': None, 'vas': None, 'duration': None}
# 2025-03-09 16:55:08,033 - __main__ - INFO - 단일 텍스트 처리 중 15/20 (인덱스 14)
# 2025-03-09 16:55:09,645 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:09,649 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "아래 치아",
#         "pain_type": "시림",
#         "painUncomp_desc_jaw": "턱 통증",
#         "disable_desc_jaw": "제한된 개구",
#         "muscle_joint_desc_stress": "스트레스로 인한 턱 근육 긴장"
#     }
# ]...
# 2025-03-09 16:55:11,037 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:11,049 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "양치할때 양쪽 아래 치료한곳이 시려요. 찬거 뜨거운거에는 괜찮구요.",
#         "clinic_history_desc": "#46 타원에서 치료 /#36 본원에서 치료",
#         "factor_habbit": "",
#         "treat_plan": ""
#     }
# ]...
# 2025-03-09 16:55:12,163 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:12,168 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": null,
#         "duration": null
#     }
# ]...
# 2025-03-09 16:55:12,169 - __main__ - INFO - 텍스트 0 (인덱스 14) 처리 완료: {'location': '아래 치아', 'pain_type': '시림', 'painUncomp_desc_jaw': '턱 통증', 'disable_desc_jaw': '제한된 개구', 'muscle_joint_desc_stress': '스트레스로 인한 턱 근육 긴장', 'dentalHistory_desc': '양치할때 양쪽 아래 치료한곳이 시려요. 찬거 뜨거운거에는 괜찮구요.', 'clinic_history_desc': '#46 타원에서 치료 /#36 본원에서 치료', 'factor_habbit': '', 'treat_plan': '', 'severity': None, 'vas': None, 'duration': None}
# 2025-03-09 16:55:12,169 - __main__ - INFO - 단일 텍스트 처리 중 16/20 (인덱스 15)
# 2025-03-09 16:55:13,805 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:13,810 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "턱관절",
#         "pain_type": "통증",
#         "painUncomp_desc_jaw": "턱 관절의 통증",
#         "disable_desc_jaw": "턱 관절의 제한된 개구",
#         "muscle_joint_desc_stress": "스트레스로 인한 턱 근육의 긴장"
#     }
# ]...
# 2025-03-09 16:55:15,761 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:15,768 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "보톡스 미용목적으로 한달 전 턱에만 맞았어요",
#         "clinic_history_desc": "턱관절진료 처음이고, 보톡스 미용목적으로 한달 전 턱에만 맞았어요",
#         "factor_habbit": "이악무는습관 있는거 같아요, 이갈이 없어요, 잠은 잘자요 : 6~7시간, 스트레스 항상 많은 편이에요 : 일 적으로 초음파ok",
#         "treat_plan": ""
#     }
# ]...
# 2025-03-09 16:55:16,479 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:16,483 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": 4,
#         "duration": "5일"
#     }
# ]...
# 2025-03-09 16:55:16,484 - __main__ - INFO - 텍스트 0 (인덱스 15) 처리 완료: {'location': '턱관절', 'pain_type': '통증', 'painUncomp_desc_jaw': '턱 관절의 통증', 'disable_desc_jaw': '턱 관절의 제한된 개구', 'muscle_joint_desc_stress': '스트레스로 인한 턱 근육의 긴장', 'dentalHistory_desc': '보톡스 미용목적으로 한달 전 턱에만 맞았어요', 'clinic_history_desc': '턱관절진료 처음이고, 보톡스 미용목적으로 한달 전 턱에만 맞았어요', 'factor_habbit': '이악무는습관 있는거 같아요, 이갈이 없어요, 잠은 잘자요 : 6~7시간, 스트레스 항상 많은 편이에요 : 일 적으로 초음파ok', 'treat_plan': '', 'severity': None, 'vas': 4, 'duration': '5일'}
# 2025-03-09 16:55:16,489 - __main__ - INFO - 단일 텍스트 처리 중 17/20 (인덱스 16)
# 2025-03-09 16:55:18,208 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:18,211 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "턱",
#         "pain_type": "통증",
#         "painUncomp_desc_jaw": "통증 없어졌어요",
#         "disable_desc_jaw": "다른 불편한거 없어요",
#         "muscle_joint_desc_stress": "딱딱하고질긴거 피하려하고 치아끼리 안닿게 노력했어요"
#     }
# ]...
# 2025-03-09 16:55:19,740 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:19,741 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "물리치료",
#         "clinic_history_desc": "통증 없어졌어요",
#         "factor_habbit": "딱딱하고질긴거 피하려하고 치아끼리 안닿게 노력했어요",
#         "treat_plan": "약 : 10일분정도는 남았어요"
#     }
# ]...
# 2025-03-09 16:55:20,670 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:20,678 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": null,
#         "duration": "10일"
#     }
# ]...
# 2025-03-09 16:55:20,679 - __main__ - INFO - 텍스트 0 (인덱스 16) 처리 완료: {'location': '턱', 'pain_type': '통증', 'painUncomp_desc_jaw': '통증 없어졌어요', 'disable_desc_jaw': '다른 불편한거 없어요', 'muscle_joint_desc_stress': '딱딱하고질긴거 피하려하고 치아끼리 안닿게 노력했어요', 'dentalHistory_desc': '물리치료', 'clinic_history_desc': '통증 없어졌어요', 'factor_habbit': '딱딱하고질긴거 피하려하고 치아끼리 안닿게 노력했어요', 'treat_plan': '약 : 10일분정도는 남았어요', 'severity': None, 'vas': None, 'duration': '10일'}
# 2025-03-09 16:55:20,679 - __main__ - INFO - 단일 텍스트 처리 중 18/20 (인덱스 17)
# 2025-03-09 16:55:22,098 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:22,102 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "왼쪽 턱관절",
#         "pain_type": "통증",
#         "painUncomp_desc_jaw": "통증 심함",
#         "disable_desc_jaw": "입벌릴 때 소리와 통증",
#         "muscle_joint_desc_stress": "스트레스로 인한 턱 근육의 긴장"
#     }
# ]...
# 2025-03-09 16:55:24,049 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:24,053 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "교정 치료, 보톡스, 물리치료",
#         "clinic_history_desc": "턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기",
#         "factor_habbit": "음식 섭취 습관, 수면 자세, 이 악물기",
#         "treat_plan": "물리치료, 보톡스 주사"
#     }
# ]...
# 2025-03-09 16:55:24,892 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:24,896 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": 3,
#         "duration": "한달"
#     }
# ]...
# 2025-03-09 16:55:24,897 - __main__ - INFO - 텍스트 0 (인덱스 17) 처리 완료: {'location': '왼쪽 턱관절', 'pain_type': '통증', 'painUncomp_desc_jaw': '통증 심함', 'disable_desc_jaw': '입벌릴 때 소리와 통증', 'muscle_joint_desc_stress': '스트레스로 인한 턱 근육의 긴장', 'dentalHistory_desc': '교정 치료, 보톡스, 물리치료', 'clinic_history_desc': '턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기', 'factor_habbit': '음식 섭취 습관, 수면 자세, 이 악물기', 'treat_plan': '물리치료, 보톡스 주사', 'severity': None, 'vas': 3, 'duration': '한달'}
# 2025-03-09 16:55:24,899 - __main__ - INFO - 단일 텍스트 처리 중 19/20 (인덱스 18)
# 2025-03-09 16:55:31,043 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:31,049 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "왼쪽",
#         "pain_type": "통증",
#         "painUncomp_desc_jaw": "턱 통증",
#         "disable_desc_jaw": "딱소리",
#         "muscle_joint_desc_stress": "스트레스로 인한 턱 근육의 긴장"
#     }
# ]...
# 2025-03-09 16:55:32,541 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:32,544 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "물리치료",
#         "clinic_history_desc": "통증 증상: 왼쪽씹을때 통증이 더심해졌어요 VAS 3->VAS 6, 왼쪽벌릴때 딱소리가나요 입벌리지 않으면 통증은 없어요",
#         "factor_habbit": "",
#         "treat_plan": ""
#     }
# ]...
# 2025-03-09 16:55:33,258 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:33,262 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": 6,
#         "duration": null
#     }
# ]...
# 2025-03-09 16:55:33,263 - __main__ - INFO - 텍스트 0 (인덱스 18) 처리 완료: {'location': '왼쪽', 'pain_type': '통증', 'painUncomp_desc_jaw': '턱 통증', 'disable_desc_jaw': '딱소리', 'muscle_joint_desc_stress': '스트레스로 인한 턱 근육의 긴장', 'dentalHistory_desc': '물리치료', 'clinic_history_desc': '통증 증상: 왼쪽씹을때 통증이 더심해졌어요 VAS 3->VAS 6, 왼쪽벌릴때 딱소리가나요 입벌리지 않으면 통증은 없어요', 'factor_habbit': '', 'treat_plan': '', 'severity': None, 'vas': 6, 'duration': None}
# 2025-03-09 16:55:33,264 - __main__ - INFO - 단일 텍스트 처리 중 20/20 (인덱스 19)
# 2025-03-09 16:55:34,211 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:34,225 - __main__ - INFO - 원시 API 응답: [
#     {
#         "location": "왼쪽",
#         "pain_type": "불편감",
#         "painUncomp_desc_jaw": "턱 통증/불편감",
#         "disable_desc_jaw": "",
#         "muscle_joint_desc_stress": ""
#     }
# ]...
# 2025-03-09 16:55:35,782 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:35,790 - __main__ - INFO - 원시 API 응답: [
#     {
#         "dentalHistory_desc": "물리치료",
#         "clinic_history_desc": "통증은 아닌데 불편감정도만 거슬리게 남아있어요",
#         "factor_habbit": "음식 섭취 습관, 수면 자세, 이 악물기 등",
#         "treat_plan": "물리치료"
#     }
# ]...
# 2025-03-09 16:55:36,534 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:36,537 - __main__ - INFO - 원시 API 응답: [
#     {
#         "severity": null,
#         "vas": null,
#         "duration": null
#     }
# ]...
# 2025-03-09 16:55:36,538 - __main__ - INFO - 텍스트 0 (인덱스 19) 처리 완료: {'location': '왼쪽', 'pain_type': '불편감', 'painUncomp_desc_jaw': '턱 통증/불편감', 'disable_desc_jaw': '', 'muscle_joint_desc_stress': '', 'dentalHistory_desc': '물리치료', 'clinic_history_desc': '통증은 아닌데 불편감정도만 거슬리게 남아있어요', 'factor_habbit': '음식 섭취 습관, 수면 자세, 이 악물기 등', 'treat_plan': '물리치료', 'severity': None, 'vas': None, 'duration': None}
# 2025-03-09 16:55:36,551 - __main__ - INFO - Checkpoint saved for column CC
# 2025-03-09 16:55:36,557 - __main__ - INFO - Checkpoint saved for column CC
# 2025-03-09 16:55:36,565 - __main__ - INFO - Column CC generated 12 derived columns: ['CC_location', 'CC_pain_type', 'CC_painUncomp_desc_jaw', 'CC_disable_desc_jaw', 'CC_muscle_joint_desc_stress', 'CC_dentalHistory_desc', 'CC_clinic_history_desc', 'CC_factor_habbit', 'CC_treat_plan', 'CC_severity', 'CC_vas', 'CC_duration']
# 2025-03-09 16:55:36,566 - __main__ - INFO - Column CC_location has 20 non-empty values
# 2025-03-09 16:55:36,567 - __main__ - INFO - Column CC_pain_type has 20 non-empty values
# 2025-03-09 16:55:36,567 - __main__ - INFO - Column CC_painUncomp_desc_jaw has 20 non-empty values
# 2025-03-09 16:55:36,568 - __main__ - INFO - Column CC_disable_desc_jaw has 19 non-empty values
# 2025-03-09 16:55:36,568 - __main__ - INFO - Column CC_muscle_joint_desc_stress has 20 non-empty values
# 2025-03-09 16:55:36,569 - __main__ - INFO - Column CC_dentalHistory_desc has 20 non-empty values
# 2025-03-09 16:55:36,569 - __main__ - INFO - Column CC_clinic_history_desc has 20 non-empty values
# 2025-03-09 16:55:36,570 - __main__ - INFO - Column CC_factor_habbit has 20 non-empty values
# 2025-03-09 16:55:36,570 - __main__ - INFO - Column CC_treat_plan has 20 non-empty values
# 2025-03-09 16:55:36,571 - __main__ - INFO - Column CC_severity has 2 non-empty values
# 2025-03-09 16:55:36,572 - __main__ - INFO - Column CC_vas has 9 non-empty values
# 2025-03-09 16:55:36,572 - __main__ - INFO - Column CC_duration has 7 non-empty values
# 2025-03-09 16:55:36,572 - __main__ - INFO - Processing column: 약
# 2025-03-09 16:55:36,576 - __main__ - INFO - Processing 3 valid records for column 약
# 2025-03-09 16:55:36,577 - __main__ - INFO - 단일 텍스트 처리 중 1/3 (인덱스 1)
# 2025-03-09 16:55:38,081 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:38,085 - __main__ - INFO - 원시 API 응답: [
#     {
#         "medication_type": "진통제",
#         "frequency": "occasional",
#         "duration": null,
#         "compliance": "fair"
#     }
# ]...
# 2025-03-09 16:55:38,085 - __main__ - INFO - 텍스트 0 (인덱스 1) 처리 완료: {'medication_type': '진통제', 'frequency': 'occasional', 'duration': None, 'compliance': 'fair'}
# 2025-03-09 16:55:38,087 - __main__ - INFO - 단일 텍스트 처리 중 2/3 (인덱스 18)
# 2025-03-09 16:55:39,358 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:39,362 - __main__ - INFO - 원시 API 응답: [
#     {
#         "medication_type": "진통제",
#         "frequency": "정기적",
#         "duration": null,
#         "compliance": "양호"
#     },
#     {
#         "medication_type": "소염제",
#         "frequency": "미복용",
#         "duration": "7일",
#         "compliance": "양호"
#     }
# ]...
# 2025-03-09 16:55:39,363 - __main__ - INFO - 텍스트 0 (인덱스 18) 처리 완료: {'medication_type': '진통제', 'frequency': '정기적', 'duration': None, 'compliance': '양호'}
# 2025-03-09 16:55:39,364 - __main__ - INFO - 단일 텍스트 처리 중 3/3 (인덱스 19)
# 2025-03-09 16:55:40,275 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:40,278 - __main__ - INFO - 원시 API 응답: [
#     {
#         "medication_type": "진통제",
#         "frequency": "regular",
#         "duration": "3일",
#         "compliance": "poor"
#     }
# ]...
# 2025-03-09 16:55:40,279 - __main__ - INFO - 텍스트 0 (인덱스 19) 처리 완료: {'medication_type': '진통제', 'frequency': 'regular', 'duration': '3일', 'compliance': 'poor'}
# 2025-03-09 16:55:40,285 - __main__ - INFO - Checkpoint saved for column 약
# 2025-03-09 16:55:40,289 - __main__ - INFO - Checkpoint saved for column 약
# 2025-03-09 16:55:40,293 - __main__ - INFO - Column 약 generated 4 derived columns: ['약_medication_type', '약_frequency', '약_duration', '약_compliance']
# 2025-03-09 16:55:40,294 - __main__ - INFO - Column 약_medication_type has 3 non-empty values
# 2025-03-09 16:55:40,294 - __main__ - INFO - Column 약_frequency has 3 non-empty values
# 2025-03-09 16:55:40,295 - __main__ - INFO - Column 약_duration has 1 non-empty values
# 2025-03-09 16:55:40,296 - __main__ - INFO - Column 약_compliance has 3 non-empty values
# 2025-03-09 16:55:40,296 - __main__ - INFO - Processing column: 장치
# 2025-03-09 16:55:40,303 - __main__ - INFO - Processing 9 valid records for column 장치
# 2025-03-09 16:55:40,304 - __main__ - INFO - 단일 텍스트 처리 중 1/9 (인덱스 2)
# 2025-03-09 16:55:41,108 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:41,113 - __main__ - INFO - 원시 API 응답: [
#     {
#         "device_type": "장치",
#         "usage_pattern": "constant",
#         "duration": null,
#         "compliance": "fair"
#     }
# ]...
# 2025-03-09 16:55:41,114 - __main__ - INFO - 텍스트 0 (인덱스 2) 처리 완료: {'device_type': '장치', 'usage_pattern': 'constant', 'duration': None, 'compliance': 'fair'}
# 2025-03-09 16:55:41,115 - __main__ - INFO - 단일 텍스트 처리 중 2/9 (인덱스 3)
# 2025-03-09 16:55:42,029 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:42,033 - __main__ - INFO - 원시 API 응답: [
#     {
#         "device_type": "임플란트",
#         "usage_pattern": "constant",
#         "duration": "3일",
#         "compliance": "good"
#     }
# ]...
# 2025-03-09 16:55:42,034 - __main__ - INFO - 텍스트 0 (인덱스 3) 처리 완료: {'device_type': '임플란트', 'usage_pattern': 'constant', 'duration': '3일', 'compliance': 'good'}
# 2025-03-09 16:55:42,035 - __main__ - INFO - 단일 텍스트 처리 중 3/9 (인덱스 4)
# 2025-03-09 16:55:42,892 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:42,896 - __main__ - INFO - 원시 API 응답: [
#     {
#         "device_type": "APS",
#         "usage_pattern": "partial",
#         "duration": null,
#         "compliance": "good"
#     }
# ]...
# 2025-03-09 16:55:42,897 - __main__ - INFO - 텍스트 0 (인덱스 4) 처리 완료: {'device_type': 'APS', 'usage_pattern': 'partial', 'duration': None, 'compliance': 'good'}
# 2025-03-09 16:55:42,898 - __main__ - INFO - 단일 텍스트 처리 중 4/9 (인덱스 5)
# 2025-03-09 16:55:43,911 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:43,915 - __main__ - INFO - 원시 API 응답: [
#     {
#         "device_type": "장치",
#         "usage_pattern": "partial",
#         "duration": "2일",
#         "compliance": "good"
#     }
# ]...
# 2025-03-09 16:55:43,916 - __main__ - INFO - 텍스트 0 (인덱스 5) 처리 완료: {'device_type': '장치', 'usage_pattern': 'partial', 'duration': '2일', 'compliance': 'good'}
# 2025-03-09 16:55:43,917 - __main__ - INFO - 단일 텍스트 처리 중 5/9 (인덱스 6)
# 2025-03-09 16:55:44,950 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:44,958 - __main__ - INFO - 원시 API 응답: [
#     {
#         "device_type": "장치",
#         "usage_pattern": "partial",
#         "duration": "2일에 한번",
#         "compliance": "good"
#     }
# ]...
# 2025-03-09 16:55:44,959 - __main__ - INFO - 텍스트 0 (인덱스 6) 처리 완료: {'device_type': '장치', 'usage_pattern': 'partial', 'duration': '2일에 한번', 'compliance': 'good'}
# 2025-03-09 16:55:44,960 - __main__ - INFO - 단일 텍스트 처리 중 6/9 (인덱스 7)
# 2025-03-09 16:55:47,083 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:47,093 - __main__ - INFO - 원시 API 응답: [
#     {
#         "device_type": "임플란트",
#         "usage_pattern": "부분착용",
#         "duration": "한달",
#         "compliance": "양호"
#     }
# ]...
# 2025-03-09 16:55:47,094 - __main__ - INFO - 텍스트 0 (인덱스 7) 처리 완료: {'device_type': '임플란트', 'usage_pattern': '부분착용', 'duration': '한달', 'compliance': '양호'}
# 2025-03-09 16:55:47,095 - __main__ - INFO - 단일 텍스트 처리 중 7/9 (인덱스 8)
# 2025-03-09 16:55:48,009 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:48,014 - __main__ - INFO - 원시 API 응답: [
#     {
#         "device_type": "장치",
#         "usage_pattern": "rare",
#         "duration": null,
#         "compliance": "good"
#     }
# ]...
# 2025-03-09 16:55:48,015 - __main__ - INFO - 텍스트 0 (인덱스 8) 처리 완료: {'device_type': '장치', 'usage_pattern': 'rare', 'duration': None, 'compliance': 'good'}
# 2025-03-09 16:55:48,016 - __main__ - INFO - 단일 텍스트 처리 중 8/9 (인덱스 9)
# 2025-03-09 16:55:49,035 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:49,050 - __main__ - INFO - 원시 API 응답: [
#     {
#         "device_type": "장치",
#         "usage_pattern": "partial",
#         "duration": null,
#         "compliance": "fair"
#     }
# ]...
# 2025-03-09 16:55:49,051 - __main__ - INFO - 텍스트 0 (인덱스 9) 처리 완료: {'device_type': '장치', 'usage_pattern': 'partial', 'duration': None, 'compliance': 'fair'}
# 2025-03-09 16:55:49,052 - __main__ - INFO - 단일 텍스트 처리 중 9/9 (인덱스 11)
# 2025-03-09 16:55:49,910 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:49,914 - __main__ - INFO - 원시 API 응답: [
#     {
#         "device_type": "SS",
#         "usage_pattern": "partial",
#         "duration": "3주",
#         "compliance": "good"
#     }
# ]...
# 2025-03-09 16:55:49,915 - __main__ - INFO - 텍스트 0 (인덱스 11) 처리 완료: {'device_type': 'SS', 'usage_pattern': 'partial', 'duration': '3주', 'compliance': 'good'}
# 2025-03-09 16:55:49,921 - __main__ - INFO - Checkpoint saved for column 장치
# 2025-03-09 16:55:49,932 - __main__ - INFO - Checkpoint saved for column 장치
# 2025-03-09 16:55:49,941 - __main__ - INFO - Column 장치 generated 4 derived columns: ['장치_device_type', '장치_usage_pattern', '장치_duration', '장치_compliance']
# 2025-03-09 16:55:49,943 - __main__ - INFO - Column 장치_device_type has 9 non-empty values
# 2025-03-09 16:55:49,944 - __main__ - INFO - Column 장치_usage_pattern has 9 non-empty values
# 2025-03-09 16:55:49,945 - __main__ - INFO - Column 장치_duration has 5 non-empty values
# 2025-03-09 16:55:49,946 - __main__ - INFO - Column 장치_compliance has 9 non-empty values
# 2025-03-09 16:55:49,946 - __main__ - INFO - Processing column: 습관
# 2025-03-09 16:55:49,949 - __main__ - INFO - Processing 12 valid records for column 습관
# 2025-03-09 16:55:49,949 - __main__ - INFO - 단일 텍스트 처리 중 1/12 (인덱스 1)
# 2025-03-09 16:55:50,817 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:50,823 - __main__ - INFO - 원시 API 응답: [
#     {
#         "habit_type": "이갈이",
#         "frequency": "medium",
#         "awareness": "aware",
#         "improvement": "improved"
#     }
# ]...
# 2025-03-09 16:55:50,824 - __main__ - INFO - 텍스트 0 (인덱스 1) 처리 완료: {'habit_type': '이갈이', 'frequency': 'medium', 'awareness': 'aware', 'improvement': 'improved'}
# 2025-03-09 16:55:50,825 - __main__ - INFO - 단일 텍스트 처리 중 2/12 (인덱스 2)
# 2025-03-09 16:55:51,752 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:51,756 - __main__ - INFO - 원시 API 응답: [
#     {
#         "habit_type": "이갈이",
#         "frequency": "medium",
#         "awareness": "aware",
#         "improvement": "improved"
#     }
# ]...
# 2025-03-09 16:55:51,757 - __main__ - INFO - 텍스트 0 (인덱스 2) 처리 완료: {'habit_type': '이갈이', 'frequency': 'medium', 'awareness': 'aware', 'improvement': 'improved'}
# 2025-03-09 16:55:51,758 - __main__ - INFO - 단일 텍스트 처리 중 3/12 (인덱스 3)
# 2025-03-09 16:55:52,719 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:52,722 - __main__ - INFO - 원시 API 응답: ```json
# [{
#     "habit_type": "이갈이",
#     "frequency": "high",
#     "awareness": "aware",
#     "improvement": "improved"
# }]
# ```...
# 2025-03-09 16:55:52,723 - __main__ - INFO - JSON 파싱 성공: [{'habit_type': '이갈이', 'frequency': 'high', 'awareness': 'aware', 'improvement': 'improved'}]
# 2025-03-09 16:55:52,724 - __main__ - INFO - 텍스트 0 (인덱스 3) 처리 완료: {'habit_type': '이갈이', 'frequency': 'high', 'awareness': 'aware', 'improvement': 'improved'}
# 2025-03-09 16:55:52,725 - __main__ - INFO - 단일 텍스트 처리 중 4/12 (인덱스 4)
# 2025-03-09 16:55:54,358 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:54,362 - __main__ - INFO - 원시 API 응답: [
#     {
#         "habit_type": "식습관",
#         "frequency": "medium",
#         "awareness": "aware",
#         "improvement": "unchanged"
#     }
# ]...
# 2025-03-09 16:55:54,363 - __main__ - INFO - 텍스트 0 (인덱스 4) 처리 완료: {'habit_type': '식습관', 'frequency': 'medium', 'awareness': 'aware', 'improvement': 'unchanged'}
# 2025-03-09 16:55:54,364 - __main__ - INFO - 단일 텍스트 처리 중 5/12 (인덱스 5)
# 2025-03-09 16:55:55,526 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:55,532 - __main__ - INFO - 원시 API 응답: [
#     {
#         "habit_type": "이갈이",
#         "frequency": "medium",
#         "awareness": "aware",
#         "improvement": "improved"
#     }
# ]...
# 2025-03-09 16:55:55,533 - __main__ - INFO - 텍스트 0 (인덱스 5) 처리 완료: {'habit_type': '이갈이', 'frequency': 'medium', 'awareness': 'aware', 'improvement': 'improved'}
# 2025-03-09 16:55:55,534 - __main__ - INFO - 단일 텍스트 처리 중 6/12 (인덱스 6)
# 2025-03-09 16:55:56,706 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:56,708 - __main__ - INFO - 원시 API 응답: [
#     {
#         "habit_type": "이갈이",
#         "frequency": "medium",
#         "awareness": "aware",
#         "improvement": "improved"
#     }
# ]...
# 2025-03-09 16:55:56,708 - __main__ - INFO - 텍스트 0 (인덱스 6) 처리 완료: {'habit_type': '이갈이', 'frequency': 'medium', 'awareness': 'aware', 'improvement': 'improved'}
# 2025-03-09 16:55:56,709 - __main__ - INFO - 단일 텍스트 처리 중 7/12 (인덱스 7)
# 2025-03-09 16:55:57,636 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:55:57,666 - __main__ - INFO - 원시 API 응답: [
#     {
#         "habit_type": "이갈이",
#         "frequency": "medium",
#         "awareness": "aware",
#         "improvement": "improved"
#     }
# ]...
# 2025-03-09 16:55:57,669 - __main__ - INFO - 텍스트 0 (인덱스 7) 처리 완료: {'habit_type': '이갈이', 'frequency': 'medium', 'awareness': 'aware', 'improvement': 'improved'}
# 2025-03-09 16:55:57,680 - __main__ - INFO - 단일 텍스트 처리 중 8/12 (인덱스 8)
# 2025-03-09 16:56:01,844 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-09 16:56:01,849 - __main__ - INFO - 원시 API 응답: ```json
# [{
#     "habit_type": "식습관",
#     "frequency": "medium",
#     "awareness": "aware",
#     "improvement": "improved"
# }]
# ```...
# 2025-03-09 16:56:01,850 - __main__ - INFO - JSON 파싱 성공: [{'habit_type': '식습관', 'frequency': 'medium', 'awareness': 'aware', 'improvement': 'improved'}]
# 2025-03-09 16:56:01,851 - __main__ - INFO - 텍스트 0 (인덱스 8) 처리 완료: {'habit_type': '식습관', 'frequency': 'medium', 'awareness': 'aware', 'improvement': 'improved'}
# 2025-03-09 16:56:01,852 - __main__ - INFO - 단일 텍스트 처리 중 9/12 (인덱스 9)
# ...
# 유치 안쪽 잇몸                              1
# 오른쪽 아랫턱                               1
# 왼쪽 아래 끝에서 2번째쯤                        1
# 오른쪽 어금니                               1
# 오른쪽으로 씹으면 왼쪽에서 치아끼리 미끄러지면서 부딪히는 소리    1
# 아래 어금니                                1
# 아래 장치 낀 이후로 왼쪽 치아끼리                   1
# 턱 관절                                  1
# 아래 치아                                 1
# 턱관절                                   1
# 왼쪽 턱관절                                1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,253 - __main__ - INFO - CC_pain_type: 20 valid entries
# 2025-03-09 16:56:28,253 - __main__ - INFO - Value distribution:
# CC_pain_type
# 통증          11
# 불편감          2
# 시림           2
# 아픔           1
# 끼익거리는 소리     1
# 안닿는 느낌       1
# 소리           1
# 시리는 통증       1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,254 - __main__ - INFO - CC_painUncomp_desc_jaw: 20 valid entries
# 2025-03-09 16:56:28,255 - __main__ - INFO - Value distribution:
# CC_painUncomp_desc_jaw
# 턱 통증                   6
# 턱 통증/불편감               2
# 오른쪽 턱의 통증              1
# 턱이 불편했음                1
# 조금 아플때도 있고 불편할때도 있는    1
# 턱의 통증                  1
# 턱통증이나 불편감은 없어요         1
#                        1
# 왼쪽 아래 어금니(#36) 통증      1
# 통증, 뻐근함 없음             1
# 양치할때 시리긴 통증            1
# 턱 관절의 통증               1
# 통증 없어졌어요               1
# 통증 심함                  1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,256 - __main__ - INFO - CC_disable_desc_jaw: 19 valid entries
# 2025-03-09 16:56:28,256 - __main__ - INFO - Value distribution:
# CC_disable_desc_jaw
# 턱 관절의 비정상적인 움직임         3
#                         3
# 턱 관절의 제한된 개구            2
# 오른쪽 턱의 제한된 개구           1
# 턱벌어지는 것이 비슷함            1
# 뻐쩍찌근한 느낌                1
# 잘 안맞물리는 것만 있음           1
# 치아끼리 안닿게 턱에 힘풀려고 멍때림    1
# 오른쪽 턱이 가끔 딱딱해지는 느낌      1
# 소리 없음, 제한된 개구 없음        1
# 제한된 개구                  1
# 다른 불편한거 없어요             1
# 입벌릴 때 소리와 통증            1
# 딱소리                     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,257 - __main__ - INFO - CC_muscle_joint_desc_stress: 20 valid entries
# 2025-03-09 16:56:28,257 - __main__ - INFO - Value distribution:
# CC_muscle_joint_desc_stress
# 스트레스로 인한 턱 근육의 긴장               11
# 스트레스로 인한 턱 근육 긴장                 3
#                                  3
# 스트레스로 인한 긴장                      1
# 왼쪽 턱이 좀 아픔                       1
# 딱딱하고질긴거 피하려하고 치아끼리 안닿게 노력했어요     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,257 - __main__ - INFO - CC_dentalHistory_desc: 20 valid entries
# 2025-03-09 16:56:28,258 - __main__ - INFO - Value distribution:
# CC_dentalHistory_desc
# 물리치료                                     9
# 교정 치료, 보톡스, 물리치료                         3
# 교정 치료, 보톡스, 물리치료 등                       1
# 레진치료                                     1
# 임플란트 정기체크                                1
# 환자의 교정 치료, 보톡스, 물리치료 등                   1
# 이갈이는 가끔 있다고 들었어요                         1
# 양치할때 시리긴했어요                              1
# 양치할때 양쪽 아래 치료한곳이 시려요. 찬거 뜨거운거에는 괜찮구요.    1
# 보톡스 미용목적으로 한달 전 턱에만 맞았어요                 1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,258 - __main__ - INFO - CC_clinic_history_desc: 20 valid entries
# 2025-03-09 16:56:28,259 - __main__ - INFO - Value distribution:
# CC_clinic_history_desc
# 턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기                                                                                                                                                                                                                                         7
# 왼쪽통증과 입벌림이 힘들어서 서울대병원 30년 전 장치도 했었어요. 장치는 두고 왔어요 - 착용은 1년정도 하고 계속 괜찮다가 이번에 오른쪽 증상 생겼어요. 저번주 토요일 아침에 하품하다가 오른쪽 턱이 쥐난거처럼 경직되더니 현재 치아맞물림도 오른쪽이 어금니가 뜨고 오른쪽 턱이 잘 안벌어져요. 그 날 바로 일반치과 갔고 손으로 턱 넣고 했는데 맞춰지지않는다고 구강내과 가보라고해서 왔어요. 통증은 없어요. 소리는 왼쪽에 있었는데 장치치료 받고 사라져서 현재까지 없어요.    1
# 통증있었어요, 지금은 괜찮아요, 오른쪽으로 씹으면 오른쪽 아파요, 통증크기 비슷해요, 30년된 장치 가지고 오라고 하셔서 가져왔어요, 치아끼리 안닿게 노력헀어요                                                                                                                                                                                 1
# 통증 증상                                                                                                                                                                                                                                                                     1
# 장치 ck구강내과#11 수빈증상: 8월 부터 오른쪽으로 씹으면 왼쪽에서 치아끼리 미끄러지면서 부딪히는 소리가 나요 그래서 왼쪽으로 씹게 되는거 같아요 오른쪽도 꼭꼭 씹어지는 거 같지 않아요 8월전에는 증상이 좋아지는게 느껴졌는데 이후에는 안느껴져요 이 외에는 불편감 없어요 불편감 없어요 장치 낀날 안낀날 아침에 똑같아요 치아끼리 안닿게 턱에 힘풀려고 멍때렸어요                                                                1
# 어금니 통증, 시려움                                                                                                                                                                                                                                                               1
# 환자의 턱관절장애 관련 과거 병력, 치료 이력, 발병 시기 및 계기 등                                                                                                                                                                                                                                   1
# 턱관절 관련해서 통증, 뻐근함 없고 소리도 과거현재없어요                                                                                                                                                                                                                                           1
# 불편한건없고 검진 보러왔어요                                                                                                                                                                                                                                                           1
# #46 타원에서 치료 /#36 본원에서 치료                                                                                                                                                                                                                                                  1
# 턱관절진료 처음이고, 보톡스 미용목적으로 한달 전 턱에만 맞았어요                                                                                                                                                                                                                                      1
# 통증 없어졌어요                                                                                                                                                                                                                                                                  1
# 통증 증상: 왼쪽씹을때 통증이 더심해졌어요 VAS 3->VAS 6, 왼쪽벌릴때 딱소리가나요 입벌리지 않으면 통증은 없어요                                                                                                                                                                                                       1
# 통증은 아닌데 불편감정도만 거슬리게 남아있어요                                                                                                                                                                                                                                                 1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,259 - __main__ - INFO - CC_factor_habbit: 20 valid entries
# 2025-03-09 16:56:28,260 - __main__ - INFO - Value distribution:
# CC_factor_habbit
# 음식 섭취 습관, 수면 자세, 이 악물기 등                                                                           4
# 음식 섭취 습관, 수면 자세, 이 악물기                                                                             3
#                                                                                                    3
# 환자의 음식 섭취 습관, 수면 자세, 이 악물기 등                                                                       2
# 이악무는습관없어요. 이갈이 어렸을 때 만 잠은 잘자요. 스트레스 딱히 없어요(현재 위 남아있는 유치 살짝 흔들리고 있는데 잇몸치료받았고 다니는 치과 있어요.). 초음파ok    1
# 씹을때 오른쪽 통증                                                                                         1
# 턱 통증, 치아 통증                                                                                        1
# 음식 섭취 시 시려움                                                                                        1
# 이악무는습관은 없어요                                                                                        1
# 정기ck                                                                                               1
# 이악무는습관 있는거 같아요, 이갈이 없어요, 잠은 잘자요 : 6~7시간, 스트레스 항상 많은 편이에요 : 일 적으로 초음파ok                             1
# 딱딱하고질긴거 피하려하고 치아끼리 안닿게 노력했어요                                                                       1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,260 - __main__ - INFO - CC_treat_plan: 20 valid entries
# 2025-03-09 16:56:28,261 - __main__ - INFO - Value distribution:
# CC_treat_plan
#                               5
# 물리치료, 장치치료                    4
# 물리치료, 약물요법, 장치치료, 보톡스 주사 등    2
# 물리치료, APS del증상               1
# 물리치료, 약물요법, 장치치료, 보톡스 주사      1
# 임플란트                          1
# 물리치료, 마사지, 스트레칭               1
# 장치치료                          1
# 약물요법                          1
# 약 : 10일분정도는 남았어요              1
# 물리치료, 보톡스 주사                  1
# 물리치료                          1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,261 - __main__ - INFO - CC_severity: 2 valid entries
# 2025-03-09 16:56:28,261 - __main__ - INFO - CC_vas: 9 valid entries
# 2025-03-09 16:56:28,261 - __main__ - INFO - CC_duration: 7 valid entries
# 2025-03-09 16:56:28,262 - __main__ - INFO - Value distribution:
# CC_duration
# 10일    2
# 30년    1
# 3일     1
# 2주     1
# 5일     1
# 한달     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,262 - __main__ - INFO - 약_medication_type: 3 valid entries
# 2025-03-09 16:56:28,263 - __main__ - INFO - Value distribution:
# 약_medication_type
# 진통제    3
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,263 - __main__ - INFO - 약_frequency: 3 valid entries
# 2025-03-09 16:56:28,263 - __main__ - INFO - Value distribution:
# 약_frequency
# occasional    1
# 정기적           1
# regular       1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,264 - __main__ - INFO - 약_duration: 1 valid entries
# 2025-03-09 16:56:28,264 - __main__ - INFO - Value distribution:
# 약_duration
# 3일    1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,264 - __main__ - INFO - 약_compliance: 3 valid entries
# 2025-03-09 16:56:28,265 - __main__ - INFO - Value distribution:
# 약_compliance
# fair    1
# 양호      1
# poor    1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,265 - __main__ - INFO - 장치_device_type: 9 valid entries
# 2025-03-09 16:56:28,265 - __main__ - INFO - Value distribution:
# 장치_device_type
# 장치      5
# 임플란트    2
# APS     1
# SS      1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,266 - __main__ - INFO - 장치_usage_pattern: 9 valid entries
# 2025-03-09 16:56:28,266 - __main__ - INFO - Value distribution:
# 장치_usage_pattern
# partial     5
# constant    2
# 부분착용        1
# rare        1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,266 - __main__ - INFO - 장치_duration: 5 valid entries
# 2025-03-09 16:56:28,267 - __main__ - INFO - Value distribution:
# 장치_duration
# 3일        1
# 2일        1
# 2일에 한번    1
# 한달        1
# 3주        1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,267 - __main__ - INFO - 장치_compliance: 9 valid entries
# 2025-03-09 16:56:28,267 - __main__ - INFO - Value distribution:
# 장치_compliance
# good    6
# fair    2
# 양호      1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,268 - __main__ - INFO - 습관_habit_type: 12 valid entries
# 2025-03-09 16:56:28,268 - __main__ - INFO - Value distribution:
# 습관_habit_type
# 이갈이      8
# 식습관      2
# 음식선택     1
# 음식 선호    1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,268 - __main__ - INFO - 습관_frequency: 12 valid entries
# 2025-03-09 16:56:28,269 - __main__ - INFO - Value distribution:
# 습관_frequency
# medium    11
# high       1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,269 - __main__ - INFO - 습관_awareness: 12 valid entries
# 2025-03-09 16:56:28,269 - __main__ - INFO - Value distribution:
# 습관_awareness
# aware      11
# unaware     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,270 - __main__ - INFO - 습관_improvement: 12 valid entries
# 2025-03-09 16:56:28,270 - __main__ - INFO - Value distribution:
# 습관_improvement
# improved     9
# unchanged    3
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,270 - __main__ - INFO - 찜질_status: 11 valid entries
# 2025-03-09 16:56:28,271 - __main__ - INFO - 찜질_frequency: 10 valid entries
# 2025-03-09 16:56:28,271 - __main__ - INFO - Value distribution:
# 찜질_frequency
# high      7
# medium    3
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,271 - __main__ - INFO - 찜질_duration: 7 valid entries
# 2025-03-09 16:56:28,271 - __main__ - INFO - 찜질_method: 8 valid entries
# 2025-03-09 16:56:28,272 - __main__ - INFO - Value distribution:
# 찜질_method
# hot     5
# both    3
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,272 - __main__ - INFO - 마사지, 스트레칭_type: 2 valid entries
# 2025-03-09 16:56:28,273 - __main__ - INFO - Value distribution:
# 마사지, 스트레칭_type
# both    2
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,273 - __main__ - INFO - 마사지, 스트레칭_frequency: 2 valid entries
# 2025-03-09 16:56:28,273 - __main__ - INFO - Value distribution:
# 마사지, 스트레칭_frequency
# high    2
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,273 - __main__ - INFO - 마사지, 스트레칭_duration: 0 valid entries
# 2025-03-09 16:56:28,277 - __main__ - INFO - 마사지, 스트레칭_method: 2 valid entries
# 2025-03-09 16:56:28,285 - __main__ - INFO - Value distribution:
# 마사지, 스트레칭_method
# self    1
# both    1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,289 - __main__ - INFO - PI_pi_aggravating_factors: 1 valid entries
# 2025-03-09 16:56:28,290 - __main__ - INFO - Value distribution:
# PI_pi_aggravating_factors
#     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,291 - __main__ - INFO - PI_pi_TMJ_PI_desc: 1 valid entries
# 2025-03-09 16:56:28,299 - __main__ - INFO - Value distribution:
# PI_pi_TMJ_PI_desc
#     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,300 - __main__ - INFO - PI_pi_TMJ_PI_treatment: 1 valid entries
# 2025-03-09 16:56:28,303 - __main__ - INFO - Value distribution:
# PI_pi_TMJ_PI_treatment
#     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,304 - __main__ - INFO - PI_pi_drug_treatment: 1 valid entries
# 2025-03-09 16:56:28,322 - __main__ - INFO - Value distribution:
# PI_pi_drug_treatment
#     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,336 - __main__ - INFO - PI_pi_closing_dentalgear_desc: 1 valid entries
# 2025-03-09 16:56:28,337 - __main__ - INFO - Value distribution:
# PI_pi_closing_dentalgear_desc
#     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,340 - __main__ - INFO - PI_pi_next_schedule: 1 valid entries
# 2025-03-09 16:56:28,361 - __main__ - INFO - Value distribution:
# PI_pi_next_schedule
#     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,362 - __main__ - INFO - PI_pi_next_ck: 1 valid entries
# 2025-03-09 16:56:28,363 - __main__ - INFO - Value distribution:
# PI_pi_next_ck
#     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,363 - __main__ - INFO - PI_pi_PI_diagnosis_jojint: 1 valid entries
# 2025-03-09 16:56:28,364 - __main__ - INFO - Value distribution:
# PI_pi_PI_diagnosis_jojint
#     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,365 - __main__ - INFO - PI_pi_occlusal_treatment: 1 valid entries
# 2025-03-09 16:56:28,365 - __main__ - INFO - Value distribution:
# PI_pi_occlusal_treatment
#     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,366 - __main__ - INFO - PI_pi_medication_prescription: 1 valid entries
# 2025-03-09 16:56:28,366 - __main__ - INFO - Value distribution:
# PI_pi_medication_prescription
#     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,367 - __main__ - INFO - PI_pi_other_treatment: 1 valid entries
# 2025-03-09 16:56:28,367 - __main__ - INFO - Value distribution:
# PI_pi_other_treatment
#     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,367 - __main__ - INFO - PI_pi_onset: 1 valid entries
# 2025-03-09 16:56:28,368 - __main__ - INFO - Value distribution:
# PI_pi_onset
#     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,368 - __main__ - INFO - PI_pi_pattern: 1 valid entries
# 2025-03-09 16:56:28,369 - __main__ - INFO - Value distribution:
# PI_pi_pattern
#     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,369 - __main__ - INFO - PI_pi_status: 1 valid entries
# 2025-03-09 16:56:28,370 - __main__ - INFO - Value distribution:
# PI_pi_status
#     1
# Name: count, dtype: int64
#
# 2025-03-09 16:56:28,370 - __main__ - INFO - 전체 실행 시간: 0시간 2분 26.86초
# 2025-03-09 16:56:28,370 - __main__ - INFO - 평균 처리 속도: 0.14건/초
# 2025-03-09 16:56:28,371 - __main__ - INFO - Program execution completed

# %%
df.head(1)
# Out:
#           환자번호         날짜                                                 CC  \
# 13927  2211-09 2022-12-16  구강내과#3물리치료 , 증상 ck, 소견서(free)증상: 아픈거 없어요, 의식을 ...
#
#          약   장치                                 습관   찜질 마사지, 스트레칭  \
# 13927  NaN  NaN  습관: 딱딱하고 질긴거 피하려 했어요, 이랑이 안닿게 했어요  NaN       NaN
#
#                                                       PI
# 13927  12345678 12345678Dr.남윤진료TMJ자극요법-단순 - K07.66 저작...

# %%
pd.read_parquet('processed_medical_data_20250303_134711.parquet')
# Out:
#            환자번호         날짜                                                 CC  \
# 13927   2211-09 2022-12-16  구강내과#3물리치료 , 증상 ck, 소견서(free)증상: 아픈거 없어요, 의식을 ...
# 20895  2202-242 2022-03-14  구강종합검진이 받고 싶습니다. 이를 많이 악물고입마름 현상이 많이 심해서요. --3...
# 8259   2309-268 2023-10-04  턱관절10년전에양쪽인데 왼쪽이 심하게 딱딱소리 났어요벌리는게 불편해요강남쪽 구강내과...
# 2083    2302-65 2024-01-09  물리치료 , 장치 ck구강내과#10/ 혜련증상: 턱에 힘 주고나면 오른쪽 턱 뻐근해...
# 25638  2206-260 2022-11-25  내과 #6물리치료 , 장치 ck경북대 안감증상: 요즘 딱히 불편감 없ㅇ ㅣ지내고 있...
# ...         ...        ...                                                ...
# 13965  2211-109 2023-11-28  #26,27 in prep 가능성 (일반 처음), 일반: 1달전쯤에 집앞 치과에 검...
# 24441  2205-279 2022-06-11  구강내과#2물리치료 , APS 진행하실 지 ck증상: 아픈 빈도, 강도 줄었어요.(...
# 15117   2211-96 2022-11-14  6개월 전부터 오른쪽 귀 앞과 그 밑으로 아팠어요. 그래서 이빈후과가서 귀에는 이상...
# 23862  2205-158 2024-02-19  물리치료 , 장치 ck구강내과#10 /.림증상:턱 뻐근함, 통증 거의 없어요 vas...
# 3666   2304-174 2023-05-24  구강내과#2[도착]물리치료 , SS del증상: 저번 내원 이후로 매일 하루에 1~...
#
#                                   약                                 장치  \
# 13927
# 20895
# 8259
# 2083                                         장치: APS 주4회 착용/ 밴드X/ 불편감X
# 25638                  약: 처방된건 다 복용
# ...                             ...                                ...
# 13965                                     장치: aps 주6일 착용, 불편감 x, 밴드 x.
# 24441                약: 모두 복용/ 불편감X
# 15117
# 23862                                장치: ss 주2회 미착용, 불편감 - 양쪽 어금니 뻑뻑해요
# 3666   약: 10개정도 남았어요./ 속쓰림 불편함 없었어요
#
#                                                       습관  \
# 13927                  습관: 딱딱하고 질긴거 피하려 했어요, 이랑이 안닿게 했어요
# 20895
# 8259
# 2083       습관: 주 1회 정도 떡볶이 같은 음식 먹었어요/ 치아끼리 안닿게 턱에 힘 풀어요
# 25638
# ...                                                  ...
# 13965                               습관:질긴음식 x, 치아끼리 안닿게o
# 24441  습관: 질기고 딱딱 피하고 살살 씹었어요. 치아 물지 않으려고 했어요. 원래 잘 안...
# 15117
# 23862                습관:질긴음식 x, 치아끼리 안닿게 턱에 힘푸는거 요즘 못했어요
# 3666             습관: 딱딱하거나 질긴음식 안먹었어요./ 이랑 이가 안닿도록 노력했어요
#
#                           찜질           마사지, 스트레칭  \
# 13927
# 20895
# 8259
# 2083    찜질: 주 3회 온찜질팩 20분 해요  마사지,스트레칭: 둘다 주3-4회
# 25638  찜질: 매일 5~10분 / 턱관절찜질팩
# ...                      ...                 ...
# 13965          찜질: 매일 15-20분     마사지,스트레칭: 매일샤워시
# 24441              찜질: 못했어요.
# 15117
# 23862               찜질: 안했어요      마사지,스트레칭: 안했어요
# 3666    찜질: 냉찜질팩 1주일동안 녹을때까지
#
#                                                       PI  \
# 13927  12345678 12345678Dr.남윤진료TMJ자극요법-단순 - K07.66 저작...
# 20895
# 8259   * daytime/ clenching-> MFP TTH* both ID* Rt DJ...
# 2083                                          *Deep bite
# 25638                                      * 교합변화 가능성 고지
# ...                                                  ...
# 13965  [완료] #27 : Vericom inlay(caries (M)-endo가능성)[취...
# 24441  [진행중] 상악 : APS[메모] 장치 조정비용 2회 FREEMMTT 1회 FREE...
# 15117  12345678 12345678Dr.남윤진료측두하악장애분석검사, 파노라마, CT촬영...
# 23862  안면 비대칭 있으심-> 왼쪽 뼈 깎여나가면서 턱이 더 돌아간 상태왼쪽치아 많이 닳아...
# 3666
#
#                  CC_location          CC_pain_type  \
# 13927                   왼쪽 턱                 딱딱 소리
# 20895                    턱관절            퇴행성 변화, 통증
# 8259            턱관절, 양쪽 관자놀이               뻐근감, 통증
# 2083   오른쪽 턱, 오른쪽 귀 앞쪽, 왼쪽 턱       뻐근함, 걸리는 느낌, 소리
# 25638                  오른쪽 턱                    소리
# ...                      ...                   ...
# 13965                      턱  딱소리, 모래갈리는 소리, 막힌 느낌
# 24441                     구강             아픈 빈도, 강도
# 15117           오른쪽 귀 앞과 그 밑         통증, 소리, 안 벌어짐
# 23862               턱, 왼쪽 치아           뻐근함, 통증, 시림
# 3666           왼쪽 귀 앞, 머리, 턱           통증, 사각사각 소리
#
#                      CC_painUncomp_desc_jaw               CC_disable_desc_jaw  \
# 13927                           딱딱 소리가 나는 것                       딱딱 소리가 나는 것
# 20895                       턱관절의 통증, 퇴행성 변화             턱관절의 비정상적 움직임, 제한된 개구
# 8259   입이 잘 안 벌어지고 통증이 있었음, 턱에 힘을 주는 것이 불편함    벌리는 것이 불편함, 턱에 힘을 주는 것이 가장 불편함
# 2083             오른쪽 턱 뻐근함, 오른쪽 귀 앞쪽 걸리는 느낌                  입 벌릴 때 왼쪽 턱에서 소리
# 25638                        가끔 오른쪽에서 소리가 남                     음식 씹을 때 소리가 남
# ...                                     ...                               ...
# 13965   턱 내밀었다가 벌리면 왼쪽 딱소리 작게, 오른쪽 모래갈리는 소리    그냥 입벌리면 왼쪽 딱소리 크게나고 오른쪽은 막힌 느낌
# 24441                      VAS 3->2로 줄어든 통증                               N/A
# 15117           오른쪽 불편감, 입이 안 벌어짐, 오른쪽에서 소리     입이 안 벌어짐, 딸깍 소리, 안 벌어지는 빈도 증가
# 23862                       턱 뻐근함, 통증 거의 없음               단단한 것 씹을 때 왼쪽 통증 증가
# 3666                       왼쪽 귀 앞, 머리, 턱 통증  턱이 빠졌다가 들어갔다 반복, 음식 씹을 때 사각사각 소리
#
#                              CC_muscle_joint_desc_stress  \
# 13927                                        보톡스 후 변화 없음
# 20895                         이갈이, 입마름, 스트레스로 인한 턱 근육 긴장
# 8259   스트레스 받을 때 턱에 힘을 주면서 두통 발생, 이 악무는 습관, 잠을 잘 못 잠,...
# 2083                                      턱에 힘 주고 나면 뻐근함
# 25638                                     스트레스로 인한 증상 없음
# ...                                                  ...
# 13965                                      통증이나 뻐근함은 없었음
# 24441                                                N/A
# 15117                          이악무는 습관 없음, 이갈이 없음, 두통 없음
# 23862                        피곤하거나 스트레스 받은 날 왼쪽 아래 치아 시림
# 3666                                     아침에 통증이 조금 더 심함
#
#                                    CC_dentalHistory_desc  \
# 13927  보톡스 맞은지 2주 넘었는데 처음 5일만 힘이 빠지는 것 같더니 지금은 변화가 느껴...
# 20895        구강종합검진을 받고 싶어하며, 과거에 다른 곳에서 검사한 적은 없다고 언급됨.
# 8259          강남쪽 구강내과에서 물리치료랑 장치 1년정도 착용, 보톡스 맞고 싶어서 내원
# 2083                                         물리치료, 장치 치료
# 25638                                        물리치료, 장치 치료
# ...                                                  ...
# 13965  1달 전 집 앞 치과에서 왼쪽 위 치아 두 개가 썩어서 치료 필요, 한 개는 충치가...
# 24441                                               물리치료
# 15117                             이빈후과 방문, 염증으로 인한 약물 복용
# 23862                                        물리치료, 장치 치료
# 3666                                                물리치료
#
#                                   CC_clinic_history_desc  \
# 13927                               왼쪽에서 딱딱 소리가 나는 것 같아요
# 20895  3년 전부터 입마름 현상이 심해졌고, 턱관절의 퇴행성 변화가 의심되어 파노라마와 C...
# 8259   턱관절 10년 전에 양쪽인데 왼쪽이 심하게 딱딱 소리, 입이 잘 안 벌어지고 통증,...
# 2083   2-3달 전부터 입 벌릴 때 오른쪽 귀 앞쪽이 걸리는 느낌, 왼쪽 턱에서 소리가 나...
# 25638                               경북대에서 치료받음, 현재 증상 없음
# ...                                                  ...
# 13965  턱 내밀었다가 벌리면 왼쪽 딱소리 작게, 오른쪽 모래갈리는 소리, 그냥 입 벌리면 ...
# 24441
# 15117  6개월 전부터 오른쪽 귀 앞과 밑의 통증, 입 벌릴 때 소리 발생, 입이 안 벌어지...
# 23862                               림증상: 턱 뻐근함, 통증 거의 없음
# 3666                           저번 내원 이후로 턱이 빠졌다가 들어갔다 반복
#
#                                         CC_factor_habbit  \
# 13927                                  하루에 두 번 정도 의식을 해서
# 20895  이를 많이 악물고, 입마름 현상이 심하며, 잠을 잘 자고 일어나면 입이 가장 많이 ...
# 8259   이 악무는 습관 O, 딱딱하고 질긴 음식 X, 잠 잘 못자요 5시간 정도 자고 일찍...
# 2083                                턱에 힘을 주면 오른쪽 턱이 뻐근해짐
# 25638     음식 씹을 때 오른쪽에서 소리, 질기고 딱딱한 음식 피함, 이 닿지 않도록 신경 씀
# ...                                                  ...
# 13965                               특정 습관이나 자세에 대한 언급 없음
# 24441
# 15117  쌈을 몇 번 싸먹거나 많이 씹고 나면 입이 안 벌어짐, 질기고 딱딱한 음식 섭취 회...
# 23862  장치 안 낀 날 특히 뻐근함, 단단한 것 씹을 때 왼쪽 통증 증가, 피곤하거나 스트...
# 3666            음식 씹을 때 왼쪽에서 사각사각 소리가 남, 아침에 통증이 조금 더 심함
#
#                                            CC_treat_plan  CC_severity  CC_vas  \
# 13927                               물리치료, 샤워 시 온수찜질 주 2회          NaN     NaN
# 20895  측두하악장애분석검사, 파노라마, CT 촬영을 통해 진단받고, 타액검사를 통해 분비율...          NaN     NaN
# 8259   보톡스 (100unit) 완료, 초음파 진단, 장치 조정 비용 2회 free, 추후...          NaN     8.0
# 2083                물리치료, 장치 치료로 증상 강도와 빈도 감소 (VAS 5->1)          1.0     1.0
# 25638                          장치 매일 착용, 장치 불편 없음, 습관 조절          NaN     NaN
# ...                                                  ...          ...     ...
# 13965              장치 ck 구강내과 #12 혜림증상, 추가적인 치료 계획 언급 없음          NaN     NaN
# 24441                    물리치료 진행 여부 확인, 증상 개선 (VAS 3->2)          NaN     2.0
# 15117                                초음파 검사, 근육성 개구장애 판독          NaN     5.0
# 23862                      물리치료, 장치 치료, 증상에 따른 VAS 변화 관찰          NaN     3.0
# 3666                                                물리치료          NaN     1.0
#
#       CC_duration 약_medication_type 약_frequency 약_duration 약_compliance  \
# 13927     2주 넘었는데
# 20895        3년정도
# 8259          10년
# 2083       2-3달 전
# 25638                                   regular                    good
# ...           ...               ...         ...        ...          ...
# 13965        1달전쯤
# 24441                                   regular                    good
# 15117     6개월 전부터
# 23862         10분
# 3666                        unknown     unknown                 unknown
#
#       장치_device_type 장치_usage_pattern 장치_duration 장치_compliance 습관_habit_type  \
# 13927                                                                   편측성저작
# 20895
# 8259
# 2083             APS          partial                      good         편측성저작
# 25638
# ...              ...              ...         ...           ...           ...
# 13965            aps          partial         주6일          good         편측성저작
# 24441                                                                   편측성저작
# 15117
# 23862             ss             rare                      poor         편측성저작
# 3666                                                                    편측성저작
#
#       습관_frequency 습관_awareness 습관_improvement  찜질_status 찜질_frequency  \
# 13927       medium        aware       improved        NaN
# 20895                                                 NaN
# 8259                                                  NaN
# 2083        medium        aware       improved        1.0       medium
# 25638                                                 1.0         high
# ...            ...          ...            ...        ...          ...
# 13965          low        aware       improved        1.0         high
# 24441          low        aware       improved        0.0
# 15117                                                 NaN
# 23862          low        aware       worsened        0.0
# 3666           low        aware       improved        1.0          low
#
#        찜질_duration 찜질_method 마사지, 스트레칭_type 마사지, 스트레칭_frequency  \
# 13927          NaN
# 20895          NaN
# 8259           NaN
# 2083          20.0       hot           both              medium
# 25638         10.0       hot
# ...            ...       ...            ...                 ...
# 13965         15.0                     both                high
# 24441          NaN
# 15117          NaN
# 23862          NaN                     both                 low
# 3666           NaN      cold
#
#       마사지, 스트레칭_duration 마사지, 스트레칭_method PI_pi_aggravating_factors  \
# 13927
# 20895
# 8259                                                          이 악물기
# 2083
# 25638
# ...                  ...              ...                       ...
# 13965                                self
# 24441
# 15117
# 23862                                self
# 3666
#
#                                    PI_pi_TMJ_PI_desc  \
# 13927                                     측두하악장애분석검사
# 20895
# 8259   파노라마, Cone Beam CT, 측두하악장애분석검사, 초음파, 파노라마(특수)
# 2083
# 25638
# ...                                              ...
# 13965                               T-scan, 동기능적교합검사
# 24441                                     측두하악장애분석검사
# 15117  측두하악장애분석검사, 파노라마, Cone Beam CT, 초음파, 파노라마(특수)
# 23862
# 3666
#
#                                   PI_pi_TMJ_PI_treatment  \
# 13927  측두하악관절자극요법-단순자극, 측두하악관절자극요법-전기자극, 측두하악관절자극요법-복...
# 20895
# 8259                                        분사신장치료, 물리치료
# 2083
# 25638
# ...                                                  ...
# 13965                       악관절 고착 해소술, 악관절고착해소술, 분사신장치료
# 24441  측두하악관절자극요법-단순자극, 측두하악관절자극요법-전기자극, 측두하악관절자극요법-복...
# 15117  측두하악관절자극요법-단순자극, 측두하악관절자극요법-전기자극, 측두하악관절자극요법-복...
# 23862
# 3666
#
#               PI_pi_drug_treatment PI_pi_closing_dentalgear_desc  \
# 13927
# 20895
# 8259                                                보톡스(교합개선 목적)
# 2083
# 25638
# ...                            ...                           ...
# 13965
# 24441   리보트릴정(클로나제팜), 소론도정(프레드니솔론)                           APS
# 15117  페리슨정(에페리손염산염), 소론도정(프레드니솔론)         APS, SS, 보톡스(교합개선 목적)
# 23862
# 3666
#
#       PI_pi_next_schedule   PI_pi_next_ck  \
# 13927                21.0  증상 ck, 근육두께 ck
# 20895
# 8259                  7.0           증상 ck
# 2083
# 25638
# ...                   ...             ...
# 13965                   7           장치 ck
# 24441                   7            물리치료
# 15117                   7            물리치료
# 23862                               37 ck
# 3666
#
#                                PI_pi_PI_diagnosis_jojint  \
# 13927                                    저작근 장애 (K07.66)
# 20895
# 8259   퇴행성 관절염 (K07.65), 턱관절 통증 (K07.63), 저작근 장애 (K07...
# 2083
# 25638
# ...                                                  ...
# 13965                                   저작근의 장애 (K07.66)
# 24441                   저작근 장애 (K07.66), 턱관절내장증 (K07.60)
# 15117                 퇴행성 관절염 (K07.65), 저작근의 장애 (K07.66)
# 23862
# 3666
#
#                                 PI_pi_occlusal_treatment  \
# 13927
# 20895
# 8259
# 2083
# 25638
# ...                                                  ...
# 13965                                              장치 조정
# 24441                                          APS 장치 조정
# 15117  APS Splint 인상채득물리치료 , APS del [1주후][완료] 전악 : A...
# 23862
# 3666
#
#                          PI_pi_medication_prescription PI_pi_other_treatment  \
# 13927
# 20895
# 8259                                                                  보톡스 시술
# 2083
# 25638
# ...                                                ...                   ...
# 13965                                                               악관절 강세척술
# 24441   리보트릴정(클로나제팜) - 1/1회/8일, 소론도정(프레드니솔론) - 1/1회/8일
# 15117  페리슨정(에페리손염산염) - 1/1회/7일, 소론도정(프레드니솔론) - 1/1회/7일                보톡스 시술
# 23862
# 3666
#
#       PI_pi_onset PI_pi_pattern PI_pi_status
# 13927         3주후
# 20895
# 8259
# 2083
# 25638
# ...           ...           ...          ...
# 13965
# 24441
# 15117
# 23862
# 3666
#
# [100 rows x 55 columns]
