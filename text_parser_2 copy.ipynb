# %%
from konlpy.tag import Okt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from collections import defaultdict
import numpy as np
from gensim.models import Word2Vec
import fasttext.util
import fasttext
import fasttext.util
import gzip
import os
import pandas as pd
import anthropic
from typing import List, Dict, Any
import json
import asyncio
import re
from tqdm.asyncio import tqdm_asyncio
import nest_asyncio
from datetime import datetime
import sys
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) # FutureWarning 제거
import requests
import json

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel('../data/centum_data/21.11-24.6환자 CC_PI_치료계획.xlsx')
df['날짜'] = pd.to_datetime(df['날짜'])
df = df.iloc[:,1:]

api = pd.read_csv('../data/info.csv')
api_key = api.loc[0][1]

# %%
df = df[['환자번호', '날짜', 'CC', '약', '장치 ', '습관', '찜질 ', '마사지, 스트레칭', 'PI', 'CMO',
       'MMO', 'Cap.pal', 'M.pal', 'Noise', 'Loading', 'Occlusion', 'OJ/OB',
       'Class', 'Midline Shift', 'Deviation', 'CR-CO', 'Tongue ridging',
       'Mucosal ridging', 'Ultrasono', 'Rt', 'Lt', 'End feel', '치료계획',
       'T-scan 악화/개선', 'CBCT 악화/개선', 'CBCT 판독소견']]

# %%
pi_list = df.PI.dropna().tolist()
len(pi_list)
pi_list = list(dict.fromkeys(pi_list))

# %%
pi_text = ' '.join(pi_list)

# %%
import os
import json
import logging
from datetime import datetime
from typing import List, Dict, Optional
import asyncio
import pandas as pd
import anthropic
from tenacity import retry, stop_after_attempt, wait_exponential
import re
from tqdm.asyncio import tqdm as tqdm_asyncio
import nest_asyncio
nest_asyncio.apply()  # Apply the patch for nested event loops

# %%
from konlpy.tag import Okt
from collections import Counter
import re

def analyze_dental_text(text_list):
    okt = Okt()
    
    # 전처리: 리스트의 모든 텍스트를 하나의 문자열로 합치기
    all_text = ' '.join(text_list)
    
    # '*' 기호 제거 및 특수문자 처리
    all_text = all_text.replace('*', ' ')
    
    # 한글과 영어 분리하여 분석
    korean_pattern = re.compile('[가-힣]+')
    english_pattern = re.compile('[a-zA-Z]+')
    
    # 한글 단어 추출
    korean_words = []
    for word in korean_pattern.finditer(all_text):
        korean_words.append(word.group())
    
    # 영어 단어 추출
    english_words = []
    for word in english_pattern.finditer(all_text):
        english_words.append(word.group())
    
    # Okt로 한글 형태소 분석
    morphs = []
    for word in korean_words:
        morphs.extend(okt.pos(word))
    
    # 주요 단어 추출 (명사, 형용사)
    important_words = []
    for word, pos in morphs:
        if pos in ['Noun', 'Adjective']:
            important_words.append(word)
    
    # 단어 빈도수 계산
    korean_freq = Counter(important_words)
    english_freq = Counter(english_words)
    
    return {
        'korean_analysis': {
            'morphemes': morphs,
            'frequency': korean_freq.most_common(),
        },
        'english_analysis': {
            'words': english_words,
            'frequency': english_freq.most_common()
        }
    }

# 데이터 분석 실행
pi_list = df.PI.dropna().tolist()
pi_list = [i.replace('\n', ' ') for i in pi_list]
dental_records = pi_list

results = analyze_dental_text(dental_records)

# 결과 출력
print("=== 한글 분석 결과 ===")
print("\n형태소 분석:")
for morph, pos in results['korean_analysis']['morphemes'][:20]:  # 처음 20개만 출력
    print(f"{morph} ({pos})")

print("\n주요 한글 단어 빈도:")
for word, count in ['korean_analysis']['frequency']:
    print(f"{word}: {count}회")

print("\n=== 영어 분석 결과 ===")
for word, count in results['english_analysis']['frequency']:
    print(f"{word}: {count}회")
# Out:
# === 한글 분석 결과 ===
#
# 형태소 분석:
# 하악 (Exclamation)
# 전치부 (Noun)
# 교모 (Noun)
# 치아 (Noun)
# 교모 (Noun)
# 치아 (Noun)
# 교모 (Noun)
# 치아 (Noun)
# 교모 (Noun)
# 치아 (Noun)
# 교모 (Noun)
# 치아 (Noun)
# 교모 (Noun)
# 치아 (Noun)
# 교모 (Noun)
# 치아 (Noun)
# 교모 (Noun)
# 턱 (Noun)
# 떨림 (Verb)
# 치 (Noun)
#
# 주요 한글 단어 빈도:
# 자극: 67029회
# 요법: 56267회
# 장애: 50684회
# 남: 40837회
# 윤진: 40798회
# 료: 39639회
# 악관절: 38691회
# 검사: 38298회
# 파노라마: 25280회
# 의: 23380회
# 일: 23368회
# 측: 21701회
# 측두: 21441회
# 복합: 19976회
# 관절염: 17151회
# 교합: 15957회
# 전기: 15147회
# 함: 14896회
# 단순: 14061회
# 회: 13998회
# 시행: 13927회
# 월: 13814회
# 분석: 13565회
# 기능: 13420회
# 촬영: 13368회
# 퇴: 9827회
# 행성: 9827회
# 턱관절: 9195회
# 복용: 9161회
# 초음파: 8893회
# 장치: 8889회
# 치료: 8796회
# 턱: 8752회
# 물리치료: 8584회
# 통증: 8237회
# 후: 7516회
# 치아: 7439회
# 특수: 7350회
# 호소: 7315회
# 기타: 7190회
# 관절: 6679회
# 분사: 6609회
# 신장: 6603회
# 조정: 5969회
# 취침: 5683회
# 직전: 5623회
# 이상: 4920회
# 진행: 4860회
# 교모: 4677회
# 정: 4513회
# 보톡스: 3887회
# 메모: 3794회
# 염: 3790회
# 술: 3727회
# 진료: 3724회
# 염산: 3637회
# 위치: 3516회
# 명시: 3498회
# 에페: 3448회
# 페리: 3443회
# 리손: 3437회
# 슨정: 3409회
# 측두근: 3369회
# 소견: 3314회
# 발급: 3304회
# 실시: 3296회
# 이용: 3274회
# 의심: 3194회
# 판독: 3092회
# 검사동: 3078회
# 교: 3016회
# 부위: 2967회
# 장병: 2846회
# 병증: 2846회
# 여러: 2846회
# 두: 2748회
# 분: 2595회
# 아침: 2521회
# 상세: 2508회
# 불명: 2507회
# 인상채득: 2475회
# 증상: 2458회
# 저녁: 2294회
# 심함: 2258회
# 식후: 2254회
# 비급: 2251회
# 개월후: 2235회
# 리보: 2150회
# 트릴: 2150회
# 나제: 2127회
# 가능성: 1995회
# 사신: 1963회
# 변화: 1887회
# 증: 1812회
# 고착: 1788회
# 내장: 1773회
# 해소: 1728회
# 세: 1709회
# 영수증: 1706회
# 착해소: 1689회
# 구강: 1681회
# 일자: 1678회
# 역서: 1669회
# 별: 1651회
# 및: 1639회
# 페낙: 1637회
# 고지: 1554회
# 전체: 1498회
# 완료: 1495회
# 이갈이: 1474회
# 긴장: 1452회
# 부내: 1319회
# 료교: 1272회
# 많음: 1264회
# 근육: 1238회
# 박유진: 1217회
# 소론: 1216회
# 도정: 1210회
# 프레드니솔론: 1208회
# 치: 1202회
# 있음: 1196회
# 기상: 1174회
# 직후: 1171회
# 악: 1163회
# 부분: 1137회
# 장착: 1064회
# 두께: 1058회
# 심: 1051회
# 드림: 1047회
# 주사: 1047회
# 번: 1011회
# 비용: 973회
# 유도: 950회
# 보증: 874회
# 설명: 862회
# 가글: 814회
# 숨: 793회
# 그린: 791회
# 수화물: 710회
# 검진: 700회
# 마모: 696회
# 상악: 674회
# 위해: 661회
# 보험: 654회
# 년: 639회
# 달리: 635회
# 분류: 629회
# 별도: 612회
# 개월: 606회
# 리드: 603회
# 프리드: 603회
# 시트르산염: 603회
# 시: 590회
# 뒤: 590회
# 전치부: 563회
# 치석제거: 544회
# 비: 537회
# 사유: 533회
# 상태: 510회
# 뇌신경: 504회
# 양쪽: 487회
# 만성: 433회
# 연: 426회
# 다수: 424회
# 밴드: 419회
# 예정: 414회
# 수분: 408회
# 지킴: 408회
# 모: 397회
# 오른쪽: 395회
# 때: 392회
# 잔금: 386회
# 왼쪽: 381회
# 리도카인: 381회
# 구치부: 376회
# 경향: 361회
# 아마: 356회
# 기간: 355회
# 필요: 353회
# 관리: 352회
# 박영민: 352회
# 세부: 351회
# 확인: 340회
# 타액: 340회
# 주: 326회
# 파절: 324회
# 치석: 323회
# 개구: 319회
# 안: 310회
# 전화: 309회
# 마취: 306회
# 파우치: 305회
# 증정: 302회
# 우승: 301회
# 용품: 298회
# 전치: 293회
# 진행중: 288회
# 교정: 286회
# 치주염: 275회
# 밀리그램: 275회
# 더: 271회
# 예약: 269회
# 신경: 269회
# 덱: 269회
# 출혈: 268회
# 손: 268회
# 환자: 267회
# 진단: 267회
# 리터: 266회
# 제작: 265회
# 박: 262회
# 디스크: 260회
# 상: 259회
# 심화: 258회
# 메타: 257회
# 위염: 256회
# 말초: 252회
# 차단: 252회
# 온스: 251회
# 힘: 245회
# 체크: 241회
# 혀: 241회
# 안내: 232회
# 금: 230회
# 추후: 227회
# 전반: 218회
# 충전: 217회
# 보철물: 216회
# 기존: 215회
# 발치: 214회
# 인대: 209회
# 량: 208회
# 상담: 205회
# 이개: 203회
# 처방: 202회
# 침착: 197회
# 에피네프린: 197회
# 비율: 197회
# 다음: 195회
# 없음: 193회
# 제거: 192회
# 사용: 187회
# 덱사: 186회
# 것: 181회
# 기본: 180회
# 재: 179회
# 보류: 179회
# 진찰: 179회
# 관찰: 178회
# 만: 176회
# 약간: 171회
# 증가: 169회
# 수: 167회
# 레진: 164회
# 전: 160회
# 개: 159회
# 일후: 159회
# 보철: 157회
# 무상: 154회
# 단: 152회
# 이내: 151회
# 접착: 150회
# 반대: 149회
# 원장: 145회
# 용: 145회
# 캡슐: 145회
# 잇몸: 142회
# 시간: 141회
# 먼저: 141회
# 형성: 141회
# 고려: 141회
# 턱끝: 140회
# 움직임: 139회
# 로: 138회
# 회사: 138회
# 갈림: 136회
# 약: 136회
# 측정: 136회
# 강세: 136회
# 임플란트: 135회
# 충치: 135회
# 원: 135회
# 척술: 135회
# 비타: 135회
# 찜질: 135회
# 영상: 134회
# 뼈: 133회
# 제한: 133회
# 권유: 132회
# 징: 132회
# 조금: 132회
# 제출: 131회
# 염수: 130회
# 화물: 130회
# 코골: 130회
# 최은혜: 130회
# 정술: 129회
# 식: 127회
# 때문: 127회
# 단독: 127회
# 임시: 126회
# 소리: 124회
# 심한: 123회
# 불편: 123회
# 구치: 122회
# 이전: 122회
# 감: 120회
# 쪽: 120회
# 한번: 120회
# 추가: 118회
# 유지: 118회
# 인부: 117회
# 연락: 115회
# 좀: 114회
# 거의: 113회
# 백: 113회
# 습관: 112회
# 정도: 112회
# 내과: 112회
# 입: 112회
# 견치: 112회
# 과: 111회
# 원하: 111회
# 아목시실린: 109회
# 산: 109회
# 칼륨: 109회
# 점: 109회
# 있으: 108회
# 비교: 108회
# 달: 107회
# 옴: 107회
# 등: 107회
# 중: 107회
# 안정: 107회
# 양상: 106회
# 선염: 106회
# 보임: 105회
# 아목: 105회
# 조절: 105회
# 감별진단: 105회
# 내: 104회
# 전달: 102회
# 결정: 102회
# 변경: 101회
# 처치: 100회
# 수술: 99회
# 충전물: 98회
# 골: 97회
# 느낌: 97회
# 문서: 96회
# 현재: 96회
# 가바: 96회
# 펜틴: 96회
# 수수료: 95회
# 내일: 95회
# 부: 94회
# 염증: 94회
# 부종: 94회
# 은퇴: 93회
# 축: 93회
# 경부: 93회
# 병적: 93회
# 다시: 92회
# 생각: 92회
# 현: 92회
# 코: 92회
# 건조: 91회
# 맹출: 90회
# 물: 90회
# 추천: 89회
# 정기: 88회
# 이: 88회
# 나졸: 88회
# 관: 88회
# 살짝: 87회
# 못: 87회
# 착용: 87회
# 와동: 87회
# 플루: 87회
# 뉴론틴: 87회
# 경우: 86회
# 하전: 84회
# 발: 82회
# 션: 82회
# 알마겔정: 82회
# 게이트: 82회
# 트랙: 81회
# 방정: 81회
# 질환: 81회
# 침윤: 80회
# 납: 80회
# 인레: 80회
# 탈락: 78회
# 병원: 78회
# 선수: 78회
# 사본: 78회
# 규격: 78회
# 시적: 77회
# 원시: 77회
# 베이스: 77회
# 감소: 76회
# 출국: 75회
# 개선: 75회
# 회차: 75회
# 오늘: 74회
# 연마: 74회
# 하방: 73회
# 일주일: 73회
# 상의: 73회
# 수복: 73회
# 아티카: 72회
# 앞니: 71회
# 유치: 71회
# 설통: 71회
# 원하시면: 70회
# 영구: 70회
# 필요함: 70회
# 향균팩: 70회
# 남윤: 69회
# 기록: 69회
# 문제: 69회
# 가능: 69회
# 영: 69회
# 여부: 68회
# 완충: 68회
# 소: 67회
# 변연: 66회
# 매우: 65회
# 타원: 65회
# 시럽: 65회
# 심하: 65회
# 있는: 64회
# 실금: 64회
# 있어서: 63회
# 도: 63회
# 우선: 63회
# 고민: 62회
# 발생: 62회
# 실비: 62회
# 결과: 62회
# 살라: 62회
# 치과: 61회
# 일반: 61회
# 덜: 61회
# 셋팅: 61회
# 차: 60회
# 필요시: 60회
# 결손: 60회
# 곽: 60회
# 있다: 60회
# 있어: 60회
# 프로펜: 60회
# 정복: 60회
# 디: 59회
# 칸: 59회
# 양치: 59회
# 차트: 59회
# 아래: 59회
# 겐정: 59회
# 사이: 59회
# 주변: 58회
# 임: 58회
# 염좌: 58회
# 필로: 58회
# 카르핀: 58회
# 록: 58회
# 복잡: 57회
# 출력: 57회
# 계획: 57회
# 제: 57회
# 원하셔서: 57회
# 섬유화: 57회
# 높음: 56회
# 앞: 56회
# 적: 56회
# 매: 56회
# 알: 56회
# 푸루: 56회
# 일치: 55회
# 부재: 55회
# 움: 55회
# 볼: 55회
# 코니아: 55회
# 있다고: 54회
# 의뢰: 54회
# 취소: 54회
# 계속: 54회
# 보호: 54회
# 청구: 53회
# 약속: 52회
# 나트륨: 52회
# 안좋음: 52회
# 역: 51회
# 입술: 51회
# 동반: 51회
# 대칭: 51회
# 금일: 51회
# 근관치료: 51회
# 변색: 50회
# 보고: 50회
# 우측: 50회
# 구취: 50회
# 부정교합: 50회
# 민감: 50회
# 년전: 49회
# 대기: 49회
# 회복: 49회
# 시크: 48회
# 묽은: 48회
# 만원: 48회
# 다음주: 48회
# 차도: 48회
# 멜라토닌: 48회
# 끝: 48회
# 위: 48회
# 이부프로펜: 47회
# 치근활택술: 47회
# 아주: 47회
# 쉐: 47회
# 이드: 47회
# 소구치: 47회
# 자국: 46회
# 이후: 46회
# 어금니: 46회
# 로펜정: 46회
# 어려움: 46회
# 장님: 45회
# 고함: 45회
# 날: 45회
# 수리: 45회
# 레이: 45회
# 분가: 45회
# 글후: 45회
# 영진: 45회
# 주의: 45회
# 료코: 44회
# 흔적: 44회
# 부모님: 44회
# 토요일: 44회
# 안됨: 44회
# 물기: 44회
# 중단: 43회
# 동의: 43회
# 가지: 43회
# 좌측: 43회
# 존재: 43회
# 남원: 42회
# 상아: 42회
# 바이트: 42회
# 상악동: 42회
# 크게: 42회
# 일정: 42회
# 우딩: 42회
# 합치: 41회
# 치부: 41회
# 사항: 41회
# 격일: 40회
# 서명: 40회
# 두통: 40회
# 구멍: 40회
# 에식스: 40회
# 연하: 40회
# 입안: 40회
# 청소: 40회
# 해결: 40회
# 보호자: 39회
# 소개: 38회
# 활택술: 38회
# 결제: 38회
# 상황: 38회
# 경과: 38회
# 촉진: 38회
# 약물: 38회
# 유: 37회
# 인접: 37회
# 말씀: 37회
# 콜: 37회
# 크라운: 37회
# 착: 37회
# 요청: 37회
# 저장: 37회
# 괜찮음: 37회
# 접촉: 37회
# 신경치료: 36회
# 해당: 36회
# 질: 36회
# 있고: 36회
# 평가: 36회
# 프렙: 36회
# 마: 35회
# 편: 35회
# 작시: 35회
# 간단: 35회
# 거: 35회
# 어머님: 35회
# 있: 35회
# 간격: 35회
# 구매: 35회
# 많고: 35회
# 감각: 34회
# 작년: 34회
# 귀국: 34회
# 보관: 34회
# 최대한: 34회
# 상하: 34회
# 개방: 34회
# 이번: 33회
# 지속: 33회
# 운동: 33회
# 없는: 32회
# 시작: 32회
# 바로: 32회
# 채득: 32회
# 계좌: 14회
# 이체: 14회
# 분과: 14회
# 신청: 14회
# 남편: 14회
# 선택: 14회
# 마무리: 14회
# 틀니: 14회
# 사진촬영: 14회
# 해: 14회
# 자주: 14회
# 피부: 14회
# 범위: 14회
# 익돌: 14회
# 보이: 14회
# 하나: 14회
# 음식물: 14회
# 끼: 14회
# 음식: 14회
# 민: 14회
# 틀때: 14회
# 현상: 14회
# 털: 14회
# 얇음: 14회
# 식립: 13회
# 함턱: 13회
# 히알루론산: 13회
# 제일: 13회
# 원해요: 13회
# 확보: 13회
# 부터: 13회
# 주위: 13회
# 척: 13회
# 있어요: 13회
# 스캔: 13회
# 서울: 13회
# 출중: 13회
# 자보: 13회
# 대구: 13회
# 음: 13회
# 악전: 13회
# 없고: 13회
# 불편하시면: 13회
# 제외: 13회
# 군입대: 13회
# 악화: 13회
# 전문가: 13회
# 짧고: 13회
# 찍기: 13회
# 진통: 13회
# 퇴축: 13회
# 발린: 13회
# 즉일: 13회
# 어깨: 13회
# 심해: 13회
# 이벤트: 13회
# 협: 13회
# 음상: 13회
# 융기: 12회
# 있으나: 12회
# 악습관: 12회
# 파: 12회
# 절로: 12회
# 대체: 12회
# 납작: 12회
# 스케쥴: 12회
# 안될: 12회
# 위아래: 12회
# 톡: 12회
# 밀면: 12회
# 기준: 12회
# 아파요: 12회
# 관세: 12회
# 있으셔서: 12회
# 목요일: 12회
# 있으면: 12회
# 휴가: 12회
# 뉴론틴정: 12회
# 분납: 12회
# 드레싱: 12회
# 보기: 12회
# 뿌리: 12회
# 거리: 12회
# 맹: 12회
# 문의: 12회
# 치은: 12회
# 월말: 12회
# 융합: 12회
# 테이프: 12회
# 시원한: 12회
# 치통: 12회
# 토러스: 12회
# 앞쪽: 12회
# 체적: 12회
# 골격: 12회
# 뜸: 12회
# 부어있음: 11회
# 악견: 11회
# 타진: 11회
# 나머지: 11회
# 배우자: 11회
# 가능하다고: 11회
# 실: 11회
# 내용: 11회
# 혜택: 11회
# 야간: 11회
# 치의: 11회
# 많은: 11회
# 내년: 11회
# 점심: 11회
# 옆: 11회
# 물리: 11회
# 헥: 11회
# 메딘: 11회
# 각: 11회
# 가압: 11회
# 교체: 11회
# 겹: 11회
# 붙이: 11회
# 강하게: 11회
# 원하지: 11회
# 교묘: 11회
# 동요: 11회
# 좋을: 11회
# 위주: 11회
# 어렵다고: 11회
# 는걸: 11회
# 잔: 11회
# 상관없는: 11회
# 차이: 11회
# 심하지는: 11회
# 므: 11회
# 많으시고: 11회
# 많다: 11회
# 미세하게: 10회
# 좀있음: 10회
# 복근: 10회
# 난: 10회
# 호흡: 10회
# 아세트아미노펜: 10회
# 원일: 10회
# 원인: 10회
# 이비인후과: 10회
# 안되면: 10회
# 원래: 10회
# 혹: 10회
# 당장: 10회
# 동이: 10회
# 계시는: 10회
# 중간: 10회
# 빼심: 10회
# 일시: 10회
# 의한: 10회
# 남아: 10회
# 신분: 10회
# 튕기: 10회
# 미맹출: 10회
# 있었음: 10회
# 단계: 10회
# 과잉: 10회
# 오픈: 10회
# 얇게: 10회
# 다량: 10회
# 추: 10회
# 심함치아: 10회
# 수직: 10회
# 슈다페드정: 10회
# 슈도: 10회
# 아산병원: 10회
# 강함: 10회
# 예전: 10회
# 바깥: 10회
# 정중: 10회
# 고지전: 10회
# 모하: 10회
# 스텝: 10회
# 뇌출혈: 9회
# 둔하다고: 9회
# 소요: 9회
# 자리: 9회
# 양호: 9회
# 없어요: 9회
# 원하신다고: 9회
# 지원: 9회
# 중복: 9회
# 세브란스: 9회
# 약국: 9회
# 없으셔서: 9회
# 엔도: 9회
# 아파서: 9회
# 금액: 9회
# 오: 9회
# 렉스: 9회
# 세레: 9회
# 관련: 9회
# 원하실: 9회
# 종류: 9회
# 폐기: 9회
# 외치: 9회
# 아스피린: 9회
# 가장: 9회
# 불편한: 9회
# 치수: 9회
# 치실: 9회
# 본인: 9회
# 잔존: 9회
# 성형: 9회
# 이동: 9회
# 간: 9회
# 해도: 9회
# 꽉: 9회
# 이니셜: 9회
# 컨텍: 9회
# 교두: 9회
# 전혀: 9회
# 시려하셔서: 9회
# 불량: 9회
# 반응: 9회
# 착색: 9회
# 예후: 9회
# 횟수: 9회
# 회로: 9회
# 바: 9회
# 없다고하: 9회
# 꼭: 9회
# 인정: 9회
# 말레산: 9회
# 줄어듬: 9회
# 그런: 9회
# 체질: 9회
# 역치: 9회
# 수치: 9회
# 이완: 9회
# 불편하다고: 9회
# 규: 9회
# 개연: 9회
# 경련: 8회
# 아버님: 8회
# 다소: 8회
# 원하시는: 8회
# 복귀: 8회
# 인상: 8회
# 불편한거: 8회
# 방향: 8회
# 환불: 8회
# 번호: 8회
# 서울대: 8회
# 길이: 8회
# 원한다고: 8회
# 올해: 8회
# 개월뒤: 8회
# 여전히: 8회
# 카카오: 8회
# 원치않으: 8회
# 쎄레브: 8회
# 콕: 8회
# 시브: 8회
# 도중: 8회
# 광대: 8회
# 크기: 8회
# 등록: 8회
# 진통제: 8회
# 리콜: 8회
# 어머니: 8회
# 당뇨: 8회
# 벌린: 8회
# 병: 8회
# 튕김: 8회
# 있는지: 8회
# 입국: 8회
# 근육통: 8회
# 확: 8회
# 근무: 8회
# 과거: 8회
# 대한: 8회
# 만약: 8회
# 모양: 8회
# 타치: 8회
# 자체: 8회
# 그대로: 8회
# 덜림: 8회
# 강한: 8회
# 보통: 8회
# 모든: 8회
# 정보: 8회
# 모래: 8회
# 아우: 8회
# 상처: 8회
# 정상: 8회
# 플린트: 8회
# 시부: 8회
# 신경안정제: 8회
# 불안: 8회
# 마다: 8회
# 알러지: 8회
# 잠: 8회
# 노력: 8회
# 하선: 8회
# 의해: 8회
# 손톱: 8회
# 측편: 8회
# 시점: 8회
# 대비: 8회
# 아림치과: 8회
# 김연: 8회
# 힘줄: 8회
# 가끔: 7회
# 성별: 7회
# 떄: 7회
# 강직: 7회
# 재생: 7회
# 골질: 7회
# 기전: 7회
# 주입: 7회
# 아드님: 7회
# 이나: 7회
# 주파: 7회
# 주차: 7회
# 짧음: 7회
# 불가능: 2회
# 산부인과: 2회
# 존함: 2회
# 빈도: 2회
# 있었다고: 2회
# 상악옴: 2회
# 벗: 2회
# 없다: 2회
# 당시: 2회
# 퇴화: 2회
# 보조: 2회
# 틈: 2회
# 기재: 2회
# 광대뼈: 2회
# 차가운거: 2회
# 빨갛고: 2회
# 없으시고: 2회
# 스텀: 2회
# 보지: 2회
# 의미: 2회
# 대부분: 2회
# 파괴: 2회
# 퍼밋: 2회
# 반증: 2회
# 푸록틴: 2회
# 재보철: 2회
# 사이사이: 2회
# 낭성: 2회
# 실시간: 2회
# 역시진: 2회
# 맨: 2회
# 그렇고: 2회
# 모랑: 2회
# 인비절: 2회
# 치구: 2회
# 품: 2회
# 간공: 1회
# 대교: 1회
# 조신: 1회
# 수준: 1회
# 강원도: 1회
# 방서: 1회
# 원님: 1회
# 언니: 1회
# 침윤마취: 1회
# 종골: 1회
# 깨끗했던: 1회
# 장력: 1회
# 지체: 1회
# 쓰려서요: 1회
# 파도: 1회
# 원한다고하: 1회
# 정량: 1회
# 실제: 1회
# 있냐: 1회
# 불법: 1회
# 단호: 1회
# 있으시지만: 1회
# 입덧: 1회
# 괜찮아질: 1회
# 검진하실: 1회
# 동일한지: 1회
# 아니니깐: 1회
# 새로운: 1회
# 표: 1회
# 지퍼: 1회
# 무서워하셔서: 1회
# 짧게라도: 1회
# 신용카드: 1회
# 안되냐고: 1회
# 아까: 1회
# 분혹: 1회
# 판테라: 1회
# 김수진: 1회
# 유선: 1회
# 정의선: 1회
# 의선: 1회
# 전진: 1회
# 덮어서: 1회
# 지지: 1회
# 조정원: 1회
# 출신: 1회
# 둘째: 1회
# 없냐고: 1회
# 외면: 1회
# 안되서: 1회
# 이승준: 1회
# 필요해서: 1회
# 출근: 1회
# 아프실: 1회
# 복된다고: 1회
# 눌리: 1회
# 아파서요: 1회
# 안되: 1회
# 회의: 1회
# 근심: 1회
# 식구: 1회
# 안내소: 1회
# 우울증: 1회
# 웰부트린: 1회
# 엑스: 1회
# 순서대로: 1회
# 도우미: 1회
# 회차때: 1회
# 근본: 1회
# 파악: 1회
# 상담시: 1회
# 셀린: 1회
# 레이져: 1회
# 법도: 1회
# 문상: 1회
# 뻐: 1회
# 드러져: 1회
# 포크: 1회
# 탈착: 1회
# 필요하진: 1회
# 다행히: 1회
# 봉지: 1회
# 괜찮아졌는데: 1회
# 웬만하면: 1회
# 예나: 1회
# 이동훈: 1회
# 개깅: 1회
# 치열: 1회
# 더라도: 1회
# 이메일: 1회
# 센텀덴탈: 1회
# 지메일: 1회
# 의원: 1회
# 윤순: 1회
# 유을규님: 1회
# 금전: 1회
# 달이: 1회
# 안되지만: 1회
# 미는: 1회
# 갈수: 1회
# 에이스: 1회
# 함유: 1회
# 지선: 1회
# 연우: 1회
# 불안정해서: 1회
# 계신는: 1회
# 화끈: 1회
# 역설: 1회
# 키키: 1회
# 부탁드려요: 1회
# 명장: 1회
# 프린터: 1회
# 아페: 1회
# 아페손: 1회
# 독소: 1회
# 무시: 1회
# 알콜: 1회
# 식염수: 1회
# 경마: 1회
# 비시: 1회
# 충북: 1회
# 골병: 1회
# 김지희: 1회
# 박희: 1회
# 최강: 1회
# 하반기: 1회
# 유정: 1회
# 검: 1회
# 산정: 1회
# 전이: 1회
# 동일해요: 1회
# 양해: 1회
# 다르시고: 1회
# 수긍: 1회
# 깊을: 1회
# 해체: 1회
# 적합: 1회
# 협력: 1회
# 번대큐렛: 1회
# 원하다고: 1회
# 전화해서: 1회
# 콩팥: 1회
# 안좋았던: 1회
# 이민: 1회
# 원하시고: 1회
# 자녀: 1회
# 명: 1회
# 표면처리: 1회
# 박영: 1회
# 겹치: 1회
# 차팅: 1회
# 열기: 1회
# 방구: 1회
# 스탑: 1회
# 확실히는: 1회
# 미확정: 1회
# 체어: 1회
# 케어: 1회
# 본도: 1회
# 자리있어서: 1회
# 미팅: 1회
# 변위: 1회
# 연조직염: 1회
# 원하셨는데: 1회
# 성함: 1회
# 윤: 1회
# 미현: 1회
# 통화시: 1회
# 입냄새: 1회
# 요일: 1회
# 최종은: 1회
# 꼬리: 1회
# 하남: 1회
# 차후: 1회
# 처지: 1회
# 사무실: 1회
# 유경: 1회
# 몽골: 1회
# 명함: 1회
# 친형: 1회
# 단대: 1회
# 없을까봐: 1회
# 이다희: 1회
# 뉴질랜드: 1회
# 건전하나: 1회
# 급한게: 1회
# 교흔: 1회
# 음유: 1회
# 도헌: 1회
# 유학생: 1회
# 택시: 1회
# 할때즘: 1회
# 함징: 1회
# 필요한가요: 1회
# 오류: 1회
# 트윈스: 1회
# 칼리: 1회
# 크레인: 1회
# 클리: 1회
# 아티: 1회
# 연질: 1회
# 디카: 1회
# 디정: 1회
# 보나: 1회
# 이정: 1회
# 독려: 1회
# 급여: 1회
# 값: 1회
# 미맹: 1회
# 옛날: 1회
# 워홀: 1회
# 픽스: 1회
# 즈음: 1회
# 깊게하시고: 1회
# 반드시: 1회
# 애매한: 1회
# 제자: 1회
# 사탕: 1회
# 혈: 1회
# 해제: 1회
# 저혈압: 1회
# 플르: 1회
# 구토: 1회
# 더부: 1회
# 배우: 1회
# 작성중: 1회
# 아플: 1회
# 부루: 1회
# 펜: 1회
# 전신: 1회
# 김영국: 1회
# 심미경: 1회
# 얼마나: 1회
# 명확해: 1회
# 포로: 1회
# 완제: 1회
# 이혜민: 1회
# 헷갈릴것: 1회
# 상온: 1회
# 헷갈리지는: 1회
# 이직: 1회
# 무서워하: 1회
# 부족하실수도: 1회
# 연말정산: 1회
# 기숙사: 1회
# 이연주: 1회
# 중등: 1회
# 증상만: 1회
# 김민솔: 1회
# 고대: 1회
# 김민정: 1회
# 통일: 1회
# 영역: 1회
# 방사선: 1회
# 나은지: 1회
# 새벽: 1회
# 체류: 1회
# 확실: 1회
# 두부: 1회
# 기차: 1회
# 연세: 1회
# 홀쭉해지실: 1회
# 부각: 1회
# 옴선: 1회
# 조종사: 1회
# 정신: 1회
# 생리: 1회
# 선납금: 1회
# 친척: 1회
# 실하셔서: 1회
# 대리인: 1회
# 윤희: 1회
# 도용: 1회
# 박호영: 1회
# 미세: 1회
# 절단연: 1회
# 정아영: 1회
# 압박: 1회
# 상한: 1회
# 은솔: 1회
# 뻐근감: 1회
# 힘들어서: 1회
# 부담스러우면: 1회
# 남자친구: 1회
# 프시: 1회
# 어프: 1회
# 랩임프: 1회
# 파마: 1회
# 유럽: 1회
# 불균형: 1회
# 모델상: 1회
# 미성년: 1회
# 자라: 1회
# 미소: 1회
# 디자인: 1회
# 이유진: 1회
# 개채득: 1회
# 말랑말랑한: 1회
# 장지: 1회
# 랩: 1회
# 영어: 1회
# 발거: 1회
# 에어: 1회
# 탈정: 1회
# 체조: 1회
# 체: 1회
# 이현희: 1회
# 혜련: 1회
# 써비: 1회
# 컬: 1회
# 길어: 1회
# 암등: 1회
# 회조: 1회
# 늦: 1회
# 가능하나: 1회
# 이야기: 1회
# 삼성: 1회
# 우울: 1회
# 차팅함: 1회
# 어지러워요: 1회
# 나름: 1회
# 화제: 1회
# 쓰리게: 1회
# 지저분한: 1회
# 타박상: 1회
# 미결: 1회
# 프린트: 1회
# 기계: 1회
# 존유: 1회
# 메일: 1회
# 청각장애: 1회
# 작게: 1회
# 넣기: 1회
# 재택근무: 1회
# 헐겁고: 1회
# 복사: 1회
# 이기: 1회
# 함침윤: 1회
# 같으면: 1회
# 송판: 1회
# 듣기: 1회
# 이어진: 1회
# 들뜬: 1회
# 예민해진: 1회
# 리셋: 1회
# 팅: 1회
# 아팠는데: 1회
# 컷팅후: 1회
# 필요함도: 1회
# 괴사: 1회
# 철저히구: 1회
# 강보: 1회
# 피곤해서: 1회
# 버튼: 1회
# 간지: 1회
# 편안해하시는: 1회
# 오히려: 1회
# 강하신것이: 1회
# 지상: 1회
# 한결: 1회
# 편안해지셨다고: 1회
# 편안해지시면: 1회
# 강하다고: 1회
# 달반: 1회
# 신지: 1회
# 아프긴: 1회
# 농: 1회
# 배출: 1회
# 멀어서: 1회
# 다다: 1회
# 굉장히: 1회
# 푸석푸석함: 1회
# 커버: 1회
# 가능하기: 1회
# 최상: 1회
# 피질: 1회
# 깊이: 1회
# 고정력: 1회
# 시린거: 1회
# 욱: 1회
# 안좋은데: 1회
# 강해: 1회
# 급한건: 1회
# 가능하긴: 1회
# 잔존골: 1회
# 단단하게: 1회
# 면적: 1회
# 송부: 1회
# 진날: 1회
# 내지: 1회
# 상병: 1회
# 방해: 1회
# 안되도록: 1회
# 가까운: 1회
# 동네: 1회
# 출력장치: 1회
# 불편해하시는: 1회
# 아까전에: 1회
# 어떤: 1회
# 떨림판: 1회
# 통원: 1회
# 외형: 1회
# 이사: 1회
# 기대하기: 1회
# 아기: 1회
# 길지: 1회
# 더함: 1회
# 나열: 1회
# 생기지: 1회
# 두꺼우신: 1회
# 기우: 1회
# 개구량: 1회
# 다발: 1회
# 러질: 1회
# 득시: 1회
# 성원: 1회
# 정확하게: 1회
# 구성: 1회
# 거상: 1회
# 과도: 1회
# 경사: 1회
# 여분: 1회
# 그런거고: 1회
# 김하은: 1회
# 베스트: 1회
# 려고: 1회
# 붓기: 1회
# 부정맥: 1회
# 중증: 1회
# 같다하셔서: 1회
# 불가능할수있음: 1회
# 원하실시: 1회
# 로펜: 1회
# 투여: 1회
# 중인: 1회
# 오래되면: 1회
# 날정: 1회
# 상관: 1회
# 필요하신거면: 1회
# 가전: 1회
# 도로: 1회
# 와이어: 1회
# 두번째: 1회
# 정장: 1회
# 정줄: 1회
# 가장자리: 1회
# 유지후: 1회
# 사이즈: 1회
# 누우: 1회
# 자세: 1회
# 있으시며: 1회
# 응급: 1회
# 최예슬: 1회
# 어스: 1회
# 태마: 1회
# 독감: 1회
# 음주: 1회
# 가도: 1회
# 그랬는데: 1회
# 그날그날: 1회
# 다를수: 1회
# 품절: 1회
# 더라구요: 1회
# 리뉴얼: 1회
# 당분간: 1회
# 힘들어: 1회
# 괜찮은데: 1회
# 자세한: 1회
# 아프신: 1회
# 심하다고하: 1회
# 긴밀하시며: 1회
# 개월전: 1회
# 협측: 1회
# 뻐근할: 1회
# 변: 1회
# 경원하: 1회
# 자리있으면: 1회
# 처음처럼: 1회
# 아닌것으로: 1회
# 교직원: 1회
# 씨: 1회
# 완치: 1회
# 향상: 1회
# 때매: 1회
# 톡톡: 1회
# 일수: 1회
# 거칠거칠한: 1회
# 정리: 1회
# 중기: 1회
# 빈: 1회
# 호함: 1회
# 적립금: 1회
# 부로: 1회
# 비타민: 1회
# 있으실: 1회
# 할부: 1회
# 좋을것: 1회
# 필요한데: 1회
# 거북하고: 1회
# 무거운: 1회
# 갑작스럽고: 1회
# 잡: 1회
# 규현: 1회
# 매년: 1회
# 부하: 1회
# 칼: 1회
# 지면: 1회
# 정주안: 1회
# 전치사: 1회
# 결체: 1회
# 엄당: 1회
# 괜찮은지: 1회
# 전화했어요: 1회
# 통영: 1회
# 쌤: 1회
# 대동문: 1회
# 원하셨고: 1회
# 가능하다고하여: 1회
# 귀가: 1회
# 멍한: 1회
# 이의: 1회
# 듭니: 1회
# 턱쪽: 1회
# 불가하시면: 1회
# 자전거: 1회
# 원하시길: 1회
# 컴: 1회
# 래인: 1회
# 자리있는지: 1회
# 색상: 1회
# 얇지만: 1회
# 불편하다고하셔서: 1회
# 고혈압: 1회
# 백내장: 1회
# 안좋아요: 1회
# 이영미: 1회
# 화함: 1회
# 두근거리는: 1회
# 반전: 1회
# 매달: 1회
# 장착티: 1회
# 심함아: 1회
# 부서: 1회
# 이원숙: 1회
# 채원준: 1회
# 인애: 1회
# 유승현: 1회
# 사촌언니: 1회
# 없도록: 1회
# 전화했으나: 1회
# 에이: 1회
# 서정: 1회
# 가스: 1회
# 김태균: 1회
# 치전: 1회
# 안된데요: 1회
# 확률: 1회
# 크랙: 1회
# 원치않아요: 1회
# 전기장판: 1회
# 갑상선: 1회
# 항진: 1회
# 호르몬: 1회
# 항체: 1회
# 카: 1회
# 힘들었고: 1회
# 구역: 1회
# 흉쇄유돌근: 1회
# 근막: 1회
# 양식: 1회
# 열람: 1회
# 워낙: 1회
# 화장: 1회
# 힘들고: 1회
# 레톨정: 1회
# 우려: 1회
# 발발: 1회
# 손보: 1회
# 원하신다: 1회
# 가까: 1회
# 알약: 1회
# 못드심: 1회
# 가루약: 1회
# 짧을: 1회
# 장단점: 1회
# 이도경: 1회
# 카운팅: 1회
# 영향: 1회
# 아닌가요: 1회
# 연하우: 1회
# 없다면: 1회
# 필요할지: 1회
# 계신다: 1회
# 행복: 1회
# 처: 1회
# 안되셨다고하: 1회
# 분동: 1회
# 이소영: 1회
# 편하신: 1회
# 불편했다고: 1회
# 주님: 1회
# 근접한: 1회
# 임박: 1회
# 쪽지: 1회
# 하라: 1회
# 약하: 1회
# 안보: 1회
# 퍼트: 1회
# 반대쪽: 1회
# 할껀데: 1회
# 라텍스: 1회
# 재채기: 1회
# 미니: 1회
# 들뜸: 1회
# 아픈게: 1회
# 아닌: 1회
# 독맥: 1회
# 관상동맥: 1회
# 재활: 1회
# 자차: 1회
# 항목: 1회
# 영빈: 1회
# 누움: 1회
# 신중하게: 1회
# 안전하게: 1회
# 이근혜: 1회
# 영문: 1회
# 벽: 1회
# 얇아진: 1회
# 엄마: 1회
# 사제: 1회
# 낮아: 1회
# 간수치: 1회
# 높으셔서: 1회
# 부분떄문: 1회
# 쓰시: 1회
# 아닌거: 1회
# 숫자: 1회
# 사액: 1회
# 프롤: 1회
# 한도: 1회
# 열: 1회
# 있었는데: 1회
# 불편했던: 1회
# 운전: 1회
# 폐구: 1회
# 인터뷰: 1회
# 찍: 1회
# 필요없다고하: 1회
# 이중: 1회
# 있을시: 1회
# 제대로: 1회
# 아프시면: 1회
# 있는게: 1회
# 동기부여: 1회
# 부드러워: 1회
# 동광: 1회
# 첫날: 1회
# 라면: 1회
# 지시: 1회
# 뇌종양: 1회
# 괜찮나요: 1회
# 술월: 1회
# 정밀: 1회
# 재결: 1회
# 제해: 1회
# 연결해주세요: 1회
# 없는데: 1회
# 꿈틀: 1회
# 린다: 1회
# 교육: 1회
# 필요함을: 1회
# 불편했어요: 1회
# 린치: 1회
# 신생아: 1회
# 음향: 1회
# 화이트: 1회
# 파라핀: 1회
# 채취: 1회
# 수탁: 1회
# 기관: 1회
# 서울대학교: 1회
# 대수술: 1회
# 좋으실것: 1회
# 중임: 1회
# 경직: 1회
# 챠팅없: 1회
# 서랍: 1회
# 노이즈: 1회
# 급히: 1회
# 좋은가요: 1회
# 같더라구요: 1회
# 축소: 1회
# 한편: 1회
# 부어있었다고: 1회
# 이상연: 1회
# 이면: 1회
# 마르고: 1회
# 심교: 1회
# 과활: 1회
# 줌: 1회
# 엑손: 1회
# 일상: 1회
# 포정: 1회
# 좋겠다고: 1회
# 위험함: 1회
# 목표: 1회
# 머리뼈: 1회
# 화상: 1회
# 떡볶이: 1회
# 젤리: 1회
# 다르다고하: 1회
# 하얀색: 1회
# 전문: 1회
# 분야: 1회
# 구분: 1회
# 시기하: 1회
# 납작한거: 1회
# 없으며: 1회
# 괜찮아진다고: 1회
# 백태: 1회
# 할머니: 1회
# 육류: 1회
# 필요없으나: 1회
# 잡지: 1회
# 객관: 1회
# 지표: 1회
# 입원: 1회
# 음압: 1회
# 출시: 1회
# 필요할수있어: 1회
# 필요해요: 1회
# 합성: 1회
# 멸균: 1회
# 거즈: 1회
# 뻐근: 1회
# 괜찮을것: 1회
# 별다른: 1회
# 이참: 1회
# 급한것: 1회
# 협접막: 1회
# 있으시기: 1회
# 불편해질: 1회
# 있으셨음: 1회
# 심한것으로: 1회
# 듯함: 1회
# 번만: 1회
# 장함: 1회
# 통점: 1회
# 털컥: 1회
# 필: 1회
# 뻐근함은: 1회
# 튼튼하: 1회
# 설암: 1회
# 윗입술: 1회
# 작고: 1회
# 물감: 1회
# 선호: 1회
# 루틴: 1회
# 두려워: 1회
# 새롬추: 1회
# 화면: 1회
# 안좋으면: 1회
# 공률: 1회
# 충분할: 1회
# 투약: 1회
# 안좋으셔서: 1회
# 게: 1회
# 뻐근해졌는데: 1회
# 약재: 1회
# 다달이: 1회
# 역냉: 1회
# 울음: 1회
# 필요한데요: 1회
# 상담사: 1회
# 필요하다는: 1회
# 이러한: 1회
# 휴직: 1회
# 틴: 1회
# 슈다페드: 1회
# 구리: 1회
# 담당: 1회
# 의사: 1회
# 안전성: 1회
# 마취제: 1회
# 심근경색: 1회
# 비슷하다하셔서: 1회
# 이라크: 1회
# 세팅시: 1회
# 복욧: 1회
# 모름: 1회
# 건조할: 1회
# 힘드신: 1회
# 염일: 1회
# 배제: 1회
# 욱신욱신: 1회
# 나쁘지: 1회
# 연히: 1회
# 적당한: 1회
# 템포: 1회
# 러리: 1회
# 얇아서: 1회
# 턱밑: 1회
# 과세: 1회
# 윗쪽: 1회
# 입천장: 1회
# 정해: 1회
# 간단함혀는: 1회
# 두시: 1회
# 은부: 1회
# 원할게요: 1회
# 그로: 1회
# 해지: 1회
# 심지: 1회
# 난번: 1회
# 편해지셨다고는: 1회
# 싫다고: 1회
# 장염: 1회
# 식중독: 1회
# 궁금해요: 1회
# 괜찮아지셨다고: 1회
# 필요하시다고: 1회
# 시급한: 1회
# 아니기: 1회
# 알레르기: 1회
# 히스타민: 1회
# 괜찮아졌다가: 1회
# 옻: 1회
# 스틸: 1회
# 녹스: 1회
# 써카딘: 1회
# 좋아하고: 1회
# 바쁘셔서: 1회
# 적당하게: 1회
# 무방: 1회
# 사과나무: 1회
# 시급하여: 1회
# 어려웠을: 1회
# 단단하고: 1회
# 부아: 1회
# 필요하시면: 1회
# 관절통: 1회
# 락: 1회
# 미보: 1회
# 철: 1회
# 도라미: 1회
# 깊을시: 1회
# 부었는데: 1회
# 있는거처럼: 1회
# 통상: 1회
# 수반: 1회
# 저희: 1회
# 회장: 1회
# 부득이: 1회
# 무마: 1회
# 많다고: 1회
# 안될시: 1회
# 불규칙한: 1회
# 없으신: 1회
# 궁금하다고: 1회
# 원하면: 1회
# 착시: 1회
# 백신: 1회
# 스리: 1회
# 납작해져: 1회
# 프로락틴: 1회
# 회정: 1회
# 필히: 1회
# 재검사: 1회
# 화끈한: 1회
# 아픈거예요: 1회
# 턱괴: 1회
# 있으려고: 1회
# 백상: 1회
# 비후: 1회
# 빼주: 1회
# 힘드: 1회
# 적인걸: 1회
# 주신: 1회
# 필요없고: 1회
# 긴밀하신: 1회
# 높이: 1회
# 만큼: 1회
# 철저히: 1회
# 당부: 1회
# 술약: 1회
# 계신거: 1회
# 같은게: 1회
# 애가: 1회
# 캐: 1회
# 생리식염수: 1회
# 소프트: 1회
# 꼐: 1회
# 국산: 1회
# 두피: 1회
# 강석: 1회
# 하순: 1회
# 막부: 1회
# 건너: 1회
# 오기: 1회
# 힘들어있는: 1회
# 단순한: 1회
# 편안하게: 1회
# 마메: 1회
# 원합니다: 1회
# 뒤통수: 1회
# 없었음: 1회
# 구정: 1회
# 함입: 1회
# 괜찮아지셨기: 1회
# 추세: 1회
# 휘: 1회
# 찌릿찌릿하고: 1회
# 깜짝: 1회
# 소용: 1회
# 없는것: 1회
# 괜찮아지시는지: 1회
# 좋을지: 1회
# 눌린쪽: 1회
# 드빌: 1회
# 보이지: 1회
# 방금: 1회
# 이사이: 1회
# 없기: 1회
# 아프지도: 1회
# 심했는데: 1회
# 있는것: 1회
# 포비: 1회
# 돈: 1회
# 시린데: 1회
# 쎄게: 1회
# 심했기: 1회
# 모로: 1회
# 동행: 1회
# 감전: 1회
# 원치않으셔서: 1회
# 셨으: 1회
# 있으시다고: 1회
# 철저한: 1회
# 불편한건: 1회
# 선영: 1회
# 유방암: 1회
# 약하다고: 1회
# 명확: 1회
# 양제: 1회
# 많으셔서: 1회
# 리메이크: 1회
# 소하: 1회
# 약하신: 1회
# 없을시: 1회
# 좋으니: 1회
# 같진: 1회
# 경차: 1회
# 단술: 1회
# 일사이: 1회
# 느리긴: 1회
# 가능해: 1회
# 함임: 1회
# 적응하셔: 1회
# 부어있었던: 1회
# 비자: 1회
# 심하며: 1회
# 부근: 1회
# 일이: 1회
# 엄지: 1회
# 검지: 1회
# 끼기: 1회
# 몽유병: 1회
# 조사해: 1회
# 버칼: 1회
# 짧아서: 1회
# 심일: 1회
# 접수: 1회
# 선생: 1회
# 강화: 1회
# 심청: 1회
# 거인: 1회
# 성숙: 1회
# 괜찮아지셔서: 1회
# 달마: 1회
# 점검: 1회
# 잠시: 1회
# 근무시간: 1회
# 시라: 1회
# 동일한: 1회
# 류: 1회
# 오래되어서: 1회
# 가능하도록: 1회
# 로서: 1회
# 적응하고: 1회
# 계신것으로: 1회
# 불편하셔: 1회
# 작하시기로: 1회
# 실패: 1회
# 국내: 1회
# 국민은행: 1회
# 이자: 1회
# 상관없다고: 1회
# 함코골: 1회
# 쓰라린: 1회
# 종일: 1회
# 있으셨는지: 1회
# 심초진: 1회
# 힘드시고: 1회
# 헐거워졌다고하: 1회
# 괜찮았는데: 1회
# 있구요: 1회
# 강하신: 1회
# 있기로: 1회
# 스마일: 1회
# 반송: 1회
# 출중하: 1회
# 타이밍: 1회
# 도움: 1회
# 어지럽고: 1회
# 침범: 1회
# 뚜렷한: 1회
# 기쁨: 1회
# 요추: 1회
# 경추: 1회
# 보정: 1회
# 겸: 1회
# 달동: 1회
# 예상: 1회
# 불편하던건: 1회
# 피곤한건: 1회
# 아프게: 1회
# 이건: 1회
# 긴밀하여: 1회
# 작용: 1회
# 갈리: 1회
# 경도: 1회
# 부어있어: 1회
# 졸업: 1회
# 대표: 1회
# 심양: 1회
# 순이: 1회
# 조건: 1회
# 질병: 1회
# 문병원: 1회
# 원한: 1회
# 좋았다고: 1회
# 경: 1회
# 주지: 1회
# 예민해서: 1회
# 감별: 1회
# 경주: 1회
# 판정: 1회
# 있으므로: 1회
# 경로: 1회
# 압: 1회
# 부을수: 1회
# 더하기: 1회
# 성변화: 1회
# 디푸루칸: 1회
# 설신: 1회
# 테이: 1회
# 윗: 1회
# 가능한가요: 1회
# 아프: 1회
# 시대: 1회
# 낫다: 1회
# 애매할: 1회
# 편하신대로: 1회
# 많기: 1회
# 회메: 1회
# 힘들다고: 1회
# 년반: 1회
# 난포: 1회
# 트라우마: 1회
# 넓고: 1회
# 측두하악: 1회
# 간증: 1회
# 많으시다고: 1회
# 명확한: 1회
# 모튼: 1회
# 아보카도: 1회
# 소야: 1회
# 불검: 1회
# 물의: 1회
# 추출: 1회
# 괜찮은가요: 1회
# 중지: 1회
# 원안: 1회
# 안모: 1회
# 무거: 1회
# 꼭꼭: 1회
# 낫: 1회
# 이수경: 1회
# 심각: 1회
# 좋으나: 1회
# 불편함: 1회
# 힘듬: 1회
# 호: 1회
# 바쁜: 1회
# 약하시기로: 1회
# 맟추: 1회
# 얼룩덜룩한거: 1회
# 단시: 1회
# 조선희: 1회
# 있으셨다고: 1회
# 불편한데: 1회
# 볼쪽: 1회
# 욱신욱신하: 1회
# 아프셨다고: 1회
# 껌: 1회
# 계신것: 1회
# 선명해: 1회
# 힘드셨고: 1회
# 사량: 1회
# 후지: 1회
# 셈: 1회
# 치핑하악: 1회
# 안되더라도: 1회
# 부족해: 1회
# 창: 1회
# 심보: 1회
# 철물: 1회
# 없는건: 1회
# 아닌데: 1회
# 박병원: 1회
# 끈적끈적한: 1회
# 재수술: 1회
# 효능: 1회
# 있긴하지만: 1회
# 임도: 1회
# 많으신: 1회
# 없었다고: 1회
# 번전: 1회
# 납입: 1회
# 갯수: 1회
# 없는지: 1회
# 원하시며: 1회
# 약관: 1회
# 멀리: 1회
# 혼재: 1회
# 비굣: 1회
# 월동: 1회
# 수원: 1회
# 당산동: 1회
# 계시기: 1회
# 브: 1회
# 피린: 1회
# 평탄: 1회
# 가능해요: 1회
# 차량: 1회
# 선납: 1회
# 껀데: 1회
# 입도: 1회
# 링거: 1회
# 컨트롤: 1회
# 안되요: 1회
# 보철안: 1회
# 착각: 1회
# 다름: 1회
# 원하시는거: 1회
# 주랑: 1회
# 연차: 1회
# 괜찮다고하: 1회
# 뒷쪽: 1회
# 이상한: 1회
# 일어나서: 1회
# 뻐근하긴한데: 1회
# 토: 1회
# 안압: 1회
# 완전한: 1회
# 상적: 1회
# 있다면: 1회
# 불편하셨다고: 1회
# 성공: 1회
# 탈: 1회
# 신촌: 1회
# 하중: 1회
# 충분하시고: 1회
# 선명하지: 1회
# 연결해서: 1회
# 성은: 1회
# 찾기: 1회
# 류재원: 1회
# 단것: 1회
# 뜨거운것에는: 1회
# 시린것: 1회
# 과민성: 1회
# 없으시나: 1회
# 기록부: 1회
# 가능하므로: 1회
# 원치않으시는: 1회
# 삭: 1회
# 야하신다고: 1회
# 입벌: 1회
# 리기: 1회
# 힘들어요: 1회
# 아팠던: 1회
# 치과의사: 1회
# 가깝게: 1회
# 뉴욕: 1회
# 떡림: 1회
# 미완료: 1회
# 계시기로: 1회
# 상급: 1회
# 풀기: 1회
# 인슐린: 1회
# 도록: 1회
# 고름: 1회
# 악취: 1회
# 힘든: 1회
# 강하고: 1회
# 셨음: 1회
# 함교: 1회
# 합: 1회
# 조정은: 1회
# 상운: 1회
# 파절부: 1회
# 이로인해: 1회
# 예민할: 1회
# 그렇지: 1회
# 괜찮아지지만: 1회
# 피나: 1회
# 활동: 1회
# 식편: 1회
# 압입: 1회
# 있었으며: 1회
# 정은: 1회
# 함장: 1회
# 가해진: 1회
# 라이트: 1회
# 바세린: 1회
# 평가원: 1회
# 시렸다고: 1회
# 뜨거운것도: 1회
# 불편하긴: 1회
# 비슷하거나: 1회
# 그러셨거든요: 1회
# 가능하실: 1회
# 불가능함: 1회
# 윮: 1회
# 행시: 1회
# 시내: 1회
# 깨끗한: 1회
# 깨끗함: 1회
# 좌: 1회
# 미비하나: 1회
# 차차: 1회
# 론: 1회
# 연조직: 1회
# 낙: 1회
# 졸정: 1회
# 동구: 1회
# 오티렌: 1회
# 졸: 1회
# 피신: 1회
# 파이: 1회
# 불가피하게: 1회
# 습관화: 1회
# 있으시다면: 1회
# 곂침: 1회
# 앤지: 1회
# 프리: 1회
# 레옹: 1회
# 사랑: 1회
# 아프니: 1회
# 야한다: 1회
# 의해서: 1회
# 비슷한: 1회
# 그러한: 1회
# 안남: 1회
# 의향: 1회
# 면밀한: 1회
# 양지: 1회
# 한화: 1회
# 부족해서: 1회
# 정희: 1회
# 가능하셔서: 1회
# 슨약: 1회
# 경미하셔서: 1회
# 시려지시면: 1회
# 모에: 1회
# 동작: 1회
# 소아: 1회
# 번거로워: 1회
# 페리슨정: 1회
# 프로그램: 1회
# 행인: 1회
# 우동: 1회
# 가능해서: 1회
# 동일한가요: 1회
# 저녁식사: 1회
# 교과서: 1회
# 심각하면: 1회
# 깊게: 1회
# 심했음: 1회
# 시인: 1회
# 필요하면: 1회
# 시린니전용: 1회
# 불분명: 1회
# 높은: 1회
# 병무: 1회
# 용진: 1회
# 단서: 1회
# 료병: 1회
# 원보: 1회
# 험비: 1회
# 버컬쪽: 1회
# 안되었으면: 1회
# 상순: 1회
# 재채득: 1회
# 신날로: 1회
# 한의원: 1회
# 회보: 1회
# 전원: 1회
# 가능할가요: 1회
# 공공기관: 1회
# 여행가: 1회
# 애기: 1회
# 정지: 1회
# 어둡게: 1회
# 얇아: 1회
# 두드러기: 1회
# 결혼식: 1회
# 홍콩: 1회
# 여의도: 1회
# 수험생: 1회
# 상술: 1회
# 불규칙: 1회
# 돌기: 1회
# 정확: 1회
# 인후: 1회
# 흡연: 1회
# 전담: 1회
# 오래된: 1회
# 지도: 1회
# 설치: 1회
# 증명서: 1회
# 감호소: 1회
# 워터: 1회
# 픽: 1회
# 어감: 1회
# 리멤버: 1회
# 중간고사: 1회
# 어려워요: 1회
# 의지: 1회
# 강하: 1회
# 기관지: 1회
# 학업: 1회
# 표시: 1회
# 원하기로: 1회
# 파절및: 1회
# 비용떄문: 1회
# 헐겁지: 1회
# 준후: 1회
# 기다림: 1회
# 야할것: 1회
# 고경: 1회
# 엽: 1회
# 증약: 1회
# 헬스: 1회
# 피온: 1회
# 부프로피온: 1회
# 폭세틴: 1회
# 플루옥세틴: 1회
# 놀정: 1회
# 역전: 1회
# 투스잼: 1회
# 의안: 1회
# 미국여행: 1회
# 박나현: 1회
# 협진: 1회
# 간유: 1회
# 지용: 1회
# 식립후: 1회
# 척수염: 1회
# 살: 1회
# 잘생길: 1회
# 퀵: 1회
# 긴밀: 1회
# 이지: 1회
# 식스: 1회
# 불편했어서: 1회
# 파일럿: 1회
# 임야: 1회
# 빙: 1회
# 김병윤: 1회
# 친구사이: 1회
# 윤보현: 1회
# 조카: 1회
# 풀림: 1회
# 자궁: 1회
# 내막: 1회
# 목쪽: 1회
#
# === 영어 분석 결과 ===
# Dr: 43101회
# K: 35926회
# TMJ: 22534회
# CT: 12088회
# ck: 6918회
# Beam: 6256회
# Cone: 6255회
# SS: 4337회
# M: 4219회
# del: 3723회
# T: 3488회
# APS: 3481회
# Splint: 3434회
# scan: 3337회
# Conclusion: 3067회
# on: 2234회
# Lt: 1706회
# Rt: 1688회
# change: 1623회
# MMTT: 1596회
# G: 1437회
# free: 1359회
# line: 1314회
# cortical: 1181회
# flattening: 1162회
# erosive: 955회
# bite: 927회
# both: 864회
# sclerotic: 859회
# of: 755회
# unit: 682회
# Both: 672회
# osteophyte: 640회
# mg: 629회
# formation: 610회
# TMJs: 592회
# CA: 568회
# S: 529회
# open: 512회
# FREE: 474회
# mm: 462회
# DEL: 412회
# CK: 410회
# botox: 381회
# t: 350회
# imp: 348회
# x: 341회
# re: 330회
# ray: 327회
# B: 291회
# d: 280회
# with: 236회
# caries: 234회
# mmtt: 233회
# inlay: 229회
# F: 229회
# fx: 227회
# A: 224회
# PDRN: 223회
# O: 221회
# cr: 220회
# MM: 219회
# craze: 210회
# ss: 209회
# X: 191회
# TPI: 187회
# irregularity: 182회
# endo: 181회
# class: 181회
# o: 180회
# blurring: 171회
# midline: 163회
# crack: 157회
# MO: 148회
# diastema: 148회
# R: 148회
# shift: 148회
# r: 146회
# Botox: 144회
# Fx: 138회
# BOTOX: 134회
# pt: 132회
# ca: 126회
# crowding: 124회
# C: 123회
# adding: 120회
# P: 118회
# deformity: 118회
# lineLt: 111회
# Vericom: 111회
# U: 109회
# conformational: 107회
# f: 105회
# lt: 103회
# m: 101회
# incipient: 19회
# stiffness: 19회
# br: 19회
# lingual: 19회
# point: 19회
# Mob: 18회
# noise: 18회
# Open: 18회
# sclass: 18회
# LINE: 18회
# a: 17회
# mice: 17회
# occulsal: 17회
# joint: 16회
# Probing: 16회
# Co: 16회
# Paper: 16회
# Point: 16회
# MISSINGCLOSING: 16회
# metal: 16회
# OJ: 16회
# devation: 16회
# apico: 15회
# swelling: 15회
# polishing: 15회
# attrition: 15회
# amalgam: 15회
# Air: 15회
# changeblurring: 15회
# pa: 15회
# CO: 15회
# MOL: 15회
# RAY: 15회
# careis: 15회
# soft: 15회
# midlineshift: 15회
# GI: 15회
# GH: 15회
# CRAZE: 15회
# clear: 14회
# condyle: 14회
# ela: 14회
# cu: 14회
# NI: 14회
# TI: 14회
# FILE: 14회
# b: 14회
# TMJosteophyte: 14회
# relinning: 14회
# CLASS: 14회
# Protrusive: 14회
# Length: 14회
# CN: 14회
# tx: 13회
# TSCAN: 13회
# OCCLUSAL: 13회
# SENSOR: 13회
# hx: 13회
# DR: 13회
# CC: 13회
# remake: 13회
# tpi: 13회
# DB: 13회
# MOB: 13회
# Bruxism: 13회
# morning: 13회
# tenderpoint: 13회
# vital: 13회
# recession: 12회
# ADDING: 12회
# bleeding: 12회
# V: 12회
# v: 12회
# Caries: 12회
# Loding: 12회
# chagne: 12회
# flattenign: 12회
# Up: 12회
# sns: 12회
# tempolis: 12회
# temporalis: 12회
# AP: 12회
# RL: 12회
# contact: 11회
# pair: 11회
# crepitus: 11회
# pontic: 11회
# Ray: 11회
# dexa: 11회
# OK: 11회
# narrow: 11회
# canal: 11회
# changeconformational: 11회
# mobility: 11회
# incisal: 11회
# PMO: 11회
# lining: 11회
# refer: 11회
# VAS: 11회
# Abutment: 11회
# torus: 11회
# pal: 11회
# multiple: 11회
# lines: 11회
# mid: 10회
# eruption: 10회
# Gauze: 10회
# H: 10회
# TMJerosive: 10회
# perforation: 10회
# apical: 10회
# xray: 10회
# PA: 10회
# soreness: 10회
# check: 10회
# crown: 10회
# gold: 10회
# foramtion: 10회
# PDL: 10회
# widening: 10회
# Traction: 10회
# MIN: 10회
# sh: 10회
# HS: 10회
# ridg: 10회
# ing: 10회
# IMPL: 9회
# partial: 9회
# reception: 9회
# perforationca: 9회
# formationRt: 9회
# clenching: 9회
# laminate: 9회
# DIASTEMA: 9회
# pit: 9회
# roll: 9회
# max: 9회
# cycle: 9회
# Level: 9회
# Pick: 9회
# Hole: 9회
# Custom: 9회
# lateral: 9회
# joe: 9회
# bruxofacet: 9회
# Max: 9회
# masster: 9회
# non: 9회
# ant: 9회
# MI: 9회
# CRCO: 9회
# cariestwo: 9회
# Adding: 9회
# scm: 8회
# tooth: 8회
# Am: 8회
# sinus: 8회
# mucosal: 8회
# cahnge: 8회
# SCRP: 8회
# HEX: 8회
# moderate: 8회
# PANO: 8회
# impaction: 8회
# defect: 8회
# sclerosisLt: 8회
# RIVA: 8회
# HV: 8회
# upper: 8회
# pointclass: 8회
# Min: 8회
# Average: 8회
# Super: 2회
# Limitation: 2회
# shortening: 2회
# XDr: 2회
# horizontal: 2회
# remain: 2회
# referred: 2회
# mmcr: 2회
# length: 2회
# name: 2회
# Airway: 2회
# back: 2회
# TMJssclerotic: 2회
# sealing: 2회
# fomration: 2회
# TMJsr: 2회
# flare: 2회
# erygoid: 2회
# Impl: 2회
# bad: 2회
# TMJsconformational: 2회
# FUJI: 2회
# CEM: 2회
# Cu: 2회
# PI: 2회
# EDGE: 2회
# Diestma: 2회
# ederpointOpen: 2회
# cement: 2회
# ADD: 2회
# MAX: 2회
# Bitte: 2회
# MISSING: 2회
# perio: 1회
# complex: 1회
# lesionext: 1회
# TEMP: 1회
# euraption: 1회
# cottonroll: 1회
# CRca: 1회
# uTx: 1회
# xeno: 1회
# allo: 1회
# umbrella: 1회
# tech: 1회
# noti: 1회
# Exstemp: 1회
# ADr: 1회
# TMJfocal: 1회
# Opt: 1회
# formationnarrow: 1회
# formationjoint: 1회
# cetral: 1회
# formationconformational: 1회
# changenarrow: 1회
# discal: 1회
# cantilever: 1회
# jig: 1회
# FREECA: 1회
# Palatal: 1회
# sinusitits: 1회
# gingivectomy: 1회
# APR: 1회
# Set: 1회
# SET: 1회
# freeX: 1회
# calcipex: 1회
# sMAF: 1회
# sN: 1회
# shaping: 1회
# PDF: 1회
# partal: 1회
# lower: 1회
# lip: 1회
# fix: 1회
# NSAID: 1회
# cystosteophyte: 1회
# ee: 1회
# total: 1회
# oblique: 1회
# infraorbital: 1회
# nerve: 1회
# targeting: 1회
# PER: 1회
# Full: 1회
# cystRt: 1회
# medication: 1회
# redel: 1회
# changeloss: 1회
# SSdel: 1회
# formationthickening: 1회
# Implant: 1회
# plasty: 1회
# JAEYUN: 1회
# YOONFrederikssundsvej: 1회
# Broenshoj: 1회
# Denmark: 1회
# MTA: 1회
# liner: 1회
# cystic: 1회
# AS: 1회
# molars: 1회
# lineLeft: 1회
# inlaly: 1회
# lineapical: 1회
# involved: 1회
# periodontal: 1회
# base: 1회
# EDr: 1회
# TMJsostoephyte: 1회
# mandible: 1회
# erosifve: 1회
# hnjjj: 1회
# pi: 1회
# formationblurring: 1회
# bot: 1회
# hTMJs: 1회
# ostephyte: 1회
# long: 1회
# ostopehyte: 1회
# fc: 1회
# Delivery: 1회
# thickeing: 1회
# inay: 1회
# periodontitis: 1회
# sclerotsis: 1회
# condyel: 1회
# conydle: 1회
# delDr: 1회
# MOBEndo: 1회
# der: 1회
# Fermit: 1회
# csyt: 1회
# narrwo: 1회
# One: 1회
# surgeryflapless: 1회
# equi: 1회
# dre: 1회
# sEDr: 1회
# approach: 1회
# Occ: 1회
# ckpt: 1회
# Fax: 1회
# fxTx: 1회
# IFC: 1회
# erosieve: 1회
# BDr: 1회
# version: 1회
# REIMP: 1회
# TMJsnarrow: 1회
# airway: 1회
# pick: 1회
# meisal: 1회
# central: 1회
# gbr: 1회
# FREETT: 1회
# oestophyte: 1회
# MSS: 1회
# xop: 1회
# LIgual: 1회
# pressure: 1회
# Dx: 1회
# chair: 1회
# side: 1회
# XTx: 1회
# FC: 1회
# PDRNpt: 1회
# ulceration: 1회
# ABCDEABCDEDr: 1회
# eorisve: 1회
# fxpt: 1회
# proximal: 1회
# SSIPM: 1회
# cahgne: 1회
# Pain: 1회
# NO: 1회
# COUNT: 1회
# TMJserosive: 1회
# posteriro: 1회
# lamp: 1회
# osteophte: 1회
# abfraction: 1회
# reapair: 1회
# pedunculated: 1회
# papilloma: 1회
# crossbite: 1회
# orifice: 1회
# nego: 1회
# GG: 1회
# ci: 1회
# TMJsthickening: 1회
# Cross: 1회
# perp: 1회
# Retightening: 1회
# delsc: 1회
# cutting: 1회
# Freept: 1회
# cavity: 1회
# TMJfalttening: 1회
# TMJsjoint: 1회
# dorsum: 1회
# white: 1회
# papule: 1회
# vestibule: 1회
# reticulation: 1회
# FREESC: 1회
# counting: 1회
# Old: 1회
# am: 1회
# TMJconformational: 1회
# pulp: 1회
# TMJloss: 1회
# Cementt: 1회
# Overlay: 1회
# changeenlargement: 1회
# nasopalatine: 1회
# SOFT: 1회
# prpe: 1회
# Xre: 1회
# LA: 1회
# slcerosis: 1회
# condylar: 1회
# high: 1회
# canine: 1회
# slcerosisRt: 1회
# Imp: 1회
# Inay: 1회
# flapless: 1회
# stretching: 1회
# opening: 1회
# SNS: 1회
# needle: 1회
# frree: 1회
# trigger: 1회
# multipe: 1회
# tenderpointsL: 1회
# kimkm: 1회
# manipulation: 1회
# end: 1회
# feel: 1회
# clalss: 1회
# shape: 1회
# discreapancy: 1회
# that: 1회
# dry: 1회
# appearance: 1회
# PFG: 1회
# TMD: 1회
# freeck: 1회
# Suture: 1회
# osteopohyte: 1회
# curretage: 1회
# cm: 1회
# XCT: 1회
# panorama: 1회
# Craze: 1회
# clicking: 1회
# Deviationocclusal: 1회
# palpation: 1회
# cclusal: 1회
# Imidline: 1회
# limitation: 1회
# chip: 1회
# tmj: 1회
# extmidline: 1회
# tenderpointcotton: 1회
# file: 1회
# quicks: 1회
# rotated: 1회
# delNN: 1회
# Park: 1회
# kh: 1회
# hexa: 1회
# Lmidline: 1회
# occlusa: 1회
# lineclass: 1회
# TMJsfocal: 1회
# traction: 1회
# dehiscence: 1회
# IO: 1회
# TAKING: 1회
# Oj: 1회
# Ob: 1회
# purpation: 1회
# sharpening: 1회
# unhealthy: 1회
# capture: 1회
# OR: 1회
# eralry: 1회
# TMJsmild: 1회
# Tmj: 1회
# FS: 1회
# abrasion: 1회
# tscan: 1회
# black: 1회
# triangle: 1회
# kim: 1회
# ja: 1회
# XX: 1회
# lesionCT: 1회
# pairdistal: 1회
# REFER: 1회
# PM: 1회
# caze: 1회
# MTJ: 1회
# septal: 1회
# fujicem: 1회
# isp: 1회
# loosening: 1회
# shimstock: 1회
# toothosteopyte: 1회
# setting: 1회
# foodimpaction: 1회
# Scan: 1회
# scaler: 1회
# healing: 1회
# CAPSULEGI: 1회
# apc: 1회
# PPI: 1회
# final: 1회
# mental: 1회
# foramen: 1회
# dydrodissection: 1회
# points: 1회
# hypertrophy: 1회
# BOP: 1회
# TPIX: 1회
# postero: 1회
# superior: 1회
# san: 1회
# RCT: 1회
# Transfer: 1회
# conformationa: 1회
# delimplant: 1회
# vericom: 1회
# ssdel: 1회
# BP: 1회
# formastion: 1회
# fill: 1회
# flatening: 1회
# cK: 1회
# osteophyfe: 1회
# bondF: 1회
# Sur: 1회
# retention: 1회
# RC: 1회
# Prep: 1회
# discharge: 1회
# oro: 1회
# antral: 1회
# coronal: 1회
# caviton: 1회
# ceCC: 1회
# toothCone: 1회
# Dry: 1회
# Socket: 1회
# formaiton: 1회
# Midline: 1회
# ift: 1회
# Varicom: 1회
# very: 1회
# benign: 1회
# tumor: 1회
# joing: 1회
# miceflattening: 1회
# scNN: 1회
# poping: 1회
# goid: 1회
# OFP: 1회
# underbite: 1회
# JO: 1회
# JJ: 1회
# firbro: 1회
# ossous: 1회
# madible: 1회
# fibro: 1회
# osseous: 1회
# implantitisIPT: 1회
# failTx: 1회
# Nlingual: 1회
# gap: 1회
# allograft: 1회
# memb: 1회
# stain: 1회
# ostetophyte: 1회
# still: 1회
# knotsGBR: 1회
# muscosal: 1회
# buccinator: 1회
# pharyngeal: 1회
# Temp: 1회
# overjet: 1회
# onf: 1회
# single: 1회
# bondendo: 1회
# OL: 1회
# Panorama: 1회
# cpature: 1회
# VRF: 1회
# SMS: 1회
# CI: 1회
# impacition: 1회
# FREEMMTT: 1회
# lc: 1회
# TMJscelrosis: 1회
# fomraiton: 1회
# HAB: 1회
# THE: 1회
# GRAFT: 1회
# pfm: 1회
# maturation: 1회
# xTx: 1회
# FollowUp: 1회
# mobDr: 1회
# ckTx: 1회
# PSG: 1회
# freeDr: 1회
# narrowing: 1회
# iregularity: 1회
# wall: 1회
# other: 1회
# pathologic: 1회
# considerations: 1회
# saline: 1회
# smesial: 1회
# MDOB: 1회
# MEndo: 1회
# fax: 1회
# Ss: 1회
# Mesial: 1회
# Qray: 1회
# dital: 1회
# Rp: 1회
# flatting: 1회
# delss: 1회
# confomrational: 1회
# RDRN: 1회
# cortcia: 1회
# lline: 1회
# Retainer: 1회
# maxillary: 1회
# bubble: 1회
# corcital: 1회
# CHIN: 1회
# TO: 1회
# Vas: 1회
# atrophy: 1회
# sensor: 1회
# irrgularity: 1회
# Burr: 1회
# l: 1회
# lineconformational: 1회
# right: 1회
# p: 1회
# boneLt: 1회
# traumatic: 1회
# bony: 1회
# nodule: 1회
# slight: 1회
# effusionLt: 1회
# without: 1회
# WAX: 1회
# resorption: 1회
# thinning: 1회
# adjacent: 1회
# changeperiapical: 1회
# linLt: 1회
# Bone: 1회
# dexibuprofen: 1회
# Onlay: 1회
# porcelain: 1회
# Diastma: 1회

# %%
import requests
import json
import time
import os
from math import ceil

def chunk_large_text(text, max_bytes=4000000, overlap_chars=1000):
    """
    대용량 텍스트를 청크로 나누어 처리합니다.
    기존보다 더 작은 청크 크기 사용 (8MB → 4MB)
    
    Args:
        text (str): 전체 텍스트
        max_bytes (int): 각 청크의 최대 바이트 크기
        overlap_chars (int): 청크 간 중복되는 문자 수
    
    Returns:
        list: 텍스트 청크 목록
    """
    chunks = []
    
    # 전체 텍스트를 바이트로 변환
    text_bytes = text.encode('utf-8')
    total_bytes = len(text_bytes)
    
    if total_bytes <= max_bytes:
        return [text]
    
    # 청크 수 계산 (50% 중첩 고려)
    num_chunks = ceil(total_bytes / (max_bytes * 0.5))
    
    # 문자 단위로 나누기 위한 계산
    chars_per_chunk = len(text) // num_chunks
    
    # 청크 분할
    start = 0
    while start < len(text):
        # 다음 청크의 끝 위치 계산
        end = min(start + chars_per_chunk + overlap_chars, len(text))
        
        # 문장 경계를 찾기
        if end < len(text):
            # 마침표, 느낌표, 물음표 뒤에 공백이 있는 위치 찾기
            sentence_end = max(
                text.rfind('. ', start, end),
                text.rfind('! ', start, end),
                text.rfind('? ', start, end),
                text.rfind('\n\n', start, end)  # 단락 구분자도 추가
            )
            
            # 문장 경계가 있으면 그 위치로 끝 조정
            if sentence_end > start + chars_per_chunk // 2:
                end = sentence_end + 2  # 문장 끝 + 공백 포함
        
        # 청크 추가
        chunk = text[start:end]
        chunks.append(chunk)
        
        # 다음 청크의 시작점 (중복 고려)
        start = end - overlap_chars if end < len(text) else end
    
    return chunks

def process_tmj_text_with_claude(api_key, text_chunks, base_prompt):
    """
    텍스트 청크를 Claude API를 사용하여 처리합니다.
    
    Args:
        api_key (str): Anthropic API 키
        text_chunks (list): 텍스트 청크 목록
        base_prompt (str): 프롬프트 베이스 템플릿
    
    Returns:
        list: 각 청크의 분석 결과
    """
    all_results = []
    
    for i, chunk in enumerate(text_chunks):
        print(f"청크 {i+1}/{len(text_chunks)} 처리 중... ({len(chunk.encode('utf-8'))} 바이트)")
        
        # 청크 크기 확인
        chunk_bytes = len(chunk.encode('utf-8'))
        if chunk_bytes > 4500000:  # 4.5MB 제한 (더 작게 설정)
            print(f"경고: 청크 {i+1}이 너무 큽니다 ({chunk_bytes} 바이트). 더 작게 분할합니다.")
            sub_chunks = chunk_large_text(chunk, 4000000, 1000)
            sub_results = process_tmj_text_with_claude(api_key, sub_chunks, base_prompt)
            all_results.extend(sub_results)
            continue
        
        # 프롬프트 준비
        full_prompt = base_prompt.replace("{texts}", chunk)
        
        # API 요청 설정
        headers = {
            "Content-Type": "application/json",
            "x-api-key": api_key,
            "anthropic-version": "2023-06-01"
        }
        
        data = {
            "model": "claude-3-5-sonnet-20241022",
            "max_tokens": 4000,
            "temperature": 0,
            "system": "턱관절장애(TMJ) 진료 기록을 JSON 형식으로만 응답하세요. 설명이나 주석 없이 JSON 데이터만 반환하세요.",
            "messages": [
                {
                    "role": "user",
                    "content": full_prompt
                }
            ]
        }
        
        # API 요청
        try:
            response = requests.post(
                "https://api.anthropic.com/v1/messages",
                headers=headers,
                json=data
            )
            
            if response.status_code == 200:
                result = response.json()
                response_text = result['content'][0]['text']
                
                # 원시 응답 저장 (디버깅용)
                with open(f"tmj_raw_response_{i+1}.txt", "w", encoding="utf-8") as f:
                    f.write(response_text)
                
                # JSON 추출
                try:
                    # JSON 부분 추출 시도 (추출 방식 강화)
                    json_str = ""
                    
                    # 방법 1: ```json 코드 블록 찾기
                    if "```json" in response_text:
                        json_str = response_text.split("```json")[1].split("```")[0].strip()
                    
                    # 방법 2: 일반 ``` 코드 블록 찾기
                    elif "```" in response_text:
                        code_blocks = response_text.split("```")
                        # 첫 번째 코드 블록 내용 사용
                        if len(code_blocks) >= 3:  # 최소한 시작과 끝 태그가 있어야 함
                            json_str = code_blocks[1].strip()
                    
                    # 방법 3: 배열 형태 찾기 - 가장 바깥쪽 괄호 쌍 찾기
                    elif '[' in response_text and ']' in response_text:
                        start_idx = response_text.find('[')
                        end_idx = response_text.rfind(']') + 1
                        if start_idx != -1 and end_idx > start_idx:
                            json_str = response_text[start_idx:end_idx]
                    
                    # 방법 4: 객체 형태 찾기
                    elif '{' in response_text and '}' in response_text:
                        start_idx = response_text.find('{')
                        end_idx = response_text.rfind('}') + 1
                        if start_idx != -1 and end_idx > start_idx:
                            json_str = response_text[start_idx:end_idx]
                    
                    # JSON 문자열이 추출되었는지 확인
                    if json_str:
                        # 추출된 JSON 문자열 저장 (디버깅용)
                        with open(f"tmj_json_str_{i+1}.txt", "w", encoding="utf-8") as f:
                            f.write(json_str)
                        
                        # JSON 파싱
                        json_result = json.loads(json_str)
                        
                        # 결과가 리스트인지 확인하고 적절히 처리
                        if isinstance(json_result, list):
                            all_results.extend(json_result)
                            print(f"청크 {i+1}: {len(json_result)}개 항목 추출 성공")
                        else:
                            all_results.append(json_result)
                            print(f"청크 {i+1}: 1개 항목 추출 성공")
                        
                        # 결과 저장 (청크별)
                        with open(f"tmj_results_chunk_{i+1}.json", "w", encoding="utf-8") as f:
                            json.dump(json_result, f, ensure_ascii=False, indent=2)
                    else:
                        print(f"청크 {i+1}에서 JSON을 찾을 수 없습니다.")
                        # 2차 시도: 더 작은 청크로 분할
                        if len(chunk) > 2000:
                            print("더 작은 청크로 분할하여 재시도합니다.")
                            mid = len(chunk) // 2
                            # 문장 경계 찾기
                            boundary = max(
                                chunk.rfind('. ', 0, mid),
                                chunk.rfind('! ', 0, mid),
                                chunk.rfind('? ', 0, mid),
                                chunk.rfind('\n\n', 0, mid)
                            )
                            
                            if boundary > 0:
                                mid = boundary + 2
                            
                            sub_chunks = [chunk[:mid], chunk[mid:]]
                            sub_results = process_tmj_text_with_claude(api_key, sub_chunks, base_prompt)
                            all_results.extend(sub_results)
                
                except (json.JSONDecodeError, IndexError) as e:
                    print(f"청크 {i+1} JSON 파싱 오류: {str(e)}")
                    print("오류가 발생한 JSON 문자열의 일부:")
                    if json_str:
                        print(json_str[:100] + "..." if len(json_str) > 100 else json_str)
                    
                    # 기본 중첩 구조 수정 시도
                    if json_str:
                        try:
                            # 중첩된 따옴표 이스케이프 문제 수정 시도
                            fixed_json = json_str.replace('\\"', '"').replace('\\\\', '\\')
                            json_result = json.loads(fixed_json)
                            
                            if isinstance(json_result, list):
                                all_results.extend(json_result)
                                print(f"청크 {i+1}: 수정 후 {len(json_result)}개 항목 추출 성공")
                            else:
                                all_results.append(json_result)
                                print(f"청크 {i+1}: 수정 후 1개 항목 추출 성공")
                            
                            with open(f"tmj_results_chunk_{i+1}_fixed.json", "w", encoding="utf-8") as f:
                                json.dump(json_result, f, ensure_ascii=False, indent=2)
                        except json.JSONDecodeError:
                            print("JSON 수정 시도 실패")
            else:
                print(f"청크 {i+1} 에러 코드: {response.status_code}")
                print(f"에러 메시지: {response.text}")
        
        except Exception as e:
            print(f"청크 {i+1} 예외 발생: {str(e)}")
        
        # API 요청 간 딜레이
        if i < len(text_chunks) - 1:
            time.sleep(2)
    
    return all_results

# 원본 프롬프트 템플릿 유지 (요청에 따라 프롬프트를 줄이지 않음)
tmj_prompt_template = """
다음은 턱관절장애(TMJ) 및 저작근 장애에 대한 진료 기록(PI 텍스트)입니다. 
문서에는 K07.65(퇴행성 관절염), K07.66(저작근의 장애), K07.63(턱관절 통증) 등의 진단 코드, 
파노라마/CT 촬영, 측두하악장애분석검사, 물리치료, 약물 처방, 경과 관찰 등의 내용이 포함될 수 있습니다.

아래 텍스트를 분석하여, 다음 14개 필드를 JSON 형식으로 추출해주세요:

1. onset (발현 시기)  
- 예: "3개월 전", "2023년 1월", "발병 시기 미상"  
- 텍스트에서 구체적으로 언급된 경우만 추출하고, 없으면 `""`(빈 문자열)

2. pattern (증상 양상)  
- "constant" (지속성), "intermittent" (간헐성), "progressive" (점진적 악화)  
- 명확히 언급된 경우에만 지정. 없으면 `""`

3. aggravating_factors (악화 요인 목록, 배열)  
- 예: ["딱딱한 음식", "스트레스", "이 악물기"]  
- 여러 개라면 배열에 순서대로 담고, 없으면 `[]`

4. status (현재 상태)  
- "improving" (호전), "unchanged" (변화 없음), "worsening" (악화)  
- 명시되지 않으면 `""`

5. TMJ_PI_desc (진단/검사 항목, 배열)  
- 파노라마, CT, 측두하악장애분석검사, 초음파, T-scan 등 실시된 검사 이름을 배열로 적습니다.  
- 예: ["파노라마", "Cone Beam CT"]

6. TMJ_PI_treatment (물리치료 항목, 배열)  
- 분사신장치료, 전기자극치료, 복합자극치료, 물리치료 등  
- 예: ["측두하악관절자극요법-단순", "분사신장치료"]

7. drug_treatment (약물치료 항목, 배열)  
- 예: ["소론도정(프레드니솔론)", "페리슨정(에페리손염산염)"]  
- 복용 방법, 용량, 횟수 등은 이 필드가 아닌 `medication_prescription`에 기입

8. closing_dentalgear_desc (교합치료 항목, 배열)  
- 교합안정장치(Splint), 교합조정, 보톡스(교합개선 목적) 등 교합 관련 치료가 있으면 적습니다.  
- 없으면 `[]`

9. PI_check (경과관찰 항목, 배열)  
- "증상 체크 [2주후]", "1개월 후 재내원", "재평가 예정" 등 주기적 검진/재평가 계획  
- 예: ["증상 ck [2주후]"]

10. PI_diagnosis_jojint (턱관절 진단 내용, 문자열)  
- K07.65 퇴행성 관절염, K07.63 턱관절 통증, K07.66 저작근 장애 등 진단명  
- 예: "퇴행성 관절염 (K07.65)"

11. physical_therapy (저작근 장애(K07.66) 물리치료 등, 문자열)  
- 저작근 장애를 치료하기 위해 시행된 물리치료나 자극요법(단순/전기/복합), 분사신장치료 등의 종합 요약  
- 예: "측두하악관절 단순/전기/복합 자극, 분사신장치료"

12. occlusal_treatment (교합안정장치(Splint) 등 장치치료, 문자열)  
- 예: "APS, SS 장치 장착 및 조정"  
- 교합 조정, 장치 제작 등

13. medication_prescription (약물 처방 상세, 문자열)  
- "페리슨정(에페리손염산염) 1/1회/14일 :: 취침 직전 복용" 처럼, 복용 용법/횟수/기간 등을 구체적으로 적습니다.  
- 여러 개라면 문장으로 나열  
- 예: "페리슨정(에페리손염산염) - 1/1회/14일, 소론도정(프레드니솔론) - 1/1회/14일"

14. other_treatment (그 외 보톡스 시술, 악관절 강세척술, 교합조정, 발치 등, 문자열)  
- "보톡스 시술" 등  
- 텍스트에서 확인되면 구체적으로 작성, 없으면 `""`

응답은 다음과 같이 JSON 배열 형태로 주세요:
```json
[
  {
    "onset": "...",
    "pattern": "...",
    "aggravating_factors": [...],
    "status": "...",
    "TMJ_PI_desc": [...],
    "TMJ_PI_treatment": [...],
    "drug_treatment": [...],
    "closing_dentalgear_desc": [...],
    "PI_check": [...],
    "PI_diagnosis_jojint": "...",
    "physical_therapy": "...",
    "occlusal_treatment": "...",
    "medication_prescription": "...",
    "other_treatment": "..."
  }
]
```

설명이나 주석 없이 JSON만 반환해주세요.

분석할 텍스트:
{texts}
"""

# 분석 결과 통합
def combine_tmj_results(results):
    """
    여러 청크의 TMJ 분석 결과를 하나로 통합합니다.
    
    Args:
        results (list): 각 청크의 분석 결과 목록
    
    Returns:
        list: 통합된 분석 결과
    """
    # 단순히 모든 결과를 합치기
    return results

# 누락된 청크 결과 통합
def combine_chunk_files():
    """
    개별적으로 저장된 청크 결과 파일들을 통합합니다.
    """
    all_results = []
    
    # tmj_results_chunk_*.json 파일 찾기
    chunk_files = [f for f in os.listdir('.') if f.startswith('tmj_results_chunk_') and f.endswith('.json')]
    chunk_files.sort(key=lambda x: int(x.split('_')[-1].split('.')[0]))
    
    if not chunk_files:
        print("청크 결과 파일을 찾을 수 없습니다.")
        return all_results
    
    print(f"{len(chunk_files)}개의 청크 결과 파일을 통합합니다.")
    
    for file_name in chunk_files:
        try:
            with open(file_name, 'r', encoding='utf-8') as f:
                chunk_result = json.load(f)
            
            if isinstance(chunk_result, list):
                all_results.extend(chunk_result)
                print(f"{file_name}: {len(chunk_result)}개 항목 추가")
            else:
                all_results.append(chunk_result)
                print(f"{file_name}: 1개 항목 추가")
        
        except Exception as e:
            print(f"{file_name} 처리 중 오류 발생: {str(e)}")
    
    # 결과 저장
    with open('tmj_analysis_combined.json', 'w', encoding='utf-8') as f:
        json.dump(all_results, f, ensure_ascii=False, indent=2)
    
    print(f"통합 완료. 총 {len(all_results)}개 항목이 tmj_analysis_combined.json에 저장되었습니다.")
    
    return all_results

# 메인 프로그램
def process_large_tmj_text(api_key, pi_text, output_file):
    """
    대용량 TMJ 텍스트를 처리합니다.
    
    Args:
        api_key (str): Anthropic API 키
        output_file (str): 출력 JSON 파일 경로
    """
    # pi_text 변수 사용 (글로벌 변수로 가정)
    # 텍스트를 청크로 분할 (더 작은 크기로)
    chunks = chunk_large_text(pi_text, max_bytes=4000000, overlap_chars=1000)
    print(f"텍스트가 {len(chunks)}개 청크로 분할되었습니다.")
    
    # 각 청크 크기 출력
    for i, chunk in enumerate(chunks):
        chunk_bytes = len(chunk.encode('utf-8'))
        print(f"청크 {i+1}: {chunk_bytes:,} 바이트 ({chunk_bytes/1024/1024:.2f} MB)")
    
    # Claude API로 텍스트 처리 (원본 프롬프트 사용)
    print("\n텍스트 분석 시작...")
    results = process_tmj_text_with_claude(api_key, chunks, tmj_prompt_template)
    
    # 결과 통합
    combined_results = combine_tmj_results(results)
    
    # 결과 저장
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(combined_results, f, ensure_ascii=False, indent=2)
    
    print(f"\n분석 완료! 결과가 {output_file}에 저장되었습니다.")
    print(f"총 {len(combined_results)}개의 TMJ 진료 기록이 분석되었습니다.")
    
    # 결과가 없는 경우 파일 통합 시도
    if len(combined_results) == 0:
        print("\n자동으로 청크 파일 통합을 시도합니다...")
        combine_chunk_files()

# 사용 예시
if __name__ == "__main__":
    api_key = api_key
    
    # 텍스트 파일에서 읽기
    
    output_file = "tmj_analysis.json"
    
    # try:
    #     with open(input_file, 'r', encoding='utf-8') as f:
    #         input_text = f.read()
        
    process_large_tmj_text(api_key, pi_text, output_file)
    
        # 이미 생성된 파일 통합 시도
    print("\n파일 통합을 시도합니다...")
    combine_chunk_files()
# Out:
# 텍스트가 7개 청크로 분할되었습니다.
# 청크 1: 1,698,453 바이트 (1.62 MB)
# 청크 2: 1,728,109 바이트 (1.65 MB)
# 청크 3: 1,762,428 바이트 (1.68 MB)
# 청크 4: 1,755,255 바이트 (1.67 MB)
# 청크 5: 1,787,476 바이트 (1.70 MB)
# 청크 6: 1,696,800 바이트 (1.62 MB)
# 청크 7: 150,463 바이트 (0.14 MB)
#
# 텍스트 분석 시작...
# 청크 1/7 처리 중... (1698453 바이트)
# 청크 1 에러 코드: 520
# 에러 메시지: <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
#
# <title>api.anthropic.com | 520: Web server is returning an unknown error</title>
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/main.css" />
#
#
# </head>
# <body>
# <div id="cf-wrapper">
#     <div id="cf-error-details" class="p-0">
#         <header class="mx-auto pt-10 lg:pt-6 lg:px-8 w-240 lg:w-full mb-8">
#             <h1 class="inline-block sm:block sm:mb-2 font-light text-60 lg:text-4xl text-black-dark leading-tight mr-2">
#               <span class="inline-block">Web server is returning an unknown error</span>
#               <span class="code-label">Error code 520</span>
#             </h1>
#             <div>
#                Visit <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">cloudflare.com</a> for more information.
#             </div>
#             <div class="mt-3">2025-02-24 14:25:48 UTC</div>
#         </header>
#         <div class="my-8 bg-gradient-gray">
#             <div class="w-240 lg:w-full mx-auto">
#                 <div class="clearfix md:px-8">
#
# <div id="cf-browser-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-browser block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">You</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Browser
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-cloudflare-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">
#     <span class="cf-icon-cloud block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#     </a>
#   </div>
#   <span class="md:block w-full truncate">Seoul</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">
#     Cloudflare
#     </a>
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-host-status" class="cf-error-source relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-server block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-error w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">api.anthropic.com</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Host
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-red-error">Error</span>
# </div>
#
#                 </div>
#             </div>
#         </div>
#
#         <div class="w-240 lg:w-full mx-auto mb-8 lg:px-8">
#             <div class="clearfix">
#                 <div class="w-1/2 md:w-full float-left pr-6 md:pb-10 md:pr-0 leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What happened?</h2>
#                     <p>There is an unknown connection issue between Cloudflare and the origin web server. As a result, the web page can not be displayed.</p>
#                 </div>
#                 <div class="w-1/2 md:w-full float-left leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What can I do?</h2>
#                           <h3 class="text-15 font-semibold mb-2">If you are a visitor of this website:</h3>
#       <p class="mb-6">Please try again in a few minutes.</p>
#
#       <h3 class="text-15 font-semibold mb-2">If you are the owner of this website:</h3>
#       <p><span>There is an issue between Cloudflare's cache and your origin web server. Cloudflare monitors for these errors and automatically investigates the cause. To help support the investigation, you can pull the corresponding error log from your web server and submit it our support team.  Please include the Ray ID (which is at the bottom of this error page).</span> <a rel="noopener noreferrer" href="https://support.cloudflare.com/hc/en-us/articles/200171936-Error-520">Additional troubleshooting resources</a>.</p>
#                 </div>
#             </div>
#         </div>
#
#         <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">917020827fb8307f</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">211.208.22.129</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
# </div>
# </body>
# </html>
#
# 청크 2/7 처리 중... (1728109 바이트)
# 청크 2 에러 코드: 520
# 에러 메시지: <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
#
# <title>api.anthropic.com | 520: Web server is returning an unknown error</title>
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/main.css" />
#
#
# </head>
# <body>
# <div id="cf-wrapper">
#     <div id="cf-error-details" class="p-0">
#         <header class="mx-auto pt-10 lg:pt-6 lg:px-8 w-240 lg:w-full mb-8">
#             <h1 class="inline-block sm:block sm:mb-2 font-light text-60 lg:text-4xl text-black-dark leading-tight mr-2">
#               <span class="inline-block">Web server is returning an unknown error</span>
#               <span class="code-label">Error code 520</span>
#             </h1>
#             <div>
#                Visit <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">cloudflare.com</a> for more information.
#             </div>
#             <div class="mt-3">2025-02-24 14:25:51 UTC</div>
#         </header>
#         <div class="my-8 bg-gradient-gray">
#             <div class="w-240 lg:w-full mx-auto">
#                 <div class="clearfix md:px-8">
#
# <div id="cf-browser-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-browser block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">You</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Browser
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-cloudflare-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">
#     <span class="cf-icon-cloud block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#     </a>
#   </div>
#   <span class="md:block w-full truncate">Seoul</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">
#     Cloudflare
#     </a>
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-host-status" class="cf-error-source relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-server block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-error w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">api.anthropic.com</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Host
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-red-error">Error</span>
# </div>
#
#                 </div>
#             </div>
#         </div>
#
#         <div class="w-240 lg:w-full mx-auto mb-8 lg:px-8">
#             <div class="clearfix">
#                 <div class="w-1/2 md:w-full float-left pr-6 md:pb-10 md:pr-0 leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What happened?</h2>
#                     <p>There is an unknown connection issue between Cloudflare and the origin web server. As a result, the web page can not be displayed.</p>
#                 </div>
#                 <div class="w-1/2 md:w-full float-left leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What can I do?</h2>
#                           <h3 class="text-15 font-semibold mb-2">If you are a visitor of this website:</h3>
#       <p class="mb-6">Please try again in a few minutes.</p>
#
#       <h3 class="text-15 font-semibold mb-2">If you are the owner of this website:</h3>
#       <p><span>There is an issue between Cloudflare's cache and your origin web server. Cloudflare monitors for these errors and automatically investigates the cause. To help support the investigation, you can pull the corresponding error log from your web server and submit it our support team.  Please include the Ray ID (which is at the bottom of this error page).</span> <a rel="noopener noreferrer" href="https://support.cloudflare.com/hc/en-us/articles/200171936-Error-520">Additional troubleshooting resources</a>.</p>
#                 </div>
#             </div>
#         </div>
#
#         <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">917020941db8ba57</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">211.208.22.129</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
# </div>
# </body>
# </html>
#
# 청크 3/7 처리 중... (1762428 바이트)
# 청크 3 에러 코드: 520
# 에러 메시지: <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
#
# <title>api.anthropic.com | 520: Web server is returning an unknown error</title>
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/main.css" />
#
#
# </head>
# <body>
# <div id="cf-wrapper">
#     <div id="cf-error-details" class="p-0">
#         <header class="mx-auto pt-10 lg:pt-6 lg:px-8 w-240 lg:w-full mb-8">
#             <h1 class="inline-block sm:block sm:mb-2 font-light text-60 lg:text-4xl text-black-dark leading-tight mr-2">
#               <span class="inline-block">Web server is returning an unknown error</span>
#               <span class="code-label">Error code 520</span>
#             </h1>
#             <div>
#                Visit <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">cloudflare.com</a> for more information.
#             </div>
#             <div class="mt-3">2025-02-24 14:25:54 UTC</div>
#         </header>
#         <div class="my-8 bg-gradient-gray">
#             <div class="w-240 lg:w-full mx-auto">
#                 <div class="clearfix md:px-8">
#
# <div id="cf-browser-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-browser block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">You</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Browser
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-cloudflare-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">
#     <span class="cf-icon-cloud block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#     </a>
#   </div>
#   <span class="md:block w-full truncate">Seoul</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">
#     Cloudflare
#     </a>
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-host-status" class="cf-error-source relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-server block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-error w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">api.anthropic.com</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Host
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-red-error">Error</span>
# </div>
#
#                 </div>
#             </div>
#         </div>
#
#         <div class="w-240 lg:w-full mx-auto mb-8 lg:px-8">
#             <div class="clearfix">
#                 <div class="w-1/2 md:w-full float-left pr-6 md:pb-10 md:pr-0 leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What happened?</h2>
#                     <p>There is an unknown connection issue between Cloudflare and the origin web server. As a result, the web page can not be displayed.</p>
#                 </div>
#                 <div class="w-1/2 md:w-full float-left leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What can I do?</h2>
#                           <h3 class="text-15 font-semibold mb-2">If you are a visitor of this website:</h3>
#       <p class="mb-6">Please try again in a few minutes.</p>
#
#       <h3 class="text-15 font-semibold mb-2">If you are the owner of this website:</h3>
#       <p><span>There is an issue between Cloudflare's cache and your origin web server. Cloudflare monitors for these errors and automatically investigates the cause. To help support the investigation, you can pull the corresponding error log from your web server and submit it our support team.  Please include the Ray ID (which is at the bottom of this error page).</span> <a rel="noopener noreferrer" href="https://support.cloudflare.com/hc/en-us/articles/200171936-Error-520">Additional troubleshooting resources</a>.</p>
#                 </div>
#             </div>
#         </div>
#
#         <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">917020a59925305a</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">211.208.22.129</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
# </div>
# </body>
# </html>
#
# 청크 4/7 처리 중... (1755255 바이트)
# 청크 4 에러 코드: 520
# 에러 메시지: <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
#
# <title>api.anthropic.com | 520: Web server is returning an unknown error</title>
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/main.css" />
#
#
# </head>
# <body>
# <div id="cf-wrapper">
#     <div id="cf-error-details" class="p-0">
#         <header class="mx-auto pt-10 lg:pt-6 lg:px-8 w-240 lg:w-full mb-8">
#             <h1 class="inline-block sm:block sm:mb-2 font-light text-60 lg:text-4xl text-black-dark leading-tight mr-2">
#               <span class="inline-block">Web server is returning an unknown error</span>
#               <span class="code-label">Error code 520</span>
#             </h1>
#             <div>
#                Visit <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">cloudflare.com</a> for more information.
#             </div>
#             <div class="mt-3">2025-02-24 14:25:56 UTC</div>
#         </header>
#         <div class="my-8 bg-gradient-gray">
#             <div class="w-240 lg:w-full mx-auto">
#                 <div class="clearfix md:px-8">
#
# <div id="cf-browser-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-browser block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">You</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Browser
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-cloudflare-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">
#     <span class="cf-icon-cloud block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#     </a>
#   </div>
#   <span class="md:block w-full truncate">Seoul</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">
#     Cloudflare
#     </a>
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-host-status" class="cf-error-source relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-server block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-error w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">api.anthropic.com</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Host
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-red-error">Error</span>
# </div>
#
#                 </div>
#             </div>
#         </div>
#
#         <div class="w-240 lg:w-full mx-auto mb-8 lg:px-8">
#             <div class="clearfix">
#                 <div class="w-1/2 md:w-full float-left pr-6 md:pb-10 md:pr-0 leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What happened?</h2>
#                     <p>There is an unknown connection issue between Cloudflare and the origin web server. As a result, the web page can not be displayed.</p>
#                 </div>
#                 <div class="w-1/2 md:w-full float-left leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What can I do?</h2>
#                           <h3 class="text-15 font-semibold mb-2">If you are a visitor of this website:</h3>
#       <p class="mb-6">Please try again in a few minutes.</p>
#
#       <h3 class="text-15 font-semibold mb-2">If you are the owner of this website:</h3>
#       <p><span>There is an issue between Cloudflare's cache and your origin web server. Cloudflare monitors for these errors and automatically investigates the cause. To help support the investigation, you can pull the corresponding error log from your web server and submit it our support team.  Please include the Ray ID (which is at the bottom of this error page).</span> <a rel="noopener noreferrer" href="https://support.cloudflare.com/hc/en-us/articles/200171936-Error-520">Additional troubleshooting resources</a>.</p>
#                 </div>
#             </div>
#         </div>
#
#         <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">917020b66e75d1dd</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">211.208.22.129</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
# </div>
# </body>
# </html>
#
# 청크 5/7 처리 중... (1787476 바이트)
# 청크 5 에러 코드: 520
# 에러 메시지: <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
#
# <title>api.anthropic.com | 520: Web server is returning an unknown error</title>
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/main.css" />
#
#
# </head>
# <body>
# <div id="cf-wrapper">
#     <div id="cf-error-details" class="p-0">
#         <header class="mx-auto pt-10 lg:pt-6 lg:px-8 w-240 lg:w-full mb-8">
#             <h1 class="inline-block sm:block sm:mb-2 font-light text-60 lg:text-4xl text-black-dark leading-tight mr-2">
#               <span class="inline-block">Web server is returning an unknown error</span>
#               <span class="code-label">Error code 520</span>
#             </h1>
#             <div>
#                Visit <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">cloudflare.com</a> for more information.
#             </div>
#             <div class="mt-3">2025-02-24 14:25:59 UTC</div>
#         </header>
#         <div class="my-8 bg-gradient-gray">
#             <div class="w-240 lg:w-full mx-auto">
#                 <div class="clearfix md:px-8">
#
# <div id="cf-browser-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-browser block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">You</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Browser
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-cloudflare-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">
#     <span class="cf-icon-cloud block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#     </a>
#   </div>
#   <span class="md:block w-full truncate">Seoul</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">
#     Cloudflare
#     </a>
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-host-status" class="cf-error-source relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-server block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-error w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">api.anthropic.com</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Host
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-red-error">Error</span>
# </div>
#
#                 </div>
#             </div>
#         </div>
#
#         <div class="w-240 lg:w-full mx-auto mb-8 lg:px-8">
#             <div class="clearfix">
#                 <div class="w-1/2 md:w-full float-left pr-6 md:pb-10 md:pr-0 leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What happened?</h2>
#                     <p>There is an unknown connection issue between Cloudflare and the origin web server. As a result, the web page can not be displayed.</p>
#                 </div>
#                 <div class="w-1/2 md:w-full float-left leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What can I do?</h2>
#                           <h3 class="text-15 font-semibold mb-2">If you are a visitor of this website:</h3>
#       <p class="mb-6">Please try again in a few minutes.</p>
#
#       <h3 class="text-15 font-semibold mb-2">If you are the owner of this website:</h3>
#       <p><span>There is an issue between Cloudflare's cache and your origin web server. Cloudflare monitors for these errors and automatically investigates the cause. To help support the investigation, you can pull the corresponding error log from your web server and submit it our support team.  Please include the Ray ID (which is at the bottom of this error page).</span> <a rel="noopener noreferrer" href="https://support.cloudflare.com/hc/en-us/articles/200171936-Error-520">Additional troubleshooting resources</a>.</p>
#                 </div>
#             </div>
#         </div>
#
#         <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">917020c73d03eaa5</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">211.208.22.129</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
# </div>
# </body>
# </html>
#
# 청크 6/7 처리 중... (1696800 바이트)
# 청크 6 에러 코드: 520
# 에러 메시지: <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
#
#
# <title>api.anthropic.com | 520: Web server is returning an unknown error</title>
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/main.css" />
#
#
# </head>
# <body>
# <div id="cf-wrapper">
#     <div id="cf-error-details" class="p-0">
#         <header class="mx-auto pt-10 lg:pt-6 lg:px-8 w-240 lg:w-full mb-8">
#             <h1 class="inline-block sm:block sm:mb-2 font-light text-60 lg:text-4xl text-black-dark leading-tight mr-2">
#               <span class="inline-block">Web server is returning an unknown error</span>
#               <span class="code-label">Error code 520</span>
#             </h1>
#             <div>
#                Visit <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">cloudflare.com</a> for more information.
#             </div>
#             <div class="mt-3">2025-02-24 14:26:02 UTC</div>
#         </header>
#         <div class="my-8 bg-gradient-gray">
#             <div class="w-240 lg:w-full mx-auto">
#                 <div class="clearfix md:px-8">
#
# <div id="cf-browser-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-browser block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">You</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Browser
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-cloudflare-status" class=" relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">
#     <span class="cf-icon-cloud block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-ok w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#     </a>
#   </div>
#   <span class="md:block w-full truncate">Seoul</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#     <a href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" target="_blank" rel="noopener noreferrer">
#     Cloudflare
#     </a>
#   </h3>
#   <span class="leading-1.3 text-2xl text-green-success">Working</span>
# </div>
#
# <div id="cf-host-status" class="cf-error-source relative w-1/3 md:w-full py-15 md:p-0 md:py-8 md:text-left md:border-solid md:border-0 md:border-b md:border-gray-400 overflow-hidden float-left md:float-none text-center">
#   <div class="relative mb-10 md:m-0">
#
#     <span class="cf-icon-server block md:hidden h-20 bg-center bg-no-repeat"></span>
#     <span class="cf-icon-error w-12 h-12 absolute left-1/2 md:left-auto md:right-0 md:top-0 -ml-6 -bottom-4"></span>
#
#   </div>
#   <span class="md:block w-full truncate">api.anthropic.com</span>
#   <h3 class="md:inline-block mt-3 md:mt-0 text-2xl text-gray-600 font-light leading-1.3">
#
#     Host
#
#   </h3>
#   <span class="leading-1.3 text-2xl text-red-error">Error</span>
# </div>
#
#                 </div>
#             </div>
#         </div>
#
#         <div class="w-240 lg:w-full mx-auto mb-8 lg:px-8">
#             <div class="clearfix">
#                 <div class="w-1/2 md:w-full float-left pr-6 md:pb-10 md:pr-0 leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What happened?</h2>
#                     <p>There is an unknown connection issue between Cloudflare and the origin web server. As a result, the web page can not be displayed.</p>
#                 </div>
#                 <div class="w-1/2 md:w-full float-left leading-relaxed">
#                     <h2 class="text-3xl font-normal leading-1.3 mb-4">What can I do?</h2>
#                           <h3 class="text-15 font-semibold mb-2">If you are a visitor of this website:</h3>
#       <p class="mb-6">Please try again in a few minutes.</p>
#
#       <h3 class="text-15 font-semibold mb-2">If you are the owner of this website:</h3>
#       <p><span>There is an issue between Cloudflare's cache and your origin web server. Cloudflare monitors for these errors and automatically investigates the cause. To help support the investigation, you can pull the corresponding error log from your web server and submit it our support team.  Please include the Ray ID (which is at the bottom of this error page).</span> <a rel="noopener noreferrer" href="https://support.cloudflare.com/hc/en-us/articles/200171936-Error-520">Additional troubleshooting resources</a>.</p>
#                 </div>
#             </div>
#         </div>
#
#         <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#   <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">917020d88f30a7de</strong></span>
#     <span class="cf-footer-separator sm:hidden">&bull;</span>
#     <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">
#       Your IP:
#       <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>
#       <span class="hidden" id="cf-footer-ip">211.208.22.129</span>
#       <span class="cf-footer-separator sm:hidden">&bull;</span>
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing?utm_source=errorcode_520&utm_campaign=api.anthropic.com" id="brand_link" target="_blank">Cloudflare</a></span>
#
#   </p>
#   <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
#
#
#     </div>
# </div>
# </body>
# </html>
#
# 청크 7/7 처리 중... (150463 바이트)
# 청크 7 에러 코드: 401
# 에러 메시지: {"type":"error","error":{"type":"authentication_error","message":"x-api-key header is required"}}
#
# 분석 완료! 결과가 tmj_analysis.json에 저장되었습니다.
# 총 0개의 TMJ 진료 기록이 분석되었습니다.
#
# 자동으로 청크 파일 통합을 시도합니다...
# 1개의 청크 결과 파일을 통합합니다.
# tmj_results_chunk_4.json: 1개 항목 추가
# 통합 완료. 총 1개 항목이 tmj_analysis_combined.json에 저장되었습니다.
#
# 파일 통합을 시도합니다...
# 1개의 청크 결과 파일을 통합합니다.
# tmj_results_chunk_4.json: 1개 항목 추가
# 통합 완료. 총 1개 항목이 tmj_analysis_combined.json에 저장되었습니다.

# %%
import requests
import json
import time
import os
from math import ceil

def chunk_large_text(text, max_bytes=500000, overlap_chars=1000):
    """
    대용량 텍스트를 청크로 나누어 처리합니다.
    4MB보다 훨씬 작은 청크 크기 사용 (500KB로 설정)
    
    Args:
        text (str): 전체 텍스트
        max_bytes (int): 각 청크의 최대 바이트 크기
        overlap_chars (int): 청크 간 중복되는 문자 수
    
    Returns:
        list: 텍스트 청크 목록
    """
    chunks = []
    
    # 전체 텍스트를 바이트로 변환
    text_bytes = text.encode('utf-8')
    total_bytes = len(text_bytes)
    
    if total_bytes <= max_bytes:
        return [text]
    
    # 청크 수 계산 (50% 중첩 고려)
    num_chunks = ceil(total_bytes / (max_bytes * 0.5))
    
    # 문자 단위로 나누기 위한 계산
    chars_per_chunk = len(text) // num_chunks
    
    # 청크 분할
    start = 0
    while start < len(text):
        # 다음 청크의 끝 위치 계산
        end = min(start + chars_per_chunk + overlap_chars, len(text))
        
        # 문장 경계를 찾기
        if end < len(text):
            # 마침표, 느낌표, 물음표 뒤에 공백이 있는 위치 찾기
            sentence_end = max(
                text.rfind('. ', start, end),
                text.rfind('! ', start, end),
                text.rfind('? ', start, end),
                text.rfind('\n\n', start, end)  # 단락 구분자도 추가
            )
            
            # 문장 경계가 있으면 그 위치로 끝 조정
            if sentence_end > start + chars_per_chunk // 2:
                end = sentence_end + 2  # 문장 끝 + 공백 포함
        
        # 청크 추가
        chunk = text[start:end]
        chunks.append(chunk)
        
        # 다음 청크의 시작점 (중복 고려)
        start = end - overlap_chars if end < len(text) else end
    
    return chunks

def process_tmj_text_with_claude(api_key, text_chunks, base_prompt):
    """
    텍스트 청크를 Claude API를 사용하여 처리합니다.
    
    Args:
        api_key (str): Anthropic API 키
        text_chunks (list): 텍스트 청크 목록
        base_prompt (str): 프롬프트 베이스 템플릿
    
    Returns:
        list: 각 청크의 분석 결과
    """
    all_results = []
    
    for i, chunk in enumerate(text_chunks):
        print(f"청크 {i+1}/{len(text_chunks)} 처리 중... ({len(chunk.encode('utf-8'))} 바이트)")
        
        # 프롬프트 준비
        full_prompt = base_prompt.replace("{texts}", chunk)
        
        # API 요청 설정
        headers = {
            "Content-Type": "application/json",
            "x-api-key": api_key,
            "anthropic-version": "2023-06-01"
        }
        
        data = {
            "model": "claude-3-5-sonnet-20241022",
            "max_tokens": 4000,
            "temperature": 0,
            "system": "턱관절장애(TMJ) 진료 기록을 JSON 형식으로만 응답하세요. 설명이나 주석 없이 JSON 데이터만 반환하세요.",
            "messages": [
                {
                    "role": "user",
                    "content": full_prompt
                }
            ]
        }
        
        # 재시도 로직 추가 (최대 3번)
        max_retries = 3
        retry_delay = 10  # 초 단위
        
        for retry in range(max_retries):
            try:
                print(f"API 요청 시도 {retry + 1}/{max_retries}...")
                
                response = requests.post(
                    "https://api.anthropic.com/v1/messages",
                    headers=headers,
                    json=data
                )
                
                if response.status_code == 200:
                    result = response.json()
                    response_text = result['content'][0]['text']
                    
                    # 원시 응답 저장 (디버깅용)
                    with open(f"tmj_raw_response_{i+1}.txt", "w", encoding="utf-8") as f:
                        f.write(response_text)
                    
                    # JSON 추출
                    try:
                        # JSON 부분 추출 시도 (추출 방식 강화)
                        json_str = ""
                        
                        # 방법 1: ```json 코드 블록 찾기
                        if "```json" in response_text:
                            json_str = response_text.split("```json")[1].split("```")[0].strip()
                        
                        # 방법 2: 일반 ``` 코드 블록 찾기
                        elif "```" in response_text:
                            code_blocks = response_text.split("```")
                            # 첫 번째 코드 블록 내용 사용
                            if len(code_blocks) >= 3:  # 최소한 시작과 끝 태그가 있어야 함
                                json_str = code_blocks[1].strip()
                        
                        # 방법 3: 배열 형태 찾기 - 가장 바깥쪽 괄호 쌍 찾기
                        elif '[' in response_text and ']' in response_text:
                            start_idx = response_text.find('[')
                            end_idx = response_text.rfind(']') + 1
                            if start_idx != -1 and end_idx > start_idx:
                                json_str = response_text[start_idx:end_idx]
                        
                        # 방법 4: 객체 형태 찾기
                        elif '{' in response_text and '}' in response_text:
                            start_idx = response_text.find('{')
                            end_idx = response_text.rfind('}') + 1
                            if start_idx != -1 and end_idx > start_idx:
                                json_str = response_text[start_idx:end_idx]
                        
                        # JSON 문자열이 추출되었는지 확인
                        if json_str:
                            # 추출된 JSON 문자열 저장 (디버깅용)
                            with open(f"tmj_json_str_{i+1}.txt", "w", encoding="utf-8") as f:
                                f.write(json_str)
                            
                            # JSON 파싱
                            json_result = json.loads(json_str)
                            
                            # 결과가 리스트인지 확인하고 적절히 처리
                            if isinstance(json_result, list):
                                all_results.extend(json_result)
                                print(f"청크 {i+1}: {len(json_result)}개 항목 추출 성공")
                            else:
                                all_results.append(json_result)
                                print(f"청크 {i+1}: 1개 항목 추출 성공")
                            
                            # 결과 저장 (청크별)
                            with open(f"tmj_results_chunk_{i+1}.json", "w", encoding="utf-8") as f:
                                json.dump(json_result, f, ensure_ascii=False, indent=2)
                            
                            # 성공했으므로 재시도 루프 종료
                            break
                        else:
                            print(f"청크 {i+1}에서 JSON을 찾을 수 없습니다.")
                            
                            if retry < max_retries - 1:
                                print(f"{retry_delay}초 후 재시도합니다...")
                                time.sleep(retry_delay)
                                continue
                            else:
                                print("최대 재시도 횟수 초과. 다음 청크로 넘어갑니다.")
                    
                    except (json.JSONDecodeError, IndexError) as e:
                        print(f"청크 {i+1} JSON 파싱 오류: {str(e)}")
                        print("오류가 발생한 JSON 문자열의 일부:")
                        if json_str:
                            print(json_str[:100] + "..." if len(json_str) > 100 else json_str)
                        
                        # 기본 중첩 구조 수정 시도
                        if json_str:
                            try:
                                # 중첩된 따옴표 이스케이프 문제 수정 시도
                                fixed_json = json_str.replace('\\"', '"').replace('\\\\', '\\')
                                json_result = json.loads(fixed_json)
                                
                                if isinstance(json_result, list):
                                    all_results.extend(json_result)
                                    print(f"청크 {i+1}: 수정 후 {len(json_result)}개 항목 추출 성공")
                                else:
                                    all_results.append(json_result)
                                    print(f"청크 {i+1}: 수정 후 1개 항목 추출 성공")
                                
                                with open(f"tmj_results_chunk_{i+1}_fixed.json", "w", encoding="utf-8") as f:
                                    json.dump(json_result, f, ensure_ascii=False, indent=2)
                                
                                # 성공했으므로 재시도 루프 종료
                                break
                            except json.JSONDecodeError:
                                print("JSON 수정 시도 실패")
                                
                                if retry < max_retries - 1:
                                    print(f"{retry_delay}초 후 재시도합니다...")
                                    time.sleep(retry_delay)
                                    continue
                                else:
                                    print("최대 재시도 횟수 초과. 다음 청크로 넘어갑니다.")
                
                elif response.status_code in [429, 500, 502, 503, 504, 520]:
                    # 서버 오류 또는 속도 제한 관련 오류 - 재시도
                    print(f"청크 {i+1} 에러 코드: {response.status_code}")
                    print(f"서버 오류 또는 속도 제한. {retry_delay}초 후 재시도합니다...")
                    
                    # 다음 재시도 전에 대기 시간 증가 (지수 백오프)
                    time.sleep(retry_delay)
                    retry_delay *= 2  # 다음 재시도에는 대기 시간을 두 배로
                    
                    continue
                
                else:
                    # 기타 오류 - 로깅 후 재시도
                    print(f"청크 {i+1} 에러 코드: {response.status_code}")
                    print(f"에러 메시지: {response.text}")
                    
                    if retry < max_retries - 1:
                        print(f"{retry_delay}초 후 재시도합니다...")
                        time.sleep(retry_delay)
                        continue
                    else:
                        print("최대 재시도 횟수 초과. 다음 청크로 넘어갑니다.")
            
            except Exception as e:
                print(f"청크 {i+1} 예외 발생: {str(e)}")
                
                if retry < max_retries - 1:
                    print(f"{retry_delay}초 후 재시도합니다...")
                    time.sleep(retry_delay)
                    continue
                else:
                    print("최대 재시도 횟수 초과. 다음 청크로 넘어갑니다.")
        
        # API 요청 간 딜레이 (훨씬 길게 설정)
        if i < len(text_chunks) - 1:
            sleep_time = 10  # 10초로 증가
            print(f"다음 청크 처리를 위해 {sleep_time}초 대기 중...")
            time.sleep(sleep_time)
    
    return all_results

# 원본 프롬프트 템플릿 유지
tmj_prompt_template = """
다음은 턱관절장애(TMJ) 및 저작근 장애에 대한 진료 기록(PI 텍스트)입니다. 
문서에는 K07.65(퇴행성 관절염), K07.66(저작근의 장애), K07.63(턱관절 통증) 등의 진단 코드, 
파노라마/CT 촬영, 측두하악장애분석검사, 물리치료, 약물 처방, 경과 관찰 등의 내용이 포함될 수 있습니다.

아래 텍스트를 분석하여, 다음 14개 필드를 JSON 형식으로 추출해주세요:

1. onset (발현 시기)  
- 예: "3개월 전", "2023년 1월", "발병 시기 미상"  
- 텍스트에서 구체적으로 언급된 경우만 추출하고, 없으면 `""`(빈 문자열)

2. pattern (증상 양상)  
- "constant" (지속성), "intermittent" (간헐성), "progressive" (점진적 악화)  
- 명확히 언급된 경우에만 지정. 없으면 `""`

3. aggravating_factors (악화 요인 목록, 배열)  
- 예: ["딱딱한 음식", "스트레스", "이 악물기"]  
- 여러 개라면 배열에 순서대로 담고, 없으면 `[]`

4. status (현재 상태)  
- "improving" (호전), "unchanged" (변화 없음), "worsening" (악화)  
- 명시되지 않으면 `""`

5. TMJ_PI_desc (진단/검사 항목, 배열)  
- 파노라마, CT, 측두하악장애분석검사, 초음파, T-scan 등 실시된 검사 이름을 배열로 적습니다.  
- 예: ["파노라마", "Cone Beam CT"]

6. TMJ_PI_treatment (물리치료 항목, 배열)  
- 분사신장치료, 전기자극치료, 복합자극치료, 물리치료 등  
- 예: ["측두하악관절자극요법-단순", "분사신장치료"]

7. drug_treatment (약물치료 항목, 배열)  
- 예: ["소론도정(프레드니솔론)", "페리슨정(에페리손염산염)"]  
- 복용 방법, 용량, 횟수 등은 이 필드가 아닌 `medication_prescription`에 기입

8. closing_dentalgear_desc (교합치료 항목, 배열)  
- 교합안정장치(Splint), 교합조정, 보톡스(교합개선 목적) 등 교합 관련 치료가 있으면 적습니다.  
- 없으면 `[]`

9. PI_check (경과관찰 항목, 배열)  
- "증상 체크 [2주후]", "1개월 후 재내원", "재평가 예정" 등 주기적 검진/재평가 계획  
- 예: ["증상 ck [2주후]"]

10. PI_diagnosis_jojint (턱관절 진단 내용, 문자열)  
- K07.65 퇴행성 관절염, K07.63 턱관절 통증, K07.66 저작근 장애 등 진단명  
- 예: "퇴행성 관절염 (K07.65)"

11. physical_therapy (저작근 장애(K07.66) 물리치료 등, 문자열)  
- 저작근 장애를 치료하기 위해 시행된 물리치료나 자극요법(단순/전기/복합), 분사신장치료 등의 종합 요약  
- 예: "측두하악관절 단순/전기/복합 자극, 분사신장치료"

12. occlusal_treatment (교합안정장치(Splint) 등 장치치료, 문자열)  
- 예: "APS, SS 장치 장착 및 조정"  
- 교합 조정, 장치 제작 등

13. medication_prescription (약물 처방 상세, 문자열)  
- "페리슨정(에페리손염산염) 1/1회/14일 :: 취침 직전 복용" 처럼, 복용 용법/횟수/기간 등을 구체적으로 적습니다.  
- 여러 개라면 문장으로 나열  
- 예: "페리슨정(에페리손염산염) - 1/1회/14일, 소론도정(프레드니솔론) - 1/1회/14일"

14. other_treatment (그 외 보톡스 시술, 악관절 강세척술, 교합조정, 발치 등, 문자열)  
- "보톡스 시술" 등  
- 텍스트에서 확인되면 구체적으로 작성, 없으면 `""`

응답은 다음과 같이 JSON 배열 형태로 주세요:
```json
[
  {
    "onset": "...",
    "pattern": "...",
    "aggravating_factors": [...],
    "status": "...",
    "TMJ_PI_desc": [...],
    "TMJ_PI_treatment": [...],
    "drug_treatment": [...],
    "closing_dentalgear_desc": [...],
    "PI_check": [...],
    "PI_diagnosis_jojint": "...",
    "physical_therapy": "...",
    "occlusal_treatment": "...",
    "medication_prescription": "...",
    "other_treatment": "..."
  }
]
```

설명이나 주석 없이 JSON만 반환해주세요.

분석할 텍스트:
{texts}
"""

# 분석 결과 통합
def combine_tmj_results(results):
    """
    여러 청크의 TMJ 분석 결과를 하나로 통합합니다.
    
    Args:
        results (list): 각 청크의 분석 결과 목록
    
    Returns:
        list: 통합된 분석 결과
    """
    # 단순히 모든 결과를 합치기
    return results

# 누락된 청크 결과 통합
def combine_chunk_files():
    """
    개별적으로 저장된 청크 결과 파일들을 통합합니다.
    """
    all_results = []
    
    # tmj_results_chunk_*.json 파일 찾기
    chunk_files = [f for f in os.listdir('.') if f.startswith('tmj_results_chunk_') and f.endswith('.json')]
    chunk_files.sort(key=lambda x: int(x.split('_')[-1].split('.')[0]))
    
    if not chunk_files:
        print("청크 결과 파일을 찾을 수 없습니다.")
        return all_results
    
    print(f"{len(chunk_files)}개의 청크 결과 파일을 통합합니다.")
    
    for file_name in chunk_files:
        try:
            with open(file_name, 'r', encoding='utf-8') as f:
                chunk_result = json.load(f)
            
            if isinstance(chunk_result, list):
                all_results.extend(chunk_result)
                print(f"{file_name}: {len(chunk_result)}개 항목 추가")
            else:
                all_results.append(chunk_result)
                print(f"{file_name}: 1개 항목 추가")
        
        except Exception as e:
            print(f"{file_name} 처리 중 오류 발생: {str(e)}")
    
    # 결과 저장
    with open('tmj_analysis_combined.json', 'w', encoding='utf-8') as f:
        json.dump(all_results, f, ensure_ascii=False, indent=2)
    
    print(f"통합 완료. 총 {len(all_results)}개 항목이 tmj_analysis_combined.json에 저장되었습니다.")
    
    return all_results

# 메인 프로그램
def process_large_tmj_text(api_key, pi_text, output_file):
    """
    대용량 TMJ 텍스트를 처리합니다.
    
    Args:
        api_key (str): Anthropic API 키
        pi_text (str): 분석할 텍스트
        output_file (str): 출력 JSON 파일 경로
    """
    # 텍스트를 청크로 분할 (훨씬 더 작은 크기로 500KB)
    chunks = chunk_large_text(pi_text, max_bytes=500000, overlap_chars=1000)
    print(f"텍스트가 {len(chunks)}개 청크로 분할되었습니다.")
    
    # 각 청크 크기 출력
    for i, chunk in enumerate(chunks):
        chunk_bytes = len(chunk.encode('utf-8'))
        print(f"청크 {i+1}: {chunk_bytes:,} 바이트 ({chunk_bytes/1024/1024:.2f} MB)")
    
    # Claude API로 텍스트 처리 (원본 프롬프트 사용)
    print("\n텍스트 분석 시작...")
    results = process_tmj_text_with_claude(api_key, chunks, tmj_prompt_template)
    
    # 결과 통합
    combined_results = combine_tmj_results(results)
    
    # 결과 저장
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(combined_results, f, ensure_ascii=False, indent=2)
    
    print(f"\n분석 완료! 결과가 {output_file}에 저장되었습니다.")
    print(f"총 {len(combined_results)}개의 TMJ 진료 기록이 분석되었습니다.")
    
    # 결과가 없는 경우 파일 통합 시도
    if len(combined_results) == 0:
        print("\n자동으로 청크 파일 통합을 시도합니다...")
        combine_chunk_files()

# 사용 예시
if __name__ == "__main__":
    api_key = api_key  # 실제 API 키로 교체
    output_file = "tmj_analysis.json"
    
    # 이미 pi_text 변수가 정의되어 있음을 가정
    process_large_tmj_text(api_key, pi_text, output_file)
    
    # 이미 생성된 파일 통합 시도
    print("\n파일 통합을 시도합니다...")
    combine_chunk_files()
# Out:
# 텍스트가 46개 청크로 분할되었습니다.
# 청크 1: 222,177 바이트 (0.21 MB)
# 청크 2: 241,817 바이트 (0.23 MB)
# 청크 3: 240,354 바이트 (0.23 MB)
# 청크 4: 227,160 바이트 (0.22 MB)
# 청크 5: 225,807 바이트 (0.22 MB)
# 청크 6: 185,458 바이트 (0.18 MB)
# 청크 7: 224,264 바이트 (0.21 MB)
# 청크 8: 221,209 바이트 (0.21 MB)
# 청크 9: 238,344 바이트 (0.23 MB)
# 청크 10: 210,729 바이트 (0.20 MB)
# 청크 11: 216,132 바이트 (0.21 MB)
# 청크 12: 211,037 바이트 (0.20 MB)
# 청크 13: 237,806 바이트 (0.23 MB)
# 청크 14: 248,082 바이트 (0.24 MB)
# 청크 15: 212,395 바이트 (0.20 MB)
# 청크 16: 238,455 바이트 (0.23 MB)
# 청크 17: 230,674 바이트 (0.22 MB)
# 청크 18: 236,766 바이트 (0.23 MB)
# 청크 19: 221,181 바이트 (0.21 MB)
# 청크 20: 244,391 바이트 (0.23 MB)
# 청크 21: 241,172 바이트 (0.23 MB)
# 청크 22: 236,511 바이트 (0.23 MB)
# 청크 23: 234,217 바이트 (0.22 MB)
# 청크 24: 225,994 바이트 (0.22 MB)
# 청크 25: 234,190 바이트 (0.22 MB)
# 청크 26: 229,377 바이트 (0.22 MB)
# 청크 27: 244,022 바이트 (0.23 MB)
# 청크 28: 246,873 바이트 (0.24 MB)
# 청크 29: 242,334 바이트 (0.23 MB)
# 청크 30: 243,643 바이트 (0.23 MB)
# 청크 31: 249,828 바이트 (0.24 MB)
# 청크 32: 243,348 바이트 (0.23 MB)
# 청크 33: 250,593 바이트 (0.24 MB)
# 청크 34: 216,367 바이트 (0.21 MB)
# 청크 35: 250,302 바이트 (0.24 MB)
# 청크 36: 243,168 바이트 (0.23 MB)
# 청크 37: 250,053 바이트 (0.24 MB)
# 청크 38: 247,861 바이트 (0.24 MB)
# 청크 39: 220,166 바이트 (0.21 MB)
# 청크 40: 236,396 바이트 (0.23 MB)
# 청크 41: 227,011 바이트 (0.22 MB)
# 청크 42: 213,343 바이트 (0.20 MB)
# 청크 43: 224,845 바이트 (0.21 MB)
# 청크 44: 205,062 바이트 (0.20 MB)
# 청크 45: 236,969 바이트 (0.23 MB)
# 청크 46: 228,273 바이트 (0.22 MB)
#
# 텍스트 분석 시작...
# 청크 1/46 처리 중... (222177 바이트)
# API 요청 시도 1/3...
# 청크 1 에러 코드: 401
# 에러 메시지: {"type":"error","error":{"type":"authentication_error","message":"invalid x-api-key"}}
# 10초 후 재시도합니다...
# API 요청 시도 2/3...
# 청크 1 에러 코드: 401
# 에러 메시지: {"type":"error","error":{"type":"authentication_error","message":"invalid x-api-key"}}
# 10초 후 재시도합니다...
# API 요청 시도 3/3...
# 청크 1 에러 코드: 401
# 에러 메시지: {"type":"error","error":{"type":"authentication_error","message":"invalid x-api-key"}}
# 최대 재시도 횟수 초과. 다음 청크로 넘어갑니다.
# 다음 청크 처리를 위해 10초 대기 중...
# 청크 2/46 처리 중... (241817 바이트)
# API 요청 시도 1/3...
# 청크 2 에러 코드: 401
# 에러 메시지: {"type":"error","error":{"type":"authentication_error","message":"invalid x-api-key"}}
# 10초 후 재시도합니다...
# API 요청 시도 2/3...
# 청크 2 에러 코드: 401
# 에러 메시지: {"type":"error","error":{"type":"authentication_error","message":"invalid x-api-key"}}
# 10초 후 재시도합니다...
# API 요청 시도 3/3...
# 청크 2 에러 코드: 401
# 에러 메시지: {"type":"error","error":{"type":"authentication_error","message":"invalid x-api-key"}}
# 최대 재시도 횟수 초과. 다음 청크로 넘어갑니다.
# 다음 청크 처리를 위해 10초 대기 중...
# 청크 3/46 처리 중... (240354 바이트)
# API 요청 시도 1/3...
# 청크 3 에러 코드: 401
# 에러 메시지: {"type":"error","error":{"type":"authentication_error","message":"invalid x-api-key"}}
# 10초 후 재시도합니다...
# API 요청 시도 2/3...
# 청크 3 에러 코드: 401
# 에러 메시지: {"type":"error","error":{"type":"authentication_error","message":"invalid x-api-key"}}
# 10초 후 재시도합니다...
# API 요청 시도 3/3...
# 청크 3 에러 코드: 401
# 에러 메시지: {"type":"error","error":{"type":"authentication_error","message":"invalid x-api-key"}}
# 최대 재시도 횟수 초과. 다음 청크로 넘어갑니다.
# 다음 청크 처리를 위해 10초 대기 중...
